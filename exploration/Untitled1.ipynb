# %%
from owid.catalog import LocalCatalog

# %%
import altair as alt

# %%
catalog = LocalCatalog("../data", channels=("garden", "backport"))
# Out:
# 2022-05-26 14:39.07 [info     ] reindex.start                  channels=('garden', 'backport')
# 2022-05-26 14:39.08 [info     ] reindex                        channel=garden datasets=15
# 2022-05-26 14:39.10 [info     ] reindex                        channel=backport datasets=763

# %%
df = catalog.find("dataset_5186").load()

# %%
df["medium_fertility_variant__2020__2100__dependency_ratios__both_sexes_combined__for_different_age_groups__annual_total_dep__ratio__0_14__and__65plus__15_64__pct"].metadata
# Out:
# VariableMeta(title='Medium fertility variant, 2020 - 2100: Dependency ratios (both sexes combined) for different age groups - Annual total dep. ratio [(0-14 & 65+) / 15-64] (%)', description=None, sources=[Source(name='United Nations – Population Division (2019 Revision)', description='Annual dependency ratios (total, child, old-age) for different age groups and for both sexes combined.', url='https://population.un.org/wpp2019/Download/Standard/Interpolated/', source_data_url=None, owid_data_url=None, date_accessed='29 September 2020', publication_date=None, publication_year=None, published_by='United Nations, Department of Economic and Social Affairs, Population Division (2019). World Population Prospects: The 2019 Revision, DVD Edition.', publisher_source='')], licenses=[], unit='Dependency ratios (both sexes combined) for different age groups', short_unit=None, display=None, additional_info={'grapher_meta': {'id': 144739, 'name': 'Medium fertility variant, 2020 - 2100: Dependency 
# ...

# %%
df.head()
# Out:
#                   estimates__1950__2020__dependency_ratios__both_sexes_combined__for_different_age_groups__annual_child_dep__ratio__0_19__20_64__pct  \
# entity_name year
# Afghanistan 1950                                         111.163002
#             1951                                         112.258003
#             1952                                         112.776001
#             1953                                         113.108002
#             1954                                         113.404999
#
#                   estimates__1950__2020__dependency_ratios__both_sexes_combined__for_different_age_groups__annual_total_dep__ratio__0_14__and__65plus__15_64__pct  \
# entity_name year
# Afghanistan 1950                                          78.237999
#             1951                                          79.141998
#             1952                                          79.470001
#             1953                                          79.572998
# ...

# %%
df.plot(x="estimates__1950__2020__dependency_ratios__both_sexes_combined__for_different_age_groups__annual_child_dep__ratio__0_19__20_64__pct")
# Out:
# <AxesSubplot:xlabel='estimates__1950__2020__dependency_ratios__both_sexes_combined__for_different_age_groups__annual_child_dep__ratio__0_19__20_64__pct'>

# %%
# !pip install altair
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 KB 7.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 KB 9.1 MB/s eta 0:00:00
# ...
# WARNING: Error parsing requirements for etl: Invalid URL: vendor/owid-catalog-py
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.1 is available.
# You should consider upgrading via the '/work/etl/.venv/bin/python -m pip install --upgrade pip' command.

# %%
alt.Chart(df.loc[["Austria", "Germany", "Russia", "China"], :].reset_index()).mark_line().encode(
    x="year",
    y=alt.Y("estimates__1950__2020__dependency_ratios__both_sexes_combined__for_different_age_groups__annual_child_dep__ratio__0_19__20_64__pct", title="Dependecy ratio"),
    color="entity_name",
)
# Out:
# alt.Chart(...)

# %%
df.loc[["Austria", "Germany"], :]
# Out:
#                   estimates__1950__2020__dependency_ratios__both_sexes_combined__for_different_age_groups__annual_child_dep__ratio__0_19__20_64__pct  \
# entity_name year
# Austria     1950                                          48.721001
#             1951                                          48.652000
#             1952                                          48.796001
#             1953                                          49.088001
#             1954                                          49.473000
# ...                                                             ...
# Germany     2096                                                NaN
#             2097                                                NaN
#             2098                                                NaN
#             2099                                                NaN
#             2100                                                NaN
#
# ...
