# %% [markdown]
# ## Add regions (continents)
#
# Fill set information so we can start to do drilldown/drillup.
#
# For this we add a members column that references other rows by primary key (code)

# %%
df = pd.read_feather("entities/03-countries-with-entitiyids.feather")

# %%
df.shape
# Out:
# (298, 17)

# %% [markdown]
# ❔ Do we have any rows that do not have a continent assigned in the continent column?

# %%
df[df.continent.isnull()]
# Out:
#          code                     name iso_alpha2 iso_alpha3  imf_code  \
# 157      None      Micronesia (region)       None       None       NaN
# 201      None        Rest of the World       None       None       NaN
# 272  OWID_WRL                    World       None       None       NaN
# 280  OWID_ABK                 Abkhazia       None       None       NaN
# 281  OWID_AKD    Akrotiri and Dhekelia       None       None       NaN
# 282  OWID_ERE     Eritrea and Ethiopia       None       None       NaN
# 283  OWID_NAG         Nagorno-Karabakh       None       None       NaN
# 284  OWID_SRM    Serbia and Montenegro       None       None       NaN
# 285  OWID_SEK  Serbia excluding Kosovo       None       None       NaN
# 286  OWID_SML               Somaliland       None       None       NaN
# 287  OWID_SOS            South Ossetia       None       None       NaN
# 288  OWID_TRS             Transnistria       None       None       NaN
# 289  OWID_USS                     USSR       None       None       NaN
# 290  OWID_KRU             United Korea       None       None       NaN
# 291  OWID_YGS               Yugoslavia       None       None       NaN
# 292      None                   Africa       None       None       NaN
# 293      None                     Asia       None       None       NaN
# 294      None                   Europe       None       None       NaN
# 295      None            Latin America       None       None       NaN
# 296      None            North America       None       None       NaN
# 297      None                  Oceania       None       None       NaN
#
#     cow_letter  cow_code unctad_code marc_code ncd_code kansas_code penn_code  \
# 157       None       NaN        None      None     None        None      None
# 201       None       NaN        None      None     None        None      None
# 272       None       NaN        None      None     None        None      None
# 280       None       NaN        None      None     None        None      None
# 281       None       NaN        None      None     None        None      None
# 282       None       NaN        None      None     None        None      None
# 283       None       NaN        None      None     None        None      None
# 284       None       NaN        None      None     None        None      None
# 285       None       NaN        None      None     None        None      None
# 286       None       NaN        None      None     None        None      None
# 287       None       NaN        None      None     None        None      None
# 288       None       NaN        None      None     None        None      None
# 289       None       NaN        None      None     None        None      None
# 290       None       NaN        None      None     None        None      None
# 291       None       NaN        None      None     None        None      None
# 292       None       NaN        None      None     None        None      None
# 293       None       NaN        None      None     None        None      None
# 294       None       NaN        None      None     None        None      None
# 295       None       NaN        None      None     None        None      None
# 296       None       NaN        None      None     None        None      None
# 297       None       NaN        None      None     None        None      None
#
#      continent wikidata_uri wikidata_label  legacy_entity_id  \
# 157        NaN         None           None               NaN
# 201        NaN         None           None               NaN
# 272        NaN         None           None             355.0
# 280        NaN         None           None             386.0
# 281        NaN         None           None             387.0
# 282        NaN         None           None             388.0
# 283        NaN         None           None             389.0
# 284        NaN         None           None             268.0
# 285        NaN         None           None             392.0
# 286        NaN         None           None             393.0
# 287        NaN         None           None             394.0
# 288        NaN         None           None             395.0
# 289        NaN         None           None             270.0
# 290        NaN         None           None             383.0
# 291        NaN         None           None             271.0
# 292        NaN         None           None             273.0
# 293        NaN         None           None             275.0
# 294        NaN         None           None             276.0
# 295        NaN         None           None            5403.0
# 296        NaN         None           None             294.0
# 297        NaN         None           None             277.0
#
#      legacy_country_id
# 157              632.0
# 201              560.0
# 272              559.0
# 280                NaN
# 281                NaN
# 282                NaN
# 283                NaN
# 284                NaN
# 285                NaN
# 286                NaN
# 287                NaN
# 288                NaN
# 289                NaN
# 290                NaN
# 291                NaN
# 292                NaN
# 293                NaN
# 294                NaN
# 295                NaN
# 296                NaN
# 297                NaN

# %% [markdown]
# 💡 It looks like Micronesia (region) is odd - do we have more entries like this?

# %%
df[df.name.str.contains("icronesia")]
# Out:
#      code                  name iso_alpha2 iso_alpha3  imf_code cow_letter  \
# 156   FSM  Micronesia (country)         FM        FSM     868.0        FSM
# 157  None   Micronesia (region)       None       None       NaN       None
#
#      cow_code unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 156     987.0        None        FM     None         FSM       FSM        6.0
# 157       NaN        None      None     None        None      None        NaN
#
#                             wikidata_uri                  wikidata_label  \
# 156  http://www.wikidata.org/entity/Q702  Federated States of Micronesia
# 157                                 None                            None
#
#      legacy_entity_id  legacy_country_id
# 156             222.0              633.0
# 157               NaN              632.0

# %% [markdown]
# I would argue that "Rest of the World" and "Micronesia (region)" should be dropped. They have no other identifiers, no entitiy id and both are not clear enough that they could easily be used across table joins. If we get rid of those then the only entry left that will not have a continent assigned is "World" which sounds good

# %%
df[df.continent.isnull() & df.code.isnull() & df.legacy_entity_id.isnull()]
# Out:
#      code                 name iso_alpha2 iso_alpha3  imf_code cow_letter  \
# 157  None  Micronesia (region)       None       None       NaN       None
# 201  None    Rest of the World       None       None       NaN       None
#
#      cow_code unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 157       NaN        None      None     None        None      None        NaN
# 201       NaN        None      None     None        None      None        NaN
#
#     wikidata_uri wikidata_label  legacy_entity_id  legacy_country_id
# 157         None           None               NaN              632.0
# 201         None           None               NaN              560.0

# %%
cleaned = df.drop(df.loc[df.continent.isnull() & df.code.isnull() & df.legacy_entity_id.isnull()].index)

# %%
cleaned.shape
# Out:
# (296, 17)

# %%
cleaned[cleaned.code.isnull()]
# Out:
#      code           name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 128  None          Korea       None       None       NaN        KOR     730.0
# 292  None         Africa       None       None       NaN       None       NaN
# 293  None           Asia       None       None       NaN       None       NaN
# 294  None         Europe       None       None       NaN       None       NaN
# 295  None  Latin America       None       None       NaN       None       NaN
# 296  None  North America       None       None       NaN       None       NaN
# 297  None        Oceania       None       None       NaN       None       NaN
#
#     unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 128        None      None     None        None      None        2.0
# 292        None      None     None        None      None        NaN
# 293        None      None     None        None      None        NaN
# 294        None      None     None        None      None        NaN
# 295        None      None     None        None      None        NaN
# 296        None      None     None        None      None        NaN
# 297        None      None     None        None      None        NaN
#
#     wikidata_uri wikidata_label  legacy_entity_id  legacy_country_id
# 128         None           None               NaN              832.0
# 292         None           None             273.0                NaN
# 293         None           None             275.0                NaN
# 294         None           None             276.0                NaN
# 295         None           None            5403.0                NaN
# 296         None           None             294.0                NaN
# 297         None           None             277.0                NaN

# %% [markdown]
# ⚡ Code will be our primary key and be mandatory for our table. Let's fill these in with some new, made up values.

# %%
new_codes = {
    "Korea": "OWID_KOR",
    "Africa": "OWID_AFR",
    "Asia": "OWID_ASI",
    "Europe": "OWID_EUR",
    "Oceania": "OWID_OCE",
    "North America": "OWID_NAM",
    "Latin America": "OWID_LAM"    
}

# %% [markdown]
# ❔ Are any of these codes already used?

# %%
cleaned[cleaned.code.isin(new_codes.values())]
# Out:
# Empty DataFrame
# Columns: [code, name, iso_alpha2, iso_alpha3, imf_code, cow_letter, cow_code, unctad_code, marc_code, ncd_code, kansas_code, penn_code, continent, wikidata_uri, wikidata_label, legacy_entity_id, legacy_country_id]
# Index: []

# %%
cleaned["code"] = cleaned.code.fillna(cleaned.name.map(new_codes))

# %%
cleaned[cleaned.code.isnull()]
# Out:
# Empty DataFrame
# Columns: [code, name, iso_alpha2, iso_alpha3, imf_code, cow_letter, cow_code, unctad_code, marc_code, ncd_code, kansas_code, penn_code, continent, wikidata_uri, wikidata_label, legacy_entity_id, legacy_country_id]
# Index: []

# %% [markdown]
# Make sure we don't have any duplicates in the code column

# %%
cleaned.duplicated(subset=["code"]).any()
# Out:
# False

# %% [markdown]
# ### Now group by continent, create and fill the members column

# %%
continents_members = cleaned.groupby("continent")["code"].apply(list)

# %%
continents_members
# Out:
# continent
# 1.0    [AIA, ATG, ABW, BHS, BRB, BLZ, BMU, BES, VGB, ...
# 2.0    [AFG, ARM, AZE, BHR, BGD, BTN, IOT, BRN, KHM, ...
# 3.0    [DZA, AGO, BEN, BWA, BFA, BDI, CMR, CPV, CAF, ...
# 4.0    [ALA, ALB, AND, AUT, OWID_AUH, OWID_BAD, OWID_...
# 5.0    [ARG, BOL, BRA, OWID_NLC, CHL, COL, ECU, FLK, ...
# 6.0    [ASM, AUS, COK, FJI, PYF, GUM, KIR, MHL, OWID_...
# 7.0                            [ATA, BVT, ATF, HMD, SGS]
# Name: code, dtype: object

# %%
continents_members.dtype
# Out:
# dtype('O')

# %%
#continents_members = continents_members.map(lambda m: pd.array(m, dtype="string"))

# %%
continents_members[7.0]
# Out:
# ['ATA', 'BVT', 'ATF', 'HMD', 'SGS']

# %%
first_items = [ l[0] for l in  continents_members.values ]

# %%
cleaned[cleaned.code.isin(first_items)]
# Out:
#    code            name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 0   AFG     Afghanistan         AF        AFG     512.0        AFG     700.0
# 1   ALA   Aland Islands         AX        ALA       NaN       None       NaN
# 3   DZA         Algeria         DZ        DZA     612.0        ALG     615.0
# 4   ASM  American Samoa         AS        ASM     859.0       None       NaN
# 7   AIA        Anguilla         AI        AIA     312.0       None       NaN
# 8   ATA      Antarctica         AQ        ATA       NaN       None       NaN
# 10  ARG       Argentina         AR        ARG     213.0        ARG     160.0
#
#    unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 0          AFG        AF     AFGN         AFG       AFG        2.0
# 1         None      None     None        None      None        4.0
# 3          ALG        AE     ALGR         DZA       DZA        3.0
# 4         None        AS     None         ASM       ASM        6.0
# 7          ANL        AM     None         AIA       AIA        1.0
# 8         None      None     None        None      None        7.0
# 10         ARG        AG     ARGN         ARG       ARG        5.0
#
#                                 wikidata_uri         wikidata_label  \
# 0        http://www.wikidata.org/entity/Q889            Afghanistan
# 1       http://www.wikidata.org/entity/Q5689                  Åland
# 3        http://www.wikidata.org/entity/Q262                Algeria
# 4      http://www.wikidata.org/entity/Q16641         American Samoa
# 7      http://www.wikidata.org/entity/Q25228               Anguilla
# 8   http://www.wikidata.org/entity/Q21590062  Antarctic Treaty area
# 10       http://www.wikidata.org/entity/Q414              Argentina
#
#     legacy_entity_id  legacy_country_id
# 0               15.0              562.0
# 1              296.0              791.0
# 3               17.0              619.0
# 4              246.0              571.0
# 7              228.0              564.0
# 8              346.0              792.0
# 10              21.0              569.0

# %%
continents_map = {
    1.0: "OWID_NAM",
    2.0: "OWID_ASI",
    3.0: "OWID_AFR",
    4.0: "OWID_EUR",
    5.0: "OWID_LAM",
    6.0: "OWID_OCE",
    7.0: "ATA"
}
reverse_continents_map = {key: value for (value, key) in continents_map.items()}

# %%
cleaned["members"] = cleaned.code.map(lambda code: continents_members[reverse_continents_map[code]] if code in reverse_continents_map else [])

# %%
cleaned[cleaned.code == "ATA"]
# Out:
#   code        name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 8  ATA  Antarctica         AQ        ATA       NaN       None       NaN
#
#   unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 8        None      None     None        None      None        7.0
#
#                                wikidata_uri         wikidata_label  \
# 8  http://www.wikidata.org/entity/Q21590062  Antarctic Treaty area
#
#    legacy_entity_id  legacy_country_id                    members
# 8             346.0              792.0  [ATA, BVT, ATF, HMD, SGS]

# %%
antarctica_index = cleaned[cleaned.code == "ATA"].index[0]

# %%
antarctica_index
# Out:
# 8

# %% [markdown]
# All looks good - let's just remove the self reference in Antarctica :)cleaned.loc[cleaned.code == "ATA", "members"].itemcleaned.at[cleaned.code == "ATA", "members"]

# %%
without_ata =  [ m for m in cleaned.loc[cleaned.code == "ATA", "members"].item() if m != "ATA" ]

# %%
without_ata
# Out:
# ['BVT', 'ATF', 'HMD', 'SGS']

# %%
cleaned.loc[cleaned.code == "ATA"]
# Out:
#   code        name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 8  ATA  Antarctica         AQ        ATA       NaN       None       NaN
#
#   unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 8        None      None     None        None      None        7.0
#
#                                wikidata_uri         wikidata_label  \
# 8  http://www.wikidata.org/entity/Q21590062  Antarctic Treaty area
#
#    legacy_entity_id  legacy_country_id                    members
# 8             346.0              792.0  [ATA, BVT, ATF, HMD, SGS]

# %%
cleaned.at[antarctica_index, "members"] = without_ata

# %%
cleaned.loc[cleaned.code == "ATA"]
# Out:
#   code        name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 8  ATA  Antarctica         AQ        ATA       NaN       None       NaN
#
#   unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 8        None      None     None        None      None        7.0
#
#                                wikidata_uri         wikidata_label  \
# 8  http://www.wikidata.org/entity/Q21590062  Antarctic Treaty area
#
#    legacy_entity_id  legacy_country_id               members
# 8             346.0              792.0  [BVT, ATF, HMD, SGS]

# %% [markdown]
# Now set the world to have the continents as members

# %%
cleaned.loc[cleaned.code == "OWID_WRL"]
# Out:
#          code   name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 272  OWID_WRL  World       None       None       NaN       None       NaN
#
#     unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 272        None      None     None        None      None        NaN
#
#     wikidata_uri wikidata_label  legacy_entity_id  legacy_country_id members
# 272         None           None             355.0              559.0      []

# %%
world_index = cleaned.loc[cleaned.code == "OWID_WRL"].index[0]

# %%
continents_values = list(continents_map.values())

# %%
continents_values
# Out:
# ['OWID_NAM', 'OWID_ASI', 'OWID_AFR', 'OWID_EUR', 'OWID_LAM', 'OWID_OCE', 'ATA']

# %%
cleaned.at[world_index, "members"] = continents_values

# %%
cleaned.loc[cleaned.code == "OWID_WRL"]
# Out:
#          code   name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 272  OWID_WRL  World       None       None       NaN       None       NaN
#
#     unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 272        None      None     None        None      None        NaN
#
#     wikidata_uri wikidata_label  legacy_entity_id  legacy_country_id  \
# 272         None           None             355.0              559.0
#
#                                                members
# 272  [OWID_NAM, OWID_ASI, OWID_AFR, OWID_EUR, OWID_...

# %% [markdown]
# ## Save the file

# %%
cleaned = cleaned.reset_index(drop=True)

# %%
cleaned.dtypes
# Out:
# code                  object
# name                  object
# iso_alpha2            object
# iso_alpha3            object
# imf_code             float64
# cow_letter            object
# cow_code             float64
# unctad_code           object
# marc_code             object
# ncd_code              object
# kansas_code           object
# penn_code             object
# continent            float64
# wikidata_uri          object
# wikidata_label        object
# legacy_entity_id     float64
# legacy_country_id    float64
# members               object
# dtype: object

# %%
cleaned_modern_dtypes = cleaned.convert_dtypes()

# %%
cleaned_modern_dtypes.dtypes
# Out:
# code                 string
# name                 string
# iso_alpha2           string
# iso_alpha3           string
# imf_code              Int64
# cow_letter           string
# cow_code              Int64
# unctad_code          string
# marc_code            string
# ncd_code             string
# kansas_code          string
# penn_code            string
# continent             Int64
# wikidata_uri         string
# wikidata_label       string
# legacy_entity_id      Int64
# legacy_country_id     Int64
# members              object
# dtype: object

# %%
cleaned_modern_dtypes.head()
# Out:
#   code            name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 0  AFG     Afghanistan         AF        AFG       512        AFG       700
# 1  ALA   Aland Islands         AX        ALA      <NA>       <NA>      <NA>
# 2  ALB         Albania         AL        ALB       914        ALB       339
# 3  DZA         Algeria         DZ        DZA       612        ALG       615
# 4  ASM  American Samoa         AS        ASM       859       <NA>      <NA>
#
#   unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 0         AFG        AF     AFGN         AFG       AFG          2
# 1        <NA>      <NA>     <NA>        <NA>      <NA>          4
# 2         ALB        AA     ALBN         ALB       ALB          4
# 3         ALG        AE     ALGR         DZA       DZA          3
# 4        <NA>        AS     <NA>         ASM       ASM          6
#
#                             wikidata_uri  wikidata_label  legacy_entity_id  \
# 0    http://www.wikidata.org/entity/Q889     Afghanistan                15
# 1   http://www.wikidata.org/entity/Q5689           Åland               296
# 2    http://www.wikidata.org/entity/Q222         Albania                16
# 3    http://www.wikidata.org/entity/Q262         Algeria                17
# 4  http://www.wikidata.org/entity/Q16641  American Samoa               246
#
#    legacy_country_id members
# 0                562      []
# 1                791      []
# 2                565      []
# 3                619      []
# 4                571      []

# %%
cleaned_modern_dtypes.drop(["continent"], axis=1, inplace=True)

# %%
cleaned_modern_dtypes.head()
# Out:
#   code            name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 0  AFG     Afghanistan         AF        AFG       512        AFG       700
# 1  ALA   Aland Islands         AX        ALA      <NA>       <NA>      <NA>
# 2  ALB         Albania         AL        ALB       914        ALB       339
# 3  DZA         Algeria         DZ        DZA       612        ALG       615
# 4  ASM  American Samoa         AS        ASM       859       <NA>      <NA>
#
#   unctad_code marc_code ncd_code kansas_code penn_code  \
# 0         AFG        AF     AFGN         AFG       AFG
# 1        <NA>      <NA>     <NA>        <NA>      <NA>
# 2         ALB        AA     ALBN         ALB       ALB
# 3         ALG        AE     ALGR         DZA       DZA
# 4        <NA>        AS     <NA>         ASM       ASM
#
#                             wikidata_uri  wikidata_label  legacy_entity_id  \
# 0    http://www.wikidata.org/entity/Q889     Afghanistan                15
# 1   http://www.wikidata.org/entity/Q5689           Åland               296
# 2    http://www.wikidata.org/entity/Q222         Albania                16
# 3    http://www.wikidata.org/entity/Q262         Algeria                17
# 4  http://www.wikidata.org/entity/Q16641  American Samoa               246
#
#    legacy_country_id members
# 0                562      []
# 1                791      []
# 2                565      []
# 3                619      []
# 4                571      []

# %%
cleaned_modern_dtypes.loc[cleaned_modern_dtypes.code == "OWID_WRL"]
# Out:
#          code   name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 270  OWID_WRL  World       <NA>       <NA>      <NA>       <NA>      <NA>
#
#     unctad_code marc_code ncd_code kansas_code penn_code wikidata_uri  \
# 270        <NA>      <NA>     <NA>        <NA>      <NA>         <NA>
#
#     wikidata_label  legacy_entity_id  legacy_country_id  \
# 270           <NA>               355                559
#
#                                                members
# 270  [OWID_NAM, OWID_ASI, OWID_AFR, OWID_EUR, OWID_...

# %%
import json

# %%
cleaned_modern_dtypes.members = cleaned_modern_dtypes.members.map(lambda row: json.dumps(row) if row != [] else None)

# %%
cleaned_modern_dtypes.loc[cleaned_modern_dtypes.code == "OWID_WRL"]
# Out:
#          code   name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 270  OWID_WRL  World       <NA>       <NA>      <NA>       <NA>      <NA>
#
#     unctad_code marc_code ncd_code kansas_code penn_code wikidata_uri  \
# 270        <NA>      <NA>     <NA>        <NA>      <NA>         <NA>
#
#     wikidata_label  legacy_entity_id  legacy_country_id  \
# 270           <NA>               355                559
#
#                                                members
# 270  ["OWID_NAM", "OWID_ASI", "OWID_AFR", "OWID_EUR...

# %%
cleaned_modern_dtypes.head()
# Out:
#   code            name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 0  AFG     Afghanistan         AF        AFG       512        AFG       700
# 1  ALA   Aland Islands         AX        ALA      <NA>       <NA>      <NA>
# 2  ALB         Albania         AL        ALB       914        ALB       339
# 3  DZA         Algeria         DZ        DZA       612        ALG       615
# 4  ASM  American Samoa         AS        ASM       859       <NA>      <NA>
#
#   unctad_code marc_code ncd_code kansas_code penn_code  \
# 0         AFG        AF     AFGN         AFG       AFG
# 1        <NA>      <NA>     <NA>        <NA>      <NA>
# 2         ALB        AA     ALBN         ALB       ALB
# 3         ALG        AE     ALGR         DZA       DZA
# 4        <NA>        AS     <NA>         ASM       ASM
#
#                             wikidata_uri  wikidata_label  legacy_entity_id  \
# 0    http://www.wikidata.org/entity/Q889     Afghanistan                15
# 1   http://www.wikidata.org/entity/Q5689           Åland               296
# 2    http://www.wikidata.org/entity/Q222         Albania                16
# 3    http://www.wikidata.org/entity/Q262         Algeria                17
# 4  http://www.wikidata.org/entity/Q16641  American Samoa               246
#
#    legacy_country_id members
# 0                562    None
# 1                791    None
# 2                565    None
# 3                619    None
# 4                571    None

# %%
cleaned_modern_dtypes.to_feather("entities/04-countries-with-continents.feather")
