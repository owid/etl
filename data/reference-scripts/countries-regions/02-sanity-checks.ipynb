# %% [markdown]
# ## Did we store any non-standard ISO level 2/3 area codes?

# %%
df = pd.read_feather("intermediate/01-countries-from-mysql.feather")

# %%
df
# Out:
#       id                owid_name iso_alpha2 iso_alpha3  imf_code cow_letter  \
# 0    562              Afghanistan         AF        AFG     512.0        AFG
# 1    791            Aland Islands         AX        ALA       NaN       None
# 2    565                  Albania         AL        ALB     914.0        ALB
# 3    619                  Algeria         DZ        DZA     612.0        ALG
# 4    571           American Samoa         AS        ASM     859.0       None
# ..   ...                      ...        ...        ...       ...        ...
# 275  830      Yemen Arab Republic       None       None       NaN        YAR
# 276  831  Yemen People's Republic       None       None       NaN        YPR
# 277  789                   Zambia         ZM        ZMB     754.0        ZAM
# 278  829                 Zanzibar       None       None       NaN        ZAN
# 279  790                 Zimbabwe         ZW        ZWE     698.0        ZIM
#
#      cow_code unctad_code marc_code ncd_code kansas_code penn_code  continent
# 0       700.0         AFG        AF     AFGN         AFG       AFG        2.0
# 1         NaN        None      None     None        None      None        4.0
# 2       339.0         ALB        AA     ALBN         ALB       ALB        4.0
# 3       615.0         ALG        AE     ALGR         DZA       DZA        3.0
# 4         NaN        None        AS     None         ASM       ASM        6.0
# ..        ...         ...       ...      ...         ...       ...        ...
# 275     678.0        None      None     None        None      None        2.0
# 276     680.0        None      None     None        None      None        2.0
# 277     551.0         ZAM        ZA     ZMBA         ZMB       ZMB        3.0
# 278     511.0        None      None     None        None      None        3.0
# 279     552.0         ZIM        RH     ZIMB         ZWE       ZWE        3.0
#
# [280 rows x 13 columns]

# %% [markdown]
# ### What entities do not have iso alpha 2 codes?

# %%
df[df["iso_alpha2"].isnull()]
# Out:
#       id                owid_name iso_alpha2 iso_alpha3  imf_code cow_letter  \
# 15   822          Austria-Hungary       None       None       NaN        AUH
# 17   816                    Baden       None       None       NaN        BAD
# 22   813                  Bavaria       None       None       NaN        BAV
# 45   837    Caribbean Netherlands       None       None       NaN       None
# 49   834          Channel Islands       None       None       NaN       None
# 65   823           Czechoslovakia       None       None       NaN        CZE
# 71   815             East Germany       None       None       NaN        GDR
# 105  812                  Hanover       None       None       NaN        HAN
# 107  819          Hesse Electoral       None       None       NaN        HSE
# 108  820        Hesse Grand Ducal       None       None       NaN        HSG
# 128  832                    Korea       None       None       NaN        KOR
# 129  828                   Kosovo       None       None       NaN        KOS
# 153  821     Mecklenburg Schwerin       None       None       NaN        MEC
# 154  835                Melanesia       None       None       NaN       None
# 157  632      Micronesia (region)       None       None       NaN       None
# 158  825                   Modena       None       None       NaN        MOD
# 181  838          Northern Cyprus       None       None       NaN       None
# 191  826                    Parma       None       None       NaN        PMA
# 196  836                Polynesia       None       None       NaN       None
# 200  833      Republic of Vietnam       None       None       NaN        RVN
# 201  560        Rest of the World       None       None       NaN       None
# 217  817                   Saxony       None       None       NaN        SAX
# 253  827                  Tuscany       None       None       NaN        TUS
# 255  824             Two Sicilies       None       None       NaN        SIC
# 270  814             West Germany       None       None       NaN        GFR
# 272  559                    World       None       None       NaN       None
# 273  818             Wuerttemburg       None       None       NaN        WRT
# 275  830      Yemen Arab Republic       None       None       NaN        YAR
# 276  831  Yemen People's Republic       None       None       NaN        YPR
# 278  829                 Zanzibar       None       None       NaN        ZAN
#
#      cow_code unctad_code marc_code ncd_code kansas_code penn_code  continent
# 15      300.0        None      None     None        None      None        4.0
# 17      267.0        None      None     None        None      None        4.0
# 22      245.0        None      None     None        None      None        4.0
# 45        NaN        None      None     None        None      None        5.0
# 49        NaN        None      None     None        None      None        4.0
# 65      315.0        None      None     None        None      None        4.0
# 71      265.0        None      None     None        None      None        4.0
# 105     240.0        None      None     None        None      None        4.0
# 107     273.0        None      None     None        None      None        4.0
# 108     275.0        None      None     None        None      None        4.0
# 128     730.0        None      None     None        None      None        2.0
# 129     347.0        None      None     None        None      None        4.0
# 153     280.0        None      None     None        None      None        4.0
# 154       NaN        None      None     None        None      None        6.0
# 157       NaN        None      None     None        None      None        NaN
# 158     332.0        None      None     None        None      None        4.0
# 181       NaN        None      None     None        None      None        4.0
# 191     335.0        None      None     None        None      None        4.0
# 196       NaN        None      None     None        None      None        6.0
# 200     817.0        None      None     None        None      None        2.0
# 201       NaN        None      None     None        None      None        NaN
# 217     269.0        None      None     None        None      None        4.0
# 253     337.0        None      None     None        None      None        4.0
# 255     329.0        None      None     None        None      None        4.0
# 270     260.0        None      None     None        None      None        4.0
# 272       NaN        None      None     None        None      None        NaN
# 273     271.0        None      None     None        None      None        4.0
# 275     678.0        None      None     None        None      None        2.0
# 276     680.0        None      None     None        None      None        2.0
# 278     511.0        None      None     None        None      None        3.0

# %% [markdown]
# 💡 This looks like most of these are historical entities. World is the main entitiy that we might want to have that does not have a ISO Alpha 2 code
