# %% [markdown]
# ## Add wikidata identifiers for all rows with ISO alpha 3 codes

# %%
df = pd.read_feather("entities/01-countries-from-mysql.feather")

# %% [markdown]
# ### Get all wikidata entity ids for countries with ISO alpha 3 code + english common name
#
# We do this for two reasons. First we want to store the wikidata ids anyhow, and second we will compare the english common names for matches we get. We would expect that all our ISO alpha 3 codes to be the official ones so if we either do not get a reply for an entity or the country name is very different then something odd may be happening.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

# %%
pd.options.display.max_rows = 30
pd.options.display.min_rows = 30

# %% [markdown]
# ⚡ For the query below: P31 is "instance of", Q3624078 is "sovereign state". P297 is ISO alpha 2, P298 is ISO alpha 3

# %%
sparql.setQuery("""
SELECT DISTINCT ?country ?countryLabel ?isoalpha2 ?isoalpha2Label ?isoalpha3 ?isoalpha3Label
WHERE
{
  # ?country wdt:P31 wd:Q3624078 .
  # ?country wdt:P297 ?isoalpha2 .
  # ?country wdt:P298 ?isoalpha3 .
  #not a former country
  FILTER NOT EXISTS {?country wdt:P31 wd:Q3024240}
  #and no an ancient civilisation (needed to exclude ancient Egypt)
  FILTER NOT EXISTS {?country wdt:P31 wd:Q28171280} .

  SERVICE wikibase:label { bd:serviceParam wikibase:language "en" }
}
ORDER BY ?countryLabel
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
sparql_df = pd.json_normalize(results['results']['bindings'])
wikidata_countries = sparql_df[["country.value", "countryLabel.value", "isoalpha2.value", "isoalpha3.value"]]

# %%
wikidata_countries = wikidata_countries.rename(columns={"country.value": "wikidata_uri", "countryLabel.value": "wikidata_label", "isoalpha2.value": "iso_alpha2", "isoalpha3.value": "iso_alpha3"})

# %%
wikidata_countries
# Out:
#                              wikidata_uri            wikidata_label  \
# 0     http://www.wikidata.org/entity/Q889               Afghanistan
# 1     http://www.wikidata.org/entity/Q222                   Albania
# 2     http://www.wikidata.org/entity/Q262                   Algeria
# 3     http://www.wikidata.org/entity/Q228                   Andorra
# 4     http://www.wikidata.org/entity/Q916                    Angola
# 5     http://www.wikidata.org/entity/Q781       Antigua and Barbuda
# 6     http://www.wikidata.org/entity/Q414                 Argentina
# 7     http://www.wikidata.org/entity/Q399                   Armenia
# 8     http://www.wikidata.org/entity/Q408                 Australia
# 9      http://www.wikidata.org/entity/Q40                   Austria
# 10    http://www.wikidata.org/entity/Q227                Azerbaijan
# 11    http://www.wikidata.org/entity/Q398                   Bahrain
# 12    http://www.wikidata.org/entity/Q902                Bangladesh
# 13    http://www.wikidata.org/entity/Q244                  Barbados
# 14    http://www.wikidata.org/entity/Q184                   Belarus
# ..                                    ...                       ...
# 180   http://www.wikidata.org/entity/Q672                    Tuvalu
# 181  http://www.wikidata.org/entity/Q1036                    Uganda
# 182   http://www.wikidata.org/entity/Q212                   Ukraine
# 183   http://www.wikidata.org/entity/Q878      United Arab Emirates
# 184   http://www.wikidata.org/entity/Q145            United Kingdom
# 185    http://www.wikidata.org/entity/Q30  United States of America
# 186    http://www.wikidata.org/entity/Q77                   Uruguay
# 187   http://www.wikidata.org/entity/Q265                Uzbekistan
# 188   http://www.wikidata.org/entity/Q686                   Vanuatu
# 189   http://www.wikidata.org/entity/Q237              Vatican City
# 190   http://www.wikidata.org/entity/Q717                 Venezuela
# 191   http://www.wikidata.org/entity/Q881                   Vietnam
# 192   http://www.wikidata.org/entity/Q805                     Yemen
# 193   http://www.wikidata.org/entity/Q953                    Zambia
# 194   http://www.wikidata.org/entity/Q954                  Zimbabwe
#
#     iso_alpha2 iso_alpha3
# 0           AF        AFG
# 1           AL        ALB
# 2           DZ        DZA
# 3           AD        AND
# 4           AO        AGO
# 5           AG        ATG
# 6           AR        ARG
# 7           AM        ARM
# 8           AU        AUS
# 9           AT        AUT
# 10          AZ        AZE
# 11          BH        BHR
# 12          BD        BGD
# 13          BB        BRB
# 14          BY        BLR
# ..         ...        ...
# 180         TV        TUV
# 181         UG        UGA
# 182         UA        UKR
# 183         AE        ARE
# 184         GB        GBR
# 185         US        USA
# 186         UY        URY
# 187         UZ        UZB
# 188         VU        VUT
# 189         VA        VAT
# 190         VE        VEN
# 191         VN        VNM
# 192         YE        YEM
# 193         ZM        ZMB
# 194         ZW        ZWE
#
# [195 rows x 4 columns]

# %% [markdown]
# #### Create two sets of ISO Alpha 3 codes

# %%
wikidata_alpha3 = set(wikidata_countries["iso_alpha3"])
len(wikidata_alpha3)
# Out:
# 195

# %%
owid_alpha3 = set(df.iso_alpha3)
len(owid_alpha3)
# Out:
# 251

# %% [markdown]
# ❔ Any wikidata alpha 3 codes that do not occur in owid?

# %%
len(wikidata_alpha3.difference(owid_alpha3))
# Out:
# 0

# %% [markdown]
# ❔ Which owid alpha 3 codes are not in the official wikidata countries?

# %%
owid_alpha3_not_in_wikidata = owid_alpha3.difference(wikidata_alpha3)

# %%
df[df.iso_alpha3.isin(owid_alpha3_not_in_wikidata) & (~df.iso_alpha3.isnull())]
# Out:
#       id                                     owid_name iso_alpha2 iso_alpha3  \
# 1    791                                 Aland Islands         AX        ALA
# 4    571                                American Samoa         AS        ASM
# 7    564                                      Anguilla         AI        AIA
# 8    792                                    Antarctica         AQ        ATA
# 12   561                                         Aruba         AW        ABW
# 27   587                                       Bermuda         BM        BMU
# 30   794               Bonaire Sint Eustatius and Saba         BQ        BES
# 33   796                                 Bouvet Island         BV        BVT
# 35   801                British Indian Ocean Territory         IO        IOT
# 36   781                        British Virgin Islands         VG        VGB
# 46   611                                Cayman Islands         KY        CYM
# 52   610                              Christmas Island         CX        CXR
# 53   596                                 Cocos Islands         CC        CCK
# 57   604                                  Cook Islands         CK        COK
# 62   797                                       Curacao         CW        CUW
# ..   ...                                           ...        ...        ...
# 198  727                                   Puerto Rico         PR        PRI
# 202  734                                       Reunion         RE        REU
# 206  795                               Saint Barthlemy         BL        BLM
# 207  742                                  Saint Helena         SH        SHN
# 210  803                    Saint Martin (French part)         MF        MAF
# 211  748                     Saint Pierre and Miquelon         PM        SPM
# 223  809                     Sint Maarten (Dutch part)         SX        SXM
# 229  807  South Georgia and the South Sandwich Islands         GS        SGS
# 236  808                        Svalbard and Jan Mayen         SJ        SJM
# 246  810                                       Tokelau         TK        TKL
# 252  759                      Turks and Caicos Islands         TC        TCA
# 261  811          United States Minor Outlying Islands         UM        UMI
# 262  782                  United States Virgin Islands         VI        VIR
# 269  785                             Wallis and Futuna         WF        WLF
# 271  623                                Western Sahara         EH        ESH
#
#      imf_code cow_letter  cow_code unctad_code marc_code ncd_code kansas_code  \
# 1         NaN       None       NaN        None      None     None        None
# 4       859.0       None       NaN        None        AS     None         ASM
# 7       312.0       None       NaN         ANL        AM     None         AIA
# 8         NaN       None       NaN        None      None     None        None
# 12      314.0       None       NaN         ARU        AW     None         ABW
# 27      319.0       None       NaN         BER        BM     None         BMU
# 30        NaN       None       NaN        None      None     None        None
# 33        NaN       None       NaN        None      None     None        None
# 35        NaN       None       NaN        None      None     None        None
# 36        NaN       None       NaN         BVI        VB     None         VGB
# 46      377.0       None       NaN         CAY        CJ     None         CYM
# 52        NaN       None       NaN        None        XA     None        None
# 53        NaN       None       NaN        None        XB     None        None
# 57      815.0       None       NaN         CKI        CW     None         COK
# 62        NaN       None       NaN        None      None     None        None
# ..        ...        ...       ...         ...       ...      ...         ...
# 198       NaN       None       6.0         PUE        PR     PRTR         PRI
# 202     696.0       None       NaN        None        RE     None         REU
# 206       NaN       None       NaN        None      None     None        None
# 207     855.0       None       NaN         STH        XJ     None         SHN
# 210       NaN       None       NaN        None      None     None        None
# 211     363.0       None       NaN        None        XL     None         SPM
# 223       NaN       None       NaN        None      None     None        None
# 229       NaN       None       NaN        None      None     None        None
# 236       NaN       None       NaN        None      None     None        None
# 246       NaN       None       NaN        None      None     None        None
# 252       NaN       None       NaN         TCI        TC     None         TCA
# 261       NaN       None       NaN        None      None     None        None
# 262       NaN       None       NaN        None        VI     None         VIR
# 269       NaN       None       NaN        None        WF     None         WLF
# 271       NaN       None       NaN        None        SS     None         ESH
#
#     penn_code  continent
# 1        None        4.0
# 4         ASM        6.0
# 7         AIA        1.0
# 8        None        7.0
# 12        ABW        1.0
# 27        BMU        1.0
# 30       None        1.0
# 33       None        7.0
# 35       None        2.0
# 36        VGB        1.0
# 46        CYM        1.0
# 52        CXR        2.0
# 53        CCK        2.0
# 57        COK        6.0
# 62       None        1.0
# ..        ...        ...
# 198       PRI        1.0
# 202       REU        3.0
# 206      None        1.0
# 207       SHN        3.0
# 210      None        1.0
# 211       SPM        1.0
# 223      None        1.0
# 229      None        7.0
# 236      None        4.0
# 246      None        6.0
# 252       TCA        1.0
# 261      None        6.0
# 262       VIR        1.0
# 269       WLF        6.0
# 271       ESH        3.0
#
# [55 rows x 13 columns]

# %% [markdown]
# ### Let's get data on the remaining entities with ISO alpha 3 codes

# %%
remaining_codes = " ".join([f"\"{s}\"" for s in owid_alpha3_not_in_wikidata if s != None])
remaining_codes
# Out:
# '"NFK" "ASM" "GUM" "SXM" "IOT" "VIR" "CCK" "PRI" "TKL" "NIU" "BMU" "BVT" "WLF" "ABW" "CXR" "GIB" "REU" "SGS" "JEY" "MAF" "HMD" "PCN" "IMN" "FLK" "CYM" "TCA" "PSE" "UMI" "SJM" "COK" "ATF" "MNP" "GUF" "SHN" "BLM" "HKG" "BES" "PYF" "GLP" "MYT" "NCL" "GRL" "MAC" "GGY" "MTQ" "MSR" "AIA" "VGB" "ANT" "CUW" "SPM" "ALA" "FRO" "ESH" "ATA"'

# %%
sparql.setQuery(f"""
SELECT DISTINCT ?country ?countryLabel ?isoalpha2 ?isoalpha2Label ?isoalpha3 ?isoalpha3Label
WHERE
{{
  # ?country wdt:P298 ?isocodes .
  # ?country wdt:P297 ?isoalpha2 .
  # ?country wdt:P298 ?isoalpha3 .
  VALUES ?isocodes {{ {remaining_codes} }}.
  #not a former country

  SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en" }}
}}
ORDER BY ?countryLabel
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
sparql_df = pd.json_normalize(results['results']['bindings'])
wikidata_remaining = sparql_df[["country.value", "countryLabel.value", "isoalpha2.value", "isoalpha3.value"]]

# %%
wikidata_remaining = wikidata_remaining.rename(columns={"country.value": "wikidata_uri", "countryLabel.value": "wikidata_label", "isoalpha2.value": "iso_alpha2", "isoalpha3.value": "iso_alpha3"})

# %%
wikidata_remaining
# Out:
#                                 wikidata_uri  \
# 0      http://www.wikidata.org/entity/Q16641
# 1      http://www.wikidata.org/entity/Q25228
# 2   http://www.wikidata.org/entity/Q21590062
# 3      http://www.wikidata.org/entity/Q21203
# 4      http://www.wikidata.org/entity/Q23635
# 5      http://www.wikidata.org/entity/Q23408
# 6      http://www.wikidata.org/entity/Q43448
# 7      http://www.wikidata.org/entity/Q25305
# 8      http://www.wikidata.org/entity/Q27561
# 9       http://www.wikidata.org/entity/Q5785
# 10     http://www.wikidata.org/entity/Q31063
# 11     http://www.wikidata.org/entity/Q36004
# 12     http://www.wikidata.org/entity/Q26988
# 13     http://www.wikidata.org/entity/Q25279
# 14      http://www.wikidata.org/entity/Q9648
# ..                                       ...
# 39     http://www.wikidata.org/entity/Q25362
# 40    http://www.wikidata.org/entity/Q192184
# 41    http://www.wikidata.org/entity/Q126125
# 42     http://www.wikidata.org/entity/Q34617
# 43     http://www.wikidata.org/entity/Q26273
# 44     http://www.wikidata.org/entity/Q35086
# 45    http://www.wikidata.org/entity/Q219060
# 46    http://www.wikidata.org/entity/Q842829
# 47     http://www.wikidata.org/entity/Q36823
# 48     http://www.wikidata.org/entity/Q18221
# 49     http://www.wikidata.org/entity/Q16645
# 50     http://www.wikidata.org/entity/Q11703
# 51     http://www.wikidata.org/entity/Q35555
# 52      http://www.wikidata.org/entity/Q6250
# 53      http://www.wikidata.org/entity/Q5689
#
#                                   wikidata_label iso_alpha2 iso_alpha3
# 0                                 American Samoa         AS        ASM
# 1                                       Anguilla         AI        AIA
# 2                          Antarctic Treaty area         AQ        ATA
# 3                                          Aruba         AW        ABW
# 4                                        Bermuda         BM        BMU
# 5                                  Bouvet Island         BV        BVT
# 6                 British Indian Ocean Territory         IO        IOT
# 7                         British Virgin Islands         VG        VGB
# 8                          Caribbean Netherlands         BQ        BES
# 9                                 Cayman Islands         KY        CYM
# 10                              Christmas Island         CX        CXR
# 11                       Cocos (Keeling) Islands         CC        CCK
# 12                                  Cook Islands         CK        COK
# 13                                       Curaçao         CW        CUW
# 14                              Falkland Islands         FK        FLK
# ..                                           ...        ...        ...
# 39                              Saint Barthélemy         BL        BLM
# 40  Saint Helena, Ascension and Tristan da Cunha         SH        SHN
# 41                    Saint Martin (French part)         MF        MAF
# 42                     Saint Pierre and Miquelon         PM        SPM
# 43                                  Sint Maarten         SX        SXM
# 44  South Georgia and the South Sandwich Islands         GS        SGS
# 45                            State of Palestine         PS        PSE
# 46                        Svalbard and Jan Mayen         SJ        SJM
# 47                                       Tokelau         TK        TKL
# 48                      Turks and Caicos Islands         TC        TCA
# 49          United States Minor Outlying Islands         UM        UMI
# 50                  United States Virgin Islands         VI        VIR
# 51                             Wallis and Futuna         WF        WLF
# 52                                Western Sahara         EH        ESH
# 53                                         Åland         AX        ALA
#
# [54 rows x 4 columns]

# %% [markdown]
# #### Merge wikidata dataframes

# %%
merged_wikidata = pd.merge(wikidata_countries, wikidata_remaining, how="outer")

# %%
merged_wikidata
# Out:
#                                wikidata_uri  \
# 0       http://www.wikidata.org/entity/Q889
# 1       http://www.wikidata.org/entity/Q222
# 2       http://www.wikidata.org/entity/Q262
# 3       http://www.wikidata.org/entity/Q228
# 4       http://www.wikidata.org/entity/Q916
# 5       http://www.wikidata.org/entity/Q781
# 6       http://www.wikidata.org/entity/Q414
# 7       http://www.wikidata.org/entity/Q399
# 8       http://www.wikidata.org/entity/Q408
# 9        http://www.wikidata.org/entity/Q40
# 10      http://www.wikidata.org/entity/Q227
# 11      http://www.wikidata.org/entity/Q398
# 12      http://www.wikidata.org/entity/Q902
# 13      http://www.wikidata.org/entity/Q244
# 14      http://www.wikidata.org/entity/Q184
# ..                                      ...
# 234   http://www.wikidata.org/entity/Q25362
# 235  http://www.wikidata.org/entity/Q192184
# 236  http://www.wikidata.org/entity/Q126125
# 237   http://www.wikidata.org/entity/Q34617
# 238   http://www.wikidata.org/entity/Q26273
# 239   http://www.wikidata.org/entity/Q35086
# 240  http://www.wikidata.org/entity/Q219060
# 241  http://www.wikidata.org/entity/Q842829
# 242   http://www.wikidata.org/entity/Q36823
# 243   http://www.wikidata.org/entity/Q18221
# 244   http://www.wikidata.org/entity/Q16645
# 245   http://www.wikidata.org/entity/Q11703
# 246   http://www.wikidata.org/entity/Q35555
# 247    http://www.wikidata.org/entity/Q6250
# 248    http://www.wikidata.org/entity/Q5689
#
#                                    wikidata_label iso_alpha2 iso_alpha3
# 0                                     Afghanistan         AF        AFG
# 1                                         Albania         AL        ALB
# 2                                         Algeria         DZ        DZA
# 3                                         Andorra         AD        AND
# 4                                          Angola         AO        AGO
# 5                             Antigua and Barbuda         AG        ATG
# 6                                       Argentina         AR        ARG
# 7                                         Armenia         AM        ARM
# 8                                       Australia         AU        AUS
# 9                                         Austria         AT        AUT
# 10                                     Azerbaijan         AZ        AZE
# 11                                        Bahrain         BH        BHR
# 12                                     Bangladesh         BD        BGD
# 13                                       Barbados         BB        BRB
# 14                                        Belarus         BY        BLR
# ..                                            ...        ...        ...
# 234                              Saint Barthélemy         BL        BLM
# 235  Saint Helena, Ascension and Tristan da Cunha         SH        SHN
# 236                    Saint Martin (French part)         MF        MAF
# 237                     Saint Pierre and Miquelon         PM        SPM
# 238                                  Sint Maarten         SX        SXM
# 239  South Georgia and the South Sandwich Islands         GS        SGS
# 240                            State of Palestine         PS        PSE
# 241                        Svalbard and Jan Mayen         SJ        SJM
# 242                                       Tokelau         TK        TKL
# 243                      Turks and Caicos Islands         TC        TCA
# 244          United States Minor Outlying Islands         UM        UMI
# 245                  United States Virgin Islands         VI        VIR
# 246                             Wallis and Futuna         WF        WLF
# 247                                Western Sahara         EH        ESH
# 248                                         Åland         AX        ALA
#
# [249 rows x 4 columns]

# %% [markdown]
# ### Merge owid and wikidata dataframes
#
# Since owid has more entities we do a left join and some wikidata columns will be None for a few cells

# %%
merged_df = df.merge(right=merged_wikidata, how="left", on="iso_alpha3")

# %%
merged_df.head()
# Out:
#     id       owid_name iso_alpha2_x iso_alpha3  imf_code cow_letter  cow_code  \
# 0  562     Afghanistan           AF        AFG     512.0        AFG     700.0
# 1  791   Aland Islands           AX        ALA       NaN       None       NaN
# 2  565         Albania           AL        ALB     914.0        ALB     339.0
# 3  619         Algeria           DZ        DZA     612.0        ALG     615.0
# 4  571  American Samoa           AS        ASM     859.0       None       NaN
#
#   unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 0         AFG        AF     AFGN         AFG       AFG        2.0
# 1        None      None     None        None      None        4.0
# 2         ALB        AA     ALBN         ALB       ALB        4.0
# 3         ALG        AE     ALGR         DZA       DZA        3.0
# 4        None        AS     None         ASM       ASM        6.0
#
#                             wikidata_uri  wikidata_label iso_alpha2_y
# 0    http://www.wikidata.org/entity/Q889     Afghanistan           AF
# 1   http://www.wikidata.org/entity/Q5689           Åland           AX
# 2    http://www.wikidata.org/entity/Q222         Albania           AL
# 3    http://www.wikidata.org/entity/Q262         Algeria           DZ
# 4  http://www.wikidata.org/entity/Q16641  American Samoa           AS

# %% [markdown]
# ❔ which entries have different values for owid_name and wikidata_label?

# %%
merged_df[~merged_df.wikidata_uri.isnull() & (merged_df.owid_name != merged_df.wikidata_label)]
# Out:
#       id                        owid_name iso_alpha2_x iso_alpha3  imf_code  \
# 1    791                    Aland Islands           AX        ALA       NaN
# 8    792                       Antarctica           AQ        ATA       NaN
# 18   583                          Bahamas           BS        BHS     313.0
# 30   794  Bonaire Sint Eustatius and Saba           BQ        BES       NaN
# 51   599                            China           CN        CHN     924.0
# 53   596                    Cocos Islands           CC        CCK       NaN
# 56   603                            Congo           CG        COG     634.0
# 59   600                    Cote d'Ivoire           CI        CIV     662.0
# 62   797                          Curacao           CW        CUW       NaN
# 64   613                          Czechia           CZ        CZE     935.0
# 66   602     Democratic Republic of Congo           CD        COD     636.0
# 80   631                   Faeroe Islands           FO        FRO       NaN
# 87   793      French Southern Territories           TF        ATF       NaN
# 89   641                           Gambia           GM        GMB     648.0
# 141  686                            Macao           MO        MAC       NaN
# 156  633             Micronesia (country)           FM        FSM     868.0
# 170  714                      Netherlands           NL        NLD     138.0
# 187  731                        Palestine           PS        PSE       NaN
# 194  806                         Pitcairn           PN        PCN       NaN
# 202  734                          Reunion           RE        REU     696.0
# 206  795                  Saint Barthlemy           BL        BLM       NaN
# 207  742                     Saint Helena           SH        SHN     855.0
# 215  751            Sao Tome and Principe           ST        STP     716.0
# 223  809        Sint Maarten (Dutch part)           SX        SXM       NaN
# 244  765                            Timor           TL        TLS     537.0
# 260  776                    United States           US        USA     111.0
# 266  778                          Vatican           VA        VAT       NaN
#
#     cow_letter  cow_code unctad_code marc_code ncd_code kansas_code penn_code  \
# 1         None       NaN        None      None     None        None      None
# 8         None       NaN        None      None     None        None      None
# 18         BHM      31.0         BHA        BF     None         BHS       BHS
# 30        None       NaN        None      None     None        None      None
# 51         CHN     710.0         CPR        CH     CHNA         CHN       CHN
# 53        None       NaN        None        XB     None        None       CCK
# 56         CON     484.0         PRC        CF     CNGO        None       COG
# 59         CDI     437.0         IVC        IV     IVCT         CIV       CIV
# 62        None       NaN        None      None     None        None      None
# 64         CZR     316.0         CZE        XR     None         CZE       CZE
# 66         DRC     490.0         ZAI        CG     ZAIR        None       ZAR
# 80        None       NaN        None        FA     None         FRO       FRO
# 87        None       NaN        None      None     None        None      None
# 89         GAM     420.0         GAM        GM     GMBA         GMB       GMB
# 141       None       NaN        None        MH     None         MAC       MAC
# 156        FSM     987.0        None        FM     None         FSM       FSM
# 170        NTH     210.0        None        NE     NTHL         NLD       NLD
# 187       None       NaN         PAL      None     None         PSE       PSE
# 194       None       NaN        None      None     None        None      None
# 202       None       NaN        None        RE     None         REU       REU
# 206       None       NaN        None      None     None        None      None
# 207       None       NaN         STH        XJ     None         SHN       SHN
# 215        STP     403.0         STP        SF     STPR         STP       STP
# 223       None       NaN        None      None     None        None      None
# 244       None     860.0        None        EM     None         TMP       TLS
# 260        USA       2.0        None       XXU     USA0         USA       USA
# 266        PAP     327.0        None        VC     None         VAT       VAT
#
#      continent                              wikidata_uri  \
# 1          4.0      http://www.wikidata.org/entity/Q5689
# 8          7.0  http://www.wikidata.org/entity/Q21590062
# 18         1.0       http://www.wikidata.org/entity/Q778
# 30         1.0     http://www.wikidata.org/entity/Q27561
# 51         2.0       http://www.wikidata.org/entity/Q148
# 53         2.0     http://www.wikidata.org/entity/Q36004
# 56         3.0       http://www.wikidata.org/entity/Q971
# 59         3.0      http://www.wikidata.org/entity/Q1008
# 62         1.0     http://www.wikidata.org/entity/Q25279
# 64         4.0       http://www.wikidata.org/entity/Q213
# 66         3.0       http://www.wikidata.org/entity/Q974
# 80         4.0      http://www.wikidata.org/entity/Q4628
# 87         7.0    http://www.wikidata.org/entity/Q129003
# 89         3.0      http://www.wikidata.org/entity/Q1005
# 141        2.0     http://www.wikidata.org/entity/Q14773
# 156        6.0       http://www.wikidata.org/entity/Q702
# 170        4.0     http://www.wikidata.org/entity/Q29999
# 187        2.0    http://www.wikidata.org/entity/Q219060
# 194        6.0     http://www.wikidata.org/entity/Q35672
# 202        3.0     http://www.wikidata.org/entity/Q17070
# 206        1.0     http://www.wikidata.org/entity/Q25362
# 207        3.0    http://www.wikidata.org/entity/Q192184
# 215        3.0      http://www.wikidata.org/entity/Q1039
# 223        1.0     http://www.wikidata.org/entity/Q26273
# 244        2.0       http://www.wikidata.org/entity/Q574
# 260        1.0        http://www.wikidata.org/entity/Q30
# 266        4.0       http://www.wikidata.org/entity/Q237
#
#                                    wikidata_label iso_alpha2_y
# 1                                           Åland           AX
# 8                           Antarctic Treaty area           AQ
# 18                                    The Bahamas           BS
# 30                          Caribbean Netherlands           BQ
# 51                     People's Republic of China           CN
# 53                        Cocos (Keeling) Islands           CC
# 56                          Republic of the Congo           CG
# 59                                    Ivory Coast           CI
# 62                                        Curaçao           CW
# 64                                 Czech Republic           CZ
# 66               Democratic Republic of the Congo           CD
# 80                                  Faroe Islands           FO
# 87            French Southern and Antarctic Lands           TF
# 89                                     The Gambia           GM
# 141                                         Macau           MO
# 156                Federated States of Micronesia           FM
# 170                    Kingdom of the Netherlands           NL
# 187                            State of Palestine           PS
# 194                              Pitcairn Islands           PN
# 202                                       Réunion           RE
# 206                              Saint Barthélemy           BL
# 207  Saint Helena, Ascension and Tristan da Cunha           SH
# 215                         São Tomé and Príncipe           ST
# 223                                  Sint Maarten           SX
# 244                                    East Timor           TL
# 260                      United States of America           US
# 266                                  Vatican City           VA

# %% [markdown]
# ❔ Are any iso_alpha2 code different?

# %%
merged_df[~merged_df.wikidata_uri.isnull() & (merged_df.iso_alpha2_x != merged_df.iso_alpha2_y)]
# Out:
# Empty DataFrame
# Columns: [id, owid_name, iso_alpha2_x, iso_alpha3, imf_code, cow_letter, cow_code, unctad_code, marc_code, ncd_code, kansas_code, penn_code, continent, wikidata_uri, wikidata_label, iso_alpha2_y]
# Index: []

# %% [markdown]
# ❔ Which entities are left over that do not have a wikidata id?

# %%
merged_df[merged_df.wikidata_uri.isnull()]
# Out:
#       id                owid_name iso_alpha2_x iso_alpha3  imf_code  \
# 15   822          Austria-Hungary         None       None       NaN
# 17   816                    Baden         None       None       NaN
# 22   813                  Bavaria         None       None       NaN
# 45   837    Caribbean Netherlands         None       None       NaN
# 49   834          Channel Islands         None       None       NaN
# 65   823           Czechoslovakia         None       None       NaN
# 71   815             East Germany         None       None       NaN
# 105  812                  Hanover         None       None       NaN
# 107  819          Hesse Electoral         None       None       NaN
# 108  820        Hesse Grand Ducal         None       None       NaN
# 128  832                    Korea         None       None       NaN
# 129  828                   Kosovo         None       None       NaN
# 153  821     Mecklenburg Schwerin         None       None       NaN
# 154  835                Melanesia         None       None       NaN
# 157  632      Micronesia (region)         None       None       NaN
# ..   ...                      ...          ...        ...       ...
# 171  567     Netherlands Antilles           AN        ANT     353.0
# 181  838          Northern Cyprus         None       None       NaN
# 191  826                    Parma         None       None       NaN
# 196  836                Polynesia         None       None       NaN
# 200  833      Republic of Vietnam         None       None       NaN
# 201  560        Rest of the World         None       None       NaN
# 217  817                   Saxony         None       None       NaN
# 253  827                  Tuscany         None       None       NaN
# 255  824             Two Sicilies         None       None       NaN
# 270  814             West Germany         None       None       NaN
# 272  559                    World         None       None       NaN
# 273  818             Wuerttemburg         None       None       NaN
# 275  830      Yemen Arab Republic         None       None       NaN
# 276  831  Yemen People's Republic         None       None       NaN
# 278  829                 Zanzibar         None       None       NaN
#
#     cow_letter  cow_code unctad_code marc_code ncd_code kansas_code penn_code  \
# 15         AUH     300.0        None      None     None        None      None
# 17         BAD     267.0        None      None     None        None      None
# 22         BAV     245.0        None      None     None        None      None
# 45        None       NaN        None      None     None        None      None
# 49        None       NaN        None      None     None        None      None
# 65         CZE     315.0        None      None     None        None      None
# 71         GDR     265.0        None      None     None        None      None
# 105        HAN     240.0        None      None     None        None      None
# 107        HSE     273.0        None      None     None        None      None
# 108        HSG     275.0        None      None     None        None      None
# 128        KOR     730.0        None      None     None        None      None
# 129        KOS     347.0        None      None     None        None      None
# 153        MEC     280.0        None      None     None        None      None
# 154       None       NaN        None      None     None        None      None
# 157       None       NaN        None      None     None        None      None
# ..         ...       ...         ...       ...      ...         ...       ...
# 171       None       NaN         NAN        NA     None         ANT       ANT
# 181       None       NaN        None      None     None        None      None
# 191        PMA     335.0        None      None     None        None      None
# 196       None       NaN        None      None     None        None      None
# 200        RVN     817.0        None      None     None        None      None
# 201       None       NaN        None      None     None        None      None
# 217        SAX     269.0        None      None     None        None      None
# 253        TUS     337.0        None      None     None        None      None
# 255        SIC     329.0        None      None     None        None      None
# 270        GFR     260.0        None      None     None        None      None
# 272       None       NaN        None      None     None        None      None
# 273        WRT     271.0        None      None     None        None      None
# 275        YAR     678.0        None      None     None        None      None
# 276        YPR     680.0        None      None     None        None      None
# 278        ZAN     511.0        None      None     None        None      None
#
#      continent wikidata_uri wikidata_label iso_alpha2_y
# 15         4.0          NaN            NaN          NaN
# 17         4.0          NaN            NaN          NaN
# 22         4.0          NaN            NaN          NaN
# 45         5.0          NaN            NaN          NaN
# 49         4.0          NaN            NaN          NaN
# 65         4.0          NaN            NaN          NaN
# 71         4.0          NaN            NaN          NaN
# 105        4.0          NaN            NaN          NaN
# 107        4.0          NaN            NaN          NaN
# 108        4.0          NaN            NaN          NaN
# 128        2.0          NaN            NaN          NaN
# 129        4.0          NaN            NaN          NaN
# 153        4.0          NaN            NaN          NaN
# 154        6.0          NaN            NaN          NaN
# 157        NaN          NaN            NaN          NaN
# ..         ...          ...            ...          ...
# 171        1.0          NaN            NaN          NaN
# 181        4.0          NaN            NaN          NaN
# 191        4.0          NaN            NaN          NaN
# 196        6.0          NaN            NaN          NaN
# 200        2.0          NaN            NaN          NaN
# 201        NaN          NaN            NaN          NaN
# 217        4.0          NaN            NaN          NaN
# 253        4.0          NaN            NaN          NaN
# 255        4.0          NaN            NaN          NaN
# 270        4.0          NaN            NaN          NaN
# 272        NaN          NaN            NaN          NaN
# 273        4.0          NaN            NaN          NaN
# 275        2.0          NaN            NaN          NaN
# 276        2.0          NaN            NaN          NaN
# 278        3.0          NaN            NaN          NaN
#
# [31 rows x 16 columns]

# %%
merged_df.shape
# Out:
# (280, 16)

# %% [markdown]
# ## Clean merged dataframe and save the new version with wikidata ids

# %%
merged_df.drop(["iso_alpha2_y"], axis=1, inplace=True)

# %%
merged_df.rename(columns={"iso_alpha2_x": "iso_alpha2"}, inplace=True)

# %%
merged_df.shape
# Out:
# (280, 15)

# %%
merged_df.head()
# Out:
#     id       owid_name iso_alpha2 iso_alpha3  imf_code cow_letter  cow_code  \
# 0  562     Afghanistan         AF        AFG     512.0        AFG     700.0
# 1  791   Aland Islands         AX        ALA       NaN       None       NaN
# 2  565         Albania         AL        ALB     914.0        ALB     339.0
# 3  619         Algeria         DZ        DZA     612.0        ALG     615.0
# 4  571  American Samoa         AS        ASM     859.0       None       NaN
#
#   unctad_code marc_code ncd_code kansas_code penn_code  continent  \
# 0         AFG        AF     AFGN         AFG       AFG        2.0
# 1        None      None     None        None      None        4.0
# 2         ALB        AA     ALBN         ALB       ALB        4.0
# 3         ALG        AE     ALGR         DZA       DZA        3.0
# 4        None        AS     None         ASM       ASM        6.0
#
#                             wikidata_uri  wikidata_label
# 0    http://www.wikidata.org/entity/Q889     Afghanistan
# 1   http://www.wikidata.org/entity/Q5689           Åland
# 2    http://www.wikidata.org/entity/Q222         Albania
# 3    http://www.wikidata.org/entity/Q262         Algeria
# 4  http://www.wikidata.org/entity/Q16641  American Samoa

# %%
merged_df.to_feather("entities/02-countries-with-wikidata-ids.feather")
