# %%
import pandas as pd
import numpy as np
import requests
from owid.catalog import Dataset
from etl.paths import BASE_DIR, DAG_DIR, DATA_DIR

from typing import List, Dict, Any

# %% [markdown]
# ## 0. What are the available country names?

# %% [markdown]
# ## 1. Get all the tags for a country

# %%
get_tags_for_title("Singapore")
# Out:
# ['first-stop-singapore/first-stop-singapore',
#  'media-network/activate-singapore',
#  'singapore-invites/singapore-invites',
#  'travel/series/singapore-city-guide',
#  'travel/singapore',
#  'visit-singapore/visit-singapore',
#  'weather/republicofsingapore',
#  'weather/singapore',
#  'world/singapore',
#  'world/singapore-changi-airport',
#  'your-singapore/your-singapore']

# %%
# Get all tags for a given title
def get_tags_for_title(title: str, verbose: bool = False):
    api_tags_url = "https://content.guardianapis.com/tags"
    LIM_PAGE_SIZE = 1000

    data = requests.get(api_tags_url, params={"api-key": API_KEY, "web-title": title, "page-size": LIM_PAGE_SIZE}).json()

    if "response" not in data:
        raise KeyError("No response!")
    if "results" not in data["response"]:
        raise KeyError("No results!")

    response = data["response"]
    results = response["results"]

    # Get num tags and tags (no contributor tags)
    num_tags = response["total"]
    tags = [t["id"] for t in results if t["type"] not in {"contributor"}]

    assert num_tags < LIM_PAGE_SIZE, "Too many tags!"

    ## Display
    tags_blist = '\n- '.join(tags)

    if verbose:
        print(f"There are {len(tags)} for country {country}:\n- {tags_blist}")

    return tags

def get_pages_from_tags(tags: List[str], lazy: bool = True):
    api_content_url = "https://content.guardianapis.com/search"

    # Get list of articles for each tag
    tag_or = "|".join(tags)
    params = params={"api-key": API_KEY, "tag": tag_or, "page-size": 200}
    data = requests.get(api_content_url, params=params).json()

    # Sanity check
    if "response" not in data:
        raise KeyError("No response!")

    response = data["response"]
    assert "results" in data["response"]


    # Number of pages with given tags
    num_pages = response["total"]

    # Get page IDs
    if not lazy:
        page_ids = _get_page_ids(api_content_url, params, response)
    else:
        page_ids = {}
    return num_pages, page_ids


def _get_page_ids(api_url: str, params: Dict[str, Any], response: Dict["str", Any]):
    # Sanity check
    assert "results" in response, "'results' not found in response"
    results = response["results"]

    # Initialise set of IDs
    page_ids = {r["id"] for r in results}

    # Get IDs for remaining pages
    if response["pages"] > 1:
        for page in range(2, response["pages"] + 1):
            data = requests.get(api_url, params=params | {"page": page}).json()
            assert "response" in data, "'response' missing"
            page_ids |= {r["id"] for r in data["response"]["results"]}
    return page_ids

# %%
# Example
tags = get_tags_for_title("North Macedonia")
num_pages = get_pages_from_tags(tags)

# %% [markdown]
# ## Get list of country names

# %%
# Load regions table from disk
tb_regions = Dataset(DATA_DIR / "garden/regions/2023-01-01/regions")["regions"]
# Extract list with country names
tb_regions = tb_regions[~tb_regions["is_historical"] & (tb_regions["region_type"]=="country")]
tb = tb_regions.reset_index()
countries = sorted(set(tb.name))

# %%
def get_tags_for_countries(countries):
    tags_by_country = {}
    for i, country in enumerate(countries):
        if i % 10 == 0:
            print(country)
        try:
            tags = get_tags_for_title(country)
        except KeyError:
            print(f"> Error for {country}")
            tags_by_country[country] = "Error"
        else:
            tags_by_country[country] = tags
    return tags_by_country

tags_by_country = get_tags_for_countries(countries)
# Out:
# Afghanistan
# Armenia
# Belgium
# Brazil
# Cape Verde
# Congo
# Denmark
# Estonia
# French Southern Territories
# Grenada
# Honduras
# Israel
# Kuwait
# Luxembourg
# Mauritania
# Morocco
# Niger
# Palau
# Puerto Rico
# Saint Martin (French part)
# Sierra Leone
# South Sudan
# Tanzania
# Tuvalu
# Vatican

# %%
countries_err = [k for k, v in tags_by_country.items() if v == "Error"]
print(f"{len(countries_err)} countries with error!")

if len(countries_err) > 0:
    # Re-run for errors
    countries_err = [k for k, v in tags_by_country.items() if v == "Error"]
    for country in countries_err:
        print(country)
        try:
            tags = get_tags_for_title(country)
        except KeyError:
            print("> Error")
            tags_by_country[country] = "Error"
# Out:
# 0 countries with error!

# %%
tags_by_country
# Out:
# {'Afghanistan': ['global-development/series/afghanistan-london-conference',
#   'global-development/series/women-report-afghanistan',
#   'sport/afghanistan-cricket-team',
#   'travel/afghanistan',
#   'weather/afghanistan',
#   'world/afghanistan',
#   'world/afghanistantimeline',
#   'world/series/afghanistan-other-voices',
#   'world/series/afghanistan-the-left-behind',
#   'world/series/john-d-mchugh-afghanistan',
#   'world/the-war-logs'],
#  'Aland Islands': [],
#  'Albania': ['football/albania',
#   'travel/albania',
#   'weather/albania',
#   'world/albania'],
#  'Algeria': ['football/algeria',
#   'travel/algeria',
#   'weather/algeria',
#   'world/algeria',
#   'world/algerian-hostage-crisis'],
#  'American Samoa': ['travel/americansamoa'],
#  'Andorra': ['football/andorra',
#   'travel/andorra',
#   'weather/andorra',
#   'weather/andorraandorra',
#   'world/andorra'],
#  'Angola': ['football/angola',
#   'travel/angola',
#   'weather/angola',
#   'world/angola'],
#  'Anguilla': ['travel/anguilla'],
#  'Antigua and Barbuda': ['travel/antiguaandbarbuda',
#   'world/antigua-and-barbuda'],
#  'Argentina': ['football/argentina',
#   'football/argentina-womens-football-team',
#   'sport/argentina-rugby-union-team',
#   'travel/argentina',
#   'travel/offers/argentina',
#   'weather/argentina',
#   'weather/cordobaargentina',
#   'world/argentina'],
#  'Armenia': ['football/armenia',
#   'travel/armenia',
#   'weather/armenia',
#   'weather/armeniacolombia',
#   'world/armenia',
#   'world/armenian-genocide'],
#  'Aruba': ['the-report/utilities-aruba', 'travel/aruba'],
#  'Australia': ['advertiser-content/australian-pork-bring-sustainable-to-the-table/australian-pork-bring-sustainable-to-the-table',
#   'advertiser-content/australian-pork/australian-pork',
#   'advertiser-content/caritas-australia-project-compassion-2024/caritas-australia-project-compassion-2024',
#   'advertiser-content/kimberly-clark-australia-depend/kimberly-clark-australia-depend',
#   'advertiser-content/opera-australia-summer-2023/opera-australia-summer-2023',
#   'art-gallery-of-western-australia-see-things-differently/art-gallery-of-western-australia-see-things-differently',
#   'artanddesign/australia-s-best-photos-of-the-month',
#   'artanddesign/australian-art',
#   'artanddesign/series/great-australian-photographs',
#   'artanddesign/series/guardian-australia-culture-podcast',
#   'australia-2014-reasons/australia-2014-reasons',
#   'australia-news/advance-australia',
#   'australia-news/australia-cop-21-climate-conference-paris',
#   'australia-news/australia-datablog',
#   'australia-news/australia-day',
#   'australia-news/australia-east-coast-floods-2021',
#   'australia-news/australia-news',
#   'australia-news/australia-news-blog',
#   'australia-news/australia-weather',
#   'australia-news/australian-biosecurity',
#   'australia-news/australian-budget-2014',
#   'australia-news/australian-budget-2015',
#   'australia-news/australian-budget-2016',
#   'australia-news/australian-budget-2017',
#   'australia-news/australian-budget-2018',
#   'australia-news/australian-budget-2019',
#   'australia-news/australian-budget-2020',
#   'australia-news/australian-budget-2021',
#   'australia-news/australian-budget-2022',
#   'australia-news/australian-budget-2023',
#   'australia-news/australian-budget-2024',
#   'australia-news/australian-bureau-of-statistics',
#   'australia-news/australian-capital-territory',
#   'australia-news/australian-capital-territory-act',
#   'australia-news/australian-citizenship',
#   'australia-news/australian-competition-and-consumer-commission',
#   'australia-news/australian-conservatives',
#   'australia-news/australian-education',
#   'australia-news/australian-election-2013',
#   'australia-news/australian-election-2016',
#   'australia-news/australian-election-2019',
#   'australia-news/australian-election-2022',
#   'australia-news/australian-federal-police',
#   'australia-news/australian-foreign-policy',
#   'australia-news/australian-greens',
#   'australia-news/australian-immigration-and-asylum',
#   'australia-news/australian-intelligence',
#   'australia-news/australian-medicare',
#   'australia-news/australian-military',
#   'australia-news/australian-motoring-enthusiast-party',
#   'australia-news/australian-political-donations',
#   'australia-news/australian-political-interests-disclosures',
#   'australia-news/australian-politicians-expenses',
#   'australia-news/australian-politics',
#   'australia-news/australian-security-and-counter-terrorism',
#   'australia-news/australian-trade-unions',
#   'australia-news/australian-universities',
#   'australia-news/australian-war-memorial',
#   'australia-news/best-photographs-of-the-month---australia',
#   'australia-news/childcare',
#   'australia-news/consulting--australia-',
#   'australia-news/crime-australia',
#   'australia-news/dear-australia',
#   'australia-news/indigenous-australians',
#   'australia-news/insurance-australia',
#   'australia-news/jim-chalmers--australian-politician-',
#   'australia-news/katter-s-australian-party',
#   'australia-news/katy-gallagher--australian-politician-',
#   'australia-news/national-australia-bank',
#   'australia-news/october-2022-australian-budget',
#   'australia-news/police-policing-australia',
#   'australia-news/reclaim-australia',
#   'australia-news/reserve-bank-of-australia',
#   'australia-news/royal-australian-navy',
#   'australia-news/rural-australia',
#   'australia-news/series/australia-politics-live-with-amy-remeikis',
#   'australia-news/series/australia-politics-live-with-gabrielle-chan',
#   'australia-news/series/australia-reads',
#   'australia-news/series/australia-s-mental-health-crisis',
#   'australia-news/series/australia-s-rental-crisis',
#   'australia-news/series/australia-year-in-review-2023',
#   'australia-news/series/australian-campaign-catchup-2019',
#   'australia-news/series/australian-election-briefing',
#   'australia-news/series/australian-news-live',
#   'australia-news/series/australian-politics-live',
#   'australia-news/series/australias-best-beach',
#   'australia-news/series/bad-bet--australia-s-unshakeable-gambling-addiction',
#   'australia-news/series/burst-your-bubble-australia',
#   'australia-news/series/coronavirus-australia-latest-at-a-glance',
#   'australia-news/series/dear-australia',
#   'australia-news/series/fighting-fit--the-future-of-australia-s-defence',
#   'australia-news/series/indonesian-boys--australian-jails',
#   'australia-news/series/next-left-where-to-now-for-australian-progressives-',
#   'australia-news/series/politics-live-with-katharine-murphy',
#   'australia-news/series/the-future-of-australian-housing',
#   'australia-news/series/toxic-nation--australia-s-pesticide-problem',
#   'australia-news/series/us-election-2020-briefing-australia',
#   'australia-news/south-australia',
#   'australia-news/south-australian-politics',
#   'australia-news/south-australian-state-election-2018',
#   'australia-news/united-australia-party',
#   'australia-news/western-australia',
#   'australia-news/western-australia-election-2017',
#   'australia-news/western-australia-election-2021',
#   'australia-news/western-australian-politics',
#   'australia-stories/australia-stories',
#   'australian-world-orchestra-mahler-9/australian-world-orchestra-mahler-9',
#   'australian-world-orchestra-zubin-mehta/australian-world-orchestra-zubin-mehta',
#   'bank-australia-a-pledge-for-our-future/bank-australia-a-pledge-for-our-future',
#   'books/australian-books',
#   'books/series/australian-book-reviews',
#   'books/series/guardian-australia-book-club',
#   'books/series/reading-australia',
#   'business/australia-economy',
#   'business/australia-post',
#   'business/tourism-australia',
#   'business/virgin-australia',
#   'campaign/callout/au-series-how-has-taylor-swifts-australian-tour-changed-your-relationship-with-your-kids',
#   'campaign/callout/aus-callout-healthcare-in-australia',
#   'campaign/callout/aus-callout-share-your-favourite-music-venue-in-australia',
#   'campaign/callout/aus-series-blind-date-australia',
#   'campaign/callout/aus-series-childcare-in-australia',
#   'campaign/callout/aus-series-intimate-details-australia',
#   'campaign/callout/aus-series-taylor-swift-has-the-australian-eras-tour-brought-you-closer-with-your-children',
#   'campaign/callout/aus-series-youth-gambling-in-australia',
#   'campaign/callout/callout-blind-date-australia',
#   'campaign/callout/callout-blind-date-australia-',
#   'campaign/callout/callout-childcare-in-australia',
#   'campaign/callout/callout-healthcare-in-australia',
#   'campaign/callout/callout-youth-gambling-in-australia',
#   'campaign/email/australian-politics',
#   'campaign/email/sports-au',
#   'care-australia-championing-change/care-australia-championing-change',
#   'cities/series/australian-cities-week',
#   'commentisfree/series/2020s-vision',
#   'commentisfree/series/australianelections2007',
#   'culture/australia-books-blog',
#   'culture/australia-culture-blog',
#   'culture/australian-television',
#   'culture/series/australia-summer-quiz',
#   'culture/series/australia-year-in-review-2022',
#   'culture/series/australian-arts-in-focus',
#   'culture/series/australian-comedy-a-z',
#   'culture/series/book-ahead-australia',
#   'culture/series/guardian-australia-culture-network',
#   'culture/series/the-guide-australia',
#   'culture/series/the-guide-australia-art-and-design-listings',
#   'culture/series/the-guide-australia-books-and-ideas-listings',
#   'culture/series/the-guide-australia-classical-listings',
#   'culture/series/the-guide-australia-comedy-listings',
#   'culture/series/the-guide-australia-dance-listings',
#   'culture/series/the-guide-australia-fashion-listings',
#   'culture/series/the-guide-australia-film-listings',
#   'culture/series/the-guide-australia-food-and-drink-listings',
#   'culture/series/the-guide-australia-music-listings',
#   'culture/series/the-guide-australia-theatre-listings',
#   'culture/series/what-australia-day-means-to-me',
#   'dairy-australia-forward-thinking/dairy-australia-forward-thinking',
#   'dementia-australia-diagnosis-can-change-lives/dementia-australia-diagnosis-can-change-lives',
#   'discover-culture/the-australian-ballet',
#   'environment/australian-bird-of-the-year--2017-',
#   'environment/australian-bird-of-the-year--2019-',
#   'environment/australian-bird-of-the-year-2021',
#   'environment/australian-bird-of-the-year-2023',
#   'environment/australian-marine-parks',
#   'environment/great-australian-bight',
#   'environment/series/australia-v-the-climate-reporting',
#   'environment/series/the-frontline',
#   'experience-western-australia/experience-western-australia',
#   'fashion/australia-fashion',
#   'fashion/australia-fashion-week',
#   'film/australia',
#   'film/series/guardian-australia-film-club',
#   'film/series/rewatching-classic-australian-films',
#   'film/series/the-50-best-films-of-2015-in-australia',
#   'food/australian-food-and-drink',
#   'food/native-ingredients--australia-',
#   'food/series/australian-food-in-season',
#   'football/australia',
#   'football/australian-professional-leagues--apl-',
#   'football/epl-the-view-from-australia',
#   'football/series/epl-the-view-from-australia',
#   'football/series/premier-league-the-view-from-australia',
#   'games/pax-australia',
#   'global/council-of-australian-governments',
#   'guardian-australia-press-office/guardian-australia-press-office',
#   'guardian-events-australia/guardian-events-australia',
#   'guardian-labs-australian-election-poll/guardian-labs-australian-election-poll',
#   'guardian-live-australia/guardian-live-australia',
#   'guardian-masterclasses-australia/australia-art-and-design-courses',
#   'guardian-masterclasses-australia/australia-business',
#   'guardian-masterclasses-australia/guardian-masterclasses-australia',
#   'guardian-masterclasses/courses-in-australia',
#   'industry-super-australia-longevity-lifestyles/industry-super-australia-longevity-lifestyles',
#   'info/about-guardian-australia',
#   'info/series/australian-data-team-blog',
#   'info/series/guardian-australia-digital-blog',
#   'journey-beyond-australia-by-train/journey-beyond-australia-by-train',
#   'law/defamation-law--australia-',
#   'law/law-australia',
#   'lexus-australia-new-luxury/lexus-australia-new-luxury',
#   'lifeandstyle/australia-food-blog',
#   'lifeandstyle/australian-lifestyle',
#   'lifeandstyle/series/australia-s-unsung-food-suburbs',
#   'lifeandstyle/series/great-australian-dishes',
#   'lifeandstyle/series/locals-guide-to-australia',
#   'media/australia-media',
#   'media/australian-broadcasting-corporation',
#   'media/guardian-australia',
#   'media/media-blog-australia',
#   'media/series/ten-years-of-guardian-australia',
#   'media/sky-news-australia',
#   'membership/membership-australia',
#   'music/australian-music',
#   'music/series/australian-anthems',
#   'music/series/australian-critics-picks',
#   'music/series/australias-best-music-venues',
#   'music/series/australias-best-new-music',
#   'music/series/guardian-australia-s-headline-act',
#   'news/series/australia-in-numbers',
#   'news/series/australia-v-the-climate',
#   'opera-australia-the-ring-cycle/opera-australia-the-ring-cycle',
#   'politics/series/australian-politics-weekly',
#   'politics/series/guardian-australia-whiteboard-explainers',
#   'small-business-network/kia-small-business-kia-australia-open-prize-draw',
#   'social-enterprise-australia-2015/social-enterprise-australia-2015',
#   'south-australia-a-new-state-of-mind/south-australia-a-new-state-of-mind',
#   'sport/australia-cricket-team',
#   'sport/australia-england-limited-overs-internationals-2014',
#   'sport/australia-in-england-2012',
#   'sport/australia-in-south-africa-2014',
#   'sport/australia-olympic-team',
#   'sport/australia-rugby-union-team',
#   'sport/australia-sport',
#   'sport/australia-v-england-2016',
#   'sport/australia-women-s-cricket-team',
#   'sport/australia-women-s-rugby-league-team',
#   'sport/australia-women-s-rugby-union-team',
#   'sport/australian-ball-tampering',
#   'sport/australian-open',
#   'sport/australian-open-2009',
#   'sport/australian-open-2010',
#   'sport/australian-open-2011',
#   'sport/australian-open-2012',
#   'sport/australian-open-2013',
#   'sport/australian-open-2014',
#   'sport/australian-open-2015',
#   'sport/australian-open-2016',
#   'sport/australian-open-2017',
#   'sport/australian-open-2018',
#   'sport/australian-open-2019',
#   'sport/australian-open-2020',
#   'sport/australian-open-2021',
#   'sport/australian-open-2022',
#   'sport/australian-open-2023',
#   'sport/australian-open-2024',
#   'sport/australian-rules-football',
#   'sport/australianopen2001',
#   'sport/australianopen2002',
#   'sport/australianopen2003',
#   'sport/australianopen2004',
#   'sport/australianopen2005',
#   'sport/australianopen2006',
#   'sport/australianopen2007',
#   'sport/australianopen2008',
#   'sport/australiarugbyleague',
#   'sport/australias-greatest-sporting-moment',
#   'sport/cricket-australia',
#   'sport/england-australia-limited-overs-2013',
#   'sport/england-in-australia-2011',
#   'sport/football-federation-australia',
#   'sport/india-australia-2008',
#   'sport/rugby-australia',
#   'sport/series/australia-sport-quiz',
#   'sport/series/australia-sportwatch',
#   'sport/series/australians-abroad',
#   'sport/series/concussion-the-hidden-cost-of-sport-in-australia',
#   'sport/series/david-squires-on-australian-sport',
#   'sport/series/guardian-australia-sports-highlights',
#   'sta-work-experience-australia/sta-work-experience-australia',
#   'stage/australian-theatre',
#   'taste-south-australia/taste-south-australia',
#   'the-australian-ballet---tudes-and-circle-electric/the-australian-ballet---tudes-and-circle-electric',
#   'the-university-of-notre-dame-australia-paramedicine/the-university-of-notre-dame-australia-paramedicine',
#   'tourism-wa-camping-with-custodians/tourism-wa-camping-with-custodians',
#   'tourism-western-australia-camping-with-custodians/tourism-western-australia-camping-with-custodians',
#   'tourism-western-australia-where-dream-events-happen/tourism-western-australia-where-dream-events-happen',
#   'tracking/commissioningdesk/australia-business',
#   'tracking/commissioningdesk/australia-culture',
#   'tracking/commissioningdesk/australia-data',
#   'tracking/commissioningdesk/australia-features',
#   'tracking/commissioningdesk/australia-foreign',
#   'tracking/commissioningdesk/australia-gsb',
#   'tracking/commissioningdesk/australia-investigations',
#   'tracking/commissioningdesk/australia-lifestyle',
#   'tracking/commissioningdesk/australia-news',
#   'tracking/commissioningdesk/australia-opinion',
#   'tracking/commissioningdesk/australia-pictures-',
#   'tracking/commissioningdesk/australia-politics',
#   'tracking/commissioningdesk/australia-social-news',
#   'tracking/commissioningdesk/australia-sport',
#   'tracking/commissioningdesk/australia-state-news',
#   'tracking/commissioningdesk/australia-technology',
#   'tracking/commissioningdesk/australia-video',
#   'travel/australia',
#   'travel/australia-travel-blog',
#   'travel/australian-capital-territory',
#   'travel/series/ashes-fans-guide-australia',
#   'travel/series/australian-short-breaks',
#   'travel/series/exploreaustralia',
#   'travel/south-australia',
#   'travel/sydneyoperahouse',
#   'travel/western-australia-travel',
#   'tv-and-radio/great-australian-bake-off',
#   'tv-and-radio/married-at-first-sight-australia',
#   'tv-and-radio/masterchef-australia',
#   'tv-and-radio/series/australian-tv-review',
#   'tv-and-radio/series/jazz-twemlow-week-in-australian-tv',
#   'tv-and-radio/series/unforgettable-australian-tv',
#   'tv-and-radio/the-great-australian-bake-off',
#   'virgin-australia-back-to-business/virgin-australia-back-to-business',
#   'volvo-car-australia-family-bond/volvo-car-australia-family-bond',
#   'west-australian-opera-2023-season/west-australian-opera-2023-season',
#   'west-australian-opera-2024-season/west-australian-opera-2024-season',
#   'west-australian-opera-wundig-wer-wilura/west-australian-opera-wundig-wer-wilura',
#   'western-australia-authentic-aboriginal-experiences/western-australia-authentic-aboriginal-experiences'],
#  'Austria': ['austria-arrive-and-revive/austria-arrive-and-revive',
#   'football/austria',
#   'football/austria-vienna',
#   'sport/austria-womens-football-team',
#   'travel/austria',
#   'travel/offers/austria',
#   'weather/austria',
#   'world/austria'],
#  'Azerbaijan': ['football/azerbaijan',
#   'travel/azerbaijan',
#   'weather/azerbaijan',
#   'world/azerbaijan'],
#  'Bahamas': ['business/series/bahamas-leaks',
#   'travel/bahamas',
#   'weather/bahamas',
#   'world/bahamas'],
#  'Bahrain': ['football/bahrain',
#   'travel/bahrain',
#   'weather/bahrain',
#   'world/bahrain'],
#  'Bangladesh': ['global-development/series/bangladesh-the-adoption-crisis',
#   'sport/bangladesh-cricket-team',
#   'sport/bangladesh-women-s-cricket-team',
#   'sport/bangladeshinengland2005',
#   'sport/england-bangladesh',
#   'sport/england-in-bangladesh-2010',
#   'sport/england-in-bangladesh-2016-17',
#   'sport/england-in-bangladesh-2023',
#   'sport/englandinbangladesh200304',
#   'travel/bangladesh',
#   'weather/bangladesh',
#   'world/bangladesh'],
#  'Barbados': ['travel/barbados', 'weather/barbados', 'world/barbados'],
#  'Belarus': ['campaign/callout/callout-mood-in-belarus',
#   'football/belarus',
#   'stage/belarus-free-theatre',
#   'travel/belarus',
#   'weather/belarus',
#   'world/belarus'],
#  'Belgium': ['football/belgium',
#   'football/belgium-womens-football-team',
#   'music/series/sounds-of-europe-belgium',
#   'travel/belgium',
#   'travel/offers/belgium',
#   'weather/belgium',
#   'world/belgium'],
#  'Belize': ['travel/belize', 'weather/belize', 'world/belize'],
#  'Benin': ['film/annette-bening',
#   'football/benin',
#   'travel/benin',
#   'weather/benin',
#   'world/benin'],
#  'Bermuda': ['travel/bermuda',
#   'weather/bermuda',
#   'weather/bermudabermuda',
#   'world/bermuda'],
#  'Bhutan': ['sustainable-business/series/happiness-in-bhutan',
#   'travel/bhutan',
#   'weather/bhutan',
#   'world/bhutan'],
#  'Bolivia': ['football/bolivia',
#   'travel/bolivia',
#   'weather/bolivia',
#   'world/bolivia'],
#  'Bonaire Sint Eustatius and Saba': [],
#  'Bosnia and Herzegovina': ['travel/bosniaherzegovina',
#   'world/bosnia-and-herzegovina'],
#  'Botswana': ['football/botswana-football',
#   'travel/botswana',
#   'weather/botswana',
#   'world/botswana'],
#  'Bouvet Island': [],
#  'Brazil': ['football/brazil',
#   'football/brazil-womens-football-team',
#   'inside-brazil/inside-brazil',
#   'society/series/public-services-the-brazilian-way',
#   'the-report/brazilworldcup',
#   'the-report/riodejaneiro',
#   'theguardian/insidebrazil',
#   'travel/brazil',
#   'travel/series/learn-brazilian-portuguese',
#   'weather/brazil',
#   'world/brazil',
#   'world/portrait-of-brazil-2014'],
#  'British Indian Ocean Territory': [],
#  'British Virgin Islands': ['travel/britishvirginislands',
#   'world/british-virgin-islands'],
#  'Brunei': ['travel/brunei', 'weather/brunei', 'world/brunei'],
#  'Bulgaria': ['football/bulgaria',
#   'travel/bulgaria',
#   'travel/offers/bulgaria',
#   'weather/bulgaria',
#   'world/bulgaria'],
#  'Burkina Faso': ['football/burkinafaso',
#   'travel/burkinafaso',
#   'weather/burkinafaso',
#   'world/burkina-faso'],
#  'Burundi': ['football/burundi-football-team',
#   'travel/burundi',
#   'weather/burundi',
#   'world/burundi'],
#  'Cambodia': ['law/extraordinary-chambers-in-the-courts-of-cambodia',
#   'travel/cambodia',
#   'weather/cambodia',
#   'world/cambodia'],
#  'Cameroon': ['football/cameroon',
#   'football/cameroon-womens-football-team',
#   'travel/cameroon',
#   'weather/cameroon',
#   'world/cameroon'],
#  'Canada': ['campaign/callout/callout-canada-wildfires',
#   'cities/series/guardian-canada-week',
#   'discover-canada/discover-canada',
#   'discover-cool-canada/ottawa',
#   'discover-cool-canada/pan-canada',
#   'football/canada',
#   'football/canada-womens-football-team',
#   'music/boards-of-canada',
#   'sport/canada-cricket-team',
#   'sport/canada-ice-hockey-team',
#   'sport/canada-women-s-rugby-union-team',
#   'sport/canadarugby',
#   'travel/canada',
#   'travel/offers/canada',
#   'travel/series/canadas-music-cities',
#   'weather/canada',
#   'weather/hamiltoncanada',
#   'world/canada',
#   'world/canada-wildfires',
#   'world/series/canada-legalizes-it'],
#  'Cape Verde': ['football/cape-verde',
#   'travel/capeverde',
#   'weather/capeverde',
#   'world/cape-verde'],
#  'Cayman Islands': ['cayman-islands/cayman-islands',
#   'travel/caymanislands',
#   'us-news/caymanislands',
#   'weather/caymanislands'],
#  'Central African Republic': ['travel/centralafricanrepublic',
#   'weather/centralafricanrepublic',
#   'world/central-african-republic'],
#  'Chad': ['film/chadwick-boseman',
#   'film/gurinder-chadha',
#   'travel/chad',
#   'weather/chad',
#   'world/chad'],
#  'Chile': ['football/chile',
#   'football/chile-womens-football-team',
#   'media/adrian-chiles',
#   'sport/chile-rugby-union-team',
#   'travel/chile',
#   'travel/offers/chile',
#   'weather/chile',
#   'world/chile',
#   'world/chilean-miners-rescue'],
#  'China': ['books/china-mieville',
#   'books/series/china-stories',
#   'cities/series/the-other-china',
#   'cities/series/urban-china',
#   'commentisfree/series/will-china-rule-the-world',
#   'createinchina/createinchina',
#   'culture/chinaarts2008',
#   'environment/chinas-choice',
#   'film/chinatown',
#   'football/china',
#   'football/china-pr-womens-football-team',
#   'global-development/series/china-africa-soft-power-hard-cash',
#   'music/series/inside-china-s-alternative-music-scene',
#   'news/series/china-in-2008-faces-in-a-billion',
#   'sport/china-olympic-team',
#   'travel/china',
#   'travel/greatwall',
#   'travel/offers/china',
#   'weather/china',
#   'world/china',
#   'world/china-earthquake',
#   'world/china-s-one-child-policy',
#   'world/china-spy-balloon-incident-2023',
#   'world/series/china-at-the-crossroads',
#   'world/series/china-leadership-in-transition',
#   'world/series/china-s-war-chest',
#   'world/series/china-tensions-in-the-indo-pacific',
#   'world/series/china-the-next-generation',
#   'world/series/peak-china',
#   'world/series/the-china-cables',
#   'world/south-china-sea'],
#  'Christmas Island': ['australia-news/christmas-island',
#   'australia-news/series/christmas-island-doctors-reports',
#   'travel/christmasisland'],
#  'Cocos Islands': [],
#  'Colombia': ['football/colombia',
#   'football/colombia-women-s-football-team',
#   'travel/colombia',
#   'weather/armeniacolombia',
#   'weather/colombia',
#   'world/colombia',
#   'world/colombia-plane-crash-2016'],
#  'Comoros': ['football/comoros',
#   'travel/comoros',
#   'weather/comoros',
#   'world/comoros'],
#  'Congo': ['football/dr-congo-football-team',
#   'global-development/series/defenders--saving-congo-s-parks',
#   'travel/congobrazzaville',
#   'travel/democraticrepublicofcongo',
#   'weather/congobrazzaville',
#   'weather/democraticrepublicofcongo',
#   'world/congo',
#   'world/congo-brazzaville'],
#  'Cook Islands': ['sport/cook-islands-rugby-league-team',
#   'travel/cookislands',
#   'weather/cookislands',
#   'world/cook-islands'],
#  'Costa Rica': ['football/costa-rica-womens-football-team',
#   'football/costarica',
#   'travel/costarica',
#   'travel/offers/costarica',
#   'world/costa-rica'],
#  "Cote d'Ivoire": [],
#  'Croatia': ['football/croatia',
#   'travel/croatia',
#   'travel/offers/croatia',
#   'visit-authentic-croatia/visit-authentic-croatia',
#   'weather/croatia',
#   'world/croatia'],
#  'Cuba': ['commentisfree/series/cubaaftercastro',
#   'film/cuba-gooding-jr',
#   'film/cuban-fury',
#   'travel/cuba',
#   'travel/offers/cuba',
#   'weather/cuba',
#   'weather/santiagodecuba',
#   'world/cuba'],
#  'Curacao': ['football/curacao'],
#  'Cyprus': ['business/series/cyprus-confidential',
#   'discover-cyprus/discover-cyprus',
#   'football/cyprus',
#   'travel/cyprus',
#   'travel/offers/cyprus',
#   'weather/cyprus',
#   'world/cyprus'],
#  'Czechia': [],
#  'Democratic Republic of Congo': ['weather/democraticrepublicofcongo'],
#  'Denmark': ['football/denmark',
#   'sport/denmark-womens-football-team',
#   'the-everyday-wonders-of-denmark/the-everyday-wonders-of-denmark',
#   'travel/denmark',
#   'travel/offers/denmark',
#   'visit-denmark/visit-denmark',
#   'weather/denmark',
#   'world/denmark'],
#  'Djibouti': ['travel/djibouti',
#   'weather/djibouti',
#   'weather/republicofdjibouti',
#   'world/djibouti'],
#  'Dominica': ['business/series/dominica--passports-of-the-caribbean',
#   'travel/dominica',
#   'travel/dominicanrepublic',
#   'weather/dominica',
#   'weather/dominicanrepublic',
#   'world/dominica',
#   'world/dominicanrepublic'],
#  'Dominican Republic': ['travel/dominicanrepublic',
#   'weather/dominicanrepublic',
#   'world/dominicanrepublic'],
#  'East Timor': [],
#  'Ecuador': ['environment/series/climate-journey-ecuador-peru',
#   'football/ecuador',
#   'travel/ecuador',
#   'travel/offers/ecuador',
#   'weather/ecuador',
#   'world/ecuador'],
#  'Egypt': ['commentisfree/series/egypt-two-years-of-revolution',
#   'film/series/egypt-postscript-to-a-revolution',
#   'football/egypt',
#   'science/egyptology',
#   'travel/egypt',
#   'travel/gizapyramid',
#   'travel/offers/egypt',
#   'weather/egypt',
#   'world/egypt',
#   'world/egyptair-flight-ms804',
#   'world/egyptaircrash',
#   'world/series/egypt-protests',
#   'world/series/the-new-egypt-100-days-on'],
#  'El Salvador': ['travel/elsalvador',
#   'weather/elsalvador',
#   'world/el-salvador'],
#  'Equatorial Guinea': ['football/equitorial-guinea',
#   'travel/equatorialguinea',
#   'world/equatorial-guinea'],
#  'Eritrea': ['travel/eritrea',
#   'weather/eritrea',
#   'world/eritrea',
#   'world/series/inside-eritrea'],
#  'Estonia': ['football/estonia',
#   'travel/estonia',
#   'travel/offers/estonia',
#   'weather/estonia',
#   'world/estonia'],
#  'Eswatini': ['travel/eswatini', 'weather/eswatini', 'world/eswatini'],
#  'Ethiopia': ['food/ethiopian-food-and-drink',
#   'football/ethiopia',
#   'global-development/series/ethiopia-30-years-on-from-the-famine',
#   'travel/ethiopia',
#   'travel/offers/ethiopia',
#   'weather/ethiopia',
#   'world/ethiopia',
#   'world/ethiopian-airlines-crash'],
#  'Falkland Islands': ['travel/falklandislands',
#   'uk/falklands',
#   'weather/falklandislands'],
#  'Faroe Islands': ['football/faroeislands',
#   'travel/faroeislands',
#   'weather/faroeislands',
#   'world/faroe-islands'],
#  'Fiji': ['sport/fiji-rugby-union-team',
#   'sport/fijirugbyleagueteam',
#   'travel/fiji',
#   'weather/fiji',
#   'world/fiji'],
#  'Finland': ['football/finland',
#   'football/finland-womens-football-team',
#   'travel/finland',
#   'travel/offers/finland',
#   'weather/finland',
#   'world/finland'],
#  'France': ['books/francesca-simon',
#   'business/air-france-klm',
#   'campaign/callout/callout-france-protests',
#   'campaign/callout/callout-france-protests-june-2023',
#   'childrens-books-site/frances-hardinge',
#   'culture/frances-barber',
#   'experience-france/experience-france',
#   'film/frances-ha',
#   'film/frances-mcdormand',
#   'film/journal-de-france',
#   'football/france',
#   'football/france-women',
#   'music/series/sounds-of-europe-france',
#   'politics/frances-o-grady',
#   'sport/france-olympic-team',
#   'sport/france-rugby-league-team',
#   'sport/france-rugby-union-team',
#   'sport/france-womens-rugby-union-team',
#   'sport/francesco-molinari',
#   'sport/series/guardian-guide-to-the-100th-tour-de-france',
#   'sport/series/philippa-york-s-team-by-team-guide-to-the-tour-de-france',
#   'sport/series/tour-de-france-2011-video-highlights',
#   'sport/series/tour-de-france-2013-live',
#   'sport/series/tour-de-france-2013-results',
#   'sport/series/tour-de-france-2013-stage-previews',
#   'sport/series/tour-de-france-2014-key-stats',
#   'sport/series/tour-de-france-2014-live',
#   'sport/series/tour-de-france-2014-results',
#   'sport/series/tour-de-france-video-highlights',
#   'sport/tour-de-france-2000',
#   'sport/tour-de-france-2009',
#   'sport/tour-de-france-2010',
#   'sport/tour-de-france-2011',
#   'sport/tour-de-france-2012',
#   'sport/tour-de-france-2013',
#   'sport/tour-de-france-2014',
#   'sport/tour-de-france-2015',
#   'sport/tour-de-france-2016',
#   'sport/tour-de-france-2017',
#   'sport/tour-de-france-2018',
#   'sport/tour-de-france-2019',
#   'sport/tour-de-france-2020',
#   'sport/tour-de-france-2023',
#   'sport/tour-de-france-femmes',
#   'sport/tourdefrance',
#   'sport/tourdefrance1999',
#   'sport/tourdefrance2001',
#   'sport/tourdefrance2002',
#   'sport/tourdefrance2003',
#   'sport/tourdefrance2004',
#   'sport/tourdefrance2005',
#   'sport/tourdefrance2006',
#   'sport/tourdefrance2007',
#   'sport/tourdefrance2008',
#   'stage/francesca-hayward',
#   'stage/francesca-moody',
#   'theguardian/guardian-guide-to-the-100th-tour-de-france',
#   'theguardian/guardian-guide-to-the-100th-tour-de-france/guardian-guide-to-the-100th-tour-de-france',
#   'travel/france',
#   'travel/offers/france',
#   'weather/france',
#   'world/france',
#   'world/france-train-attack',
#   'world/francesco-schettino',
#   'world/series/new-europe-france'],
#  'French Guiana': ['travel/frenchguiana'],
#  'French Polynesia': ['world/french-polynesia'],
#  'French Southern Territories': [],
#  'Gabon': ['football/gabon', 'travel/gabon', 'weather/gabon', 'world/gabon'],
#  'Gambia': ['football/gambia',
#   'football/gambia-football-team',
#   'travel/gambia',
#   'weather/gambia',
#   'world/gambia'],
#  'Gaza Strip': [],
#  'Georgia': ['artanddesign/series/a-guide-to-georgian-architecture-in-britain',
#   'campaign/callout/callout-georgia',
#   'culture/georgia-o-keeffe',
#   'film/the-haunting-of-connecticut-2-the-ghosts-of-georgia',
#   'football/georgia',
#   'music/georgia',
#   'sport/georgia-hall',
#   'sport/georgia-rugby-union-team',
#   'the-report/georgia',
#   'travel/georgia',
#   'us-news/state-of-georgia',
#   'weather/georgia',
#   'world/georgia-news'],
#  'Germany': ['commentisfree/series/germany-now',
#   'commentisfree/series/joris-luyendijk-banking-blog-goes-native-germany',
#   'football/germany',
#   'football/germany-womens-football-team',
#   'music/series/sounds-of-europe-germany',
#   'sport/germany-olympic-team',
#   'travel/germany',
#   'travel/offers/germany',
#   'weather/germany',
#   'world/germany',
#   'world/series/germany-the-accidental-empire',
#   'world/series/new-europe-germany'],
#  'Ghana': ['football/ghana',
#   'the-report/ghana',
#   'travel/ghana',
#   'weather/ghana',
#   'world/ghana'],
#  'Gibraltar': ['football/gibraltar',
#   'the-report/gibraltar',
#   'travel/gibraltar',
#   'world/gibraltar'],
#  'Greece': ['campaign/callout/callout-greece-election',
#   'campaign/callout/callout-greece-train-crash',
#   'campaign/callout/callout-greece-wildfires',
#   'football/greece',
#   'gnto/gnto',
#   'sunvil-greece/sunvil-greece',
#   'travel/greece',
#   'travel/offers/greece',
#   'travel/zeus',
#   'weather/greece',
#   'weather/tripoligreece',
#   'world/greece',
#   'world/series/greece-in-crisis',
#   'world/series/greece-on-the-breadline'],
#  'Greenland': ['travel/greenland', 'weather/greenland', 'world/greenland'],
#  'Grenada': ['travel/grenada', 'weather/grenada', 'world/grenada'],
#  'Guadeloupe': ['travel/guadeloupe'],
#  'Guam': ['travel/guam', 'weather/guam', 'world/guam'],
#  'Guatemala': ['travel/guatemala',
#   'travel/mayan-temples-of-tikal',
#   'weather/guatemala',
#   'weather/guatemalaguatemala',
#   'world/guatemala'],
#  'Guernsey': ['uk-news/guernsey', 'weather/guernsey'],
#  'Guinea': ['football/equitorial-guinea',
#   'football/guinea-bissau-football-team',
#   'football/guinea-football-team',
#   'sport/1000-guineas',
#   'sport/2000-guineas',
#   'sport/papua-new-guinea-rugby-league-team',
#   'travel/equatorialguinea',
#   'travel/guinea',
#   'travel/guinea-bissau',
#   'travel/papuanewguinea',
#   'weather/guinea',
#   'weather/guineabissau',
#   'weather/papuanewguinea',
#   'world/equatorial-guinea',
#   'world/guinea',
#   'world/guinea-bissau',
#   'world/papua-new-guinea'],
#  'Guinea-Bissau': ['football/guinea-bissau-football-team',
#   'travel/guinea-bissau',
#   'weather/guineabissau',
#   'world/guinea-bissau'],
#  'Guyana': ['travel/guyana', 'weather/guyana', 'world/guyana'],
#  'Haiti': ['football/haiti-womens-football-team',
#   'global-development/series/rebuilding-haiti',
#   'music/bernard-haitink',
#   'travel/haiti',
#   'weather/haiti',
#   'world/haiti',
#   'world/series/haiti-six-months-on'],
#  'Heard Island and McDonald Islands': [],
#  'Honduras': ['football/honduras',
#   'travel/honduras',
#   'weather/honduras',
#   'world/honduras'],
#  'Hong Kong': ['hong-kong-tourism/hong-kong-tourism',
#   'travel/hongkong',
#   'travel/series/hong-kong-city-guide',
#   'travel/series/hong-kong-hotlist',
#   'visit-hong-kong/visit-hong-kong',
#   'weather/hongkong',
#   'world/hong-kong',
#   'world/series/the-fight-for-hong-kong'],
#  'Hungary': ['football/hungary',
#   'travel/hungary',
#   'travel/offers/hungary',
#   'weather/hungary',
#   'world/hungary'],
#  'Iceland': ['business/iceland-foods',
#   'campaign/callout/callout-iceland',
#   'football/iceland',
#   'football/iceland-womens-football-team',
#   'travel/iceland',
#   'travel/offers/iceland',
#   'weather/iceland',
#   'world/iceland',
#   'world/iceland-volcano',
#   'world/iceland-volcano-grimsvotn'],
#  'India': ['campaign/callout/callout-india-election-2024',
#   'campaign/callout/callout-indiana-teachers',
#   'culture/indiana-jones',
#   'environment/india-untamed',
#   'environment/terra-india',
#   'film/india-s-daughter',
#   'film/indiana-jones-and-the-kingdom-of-the-crystal-skull',
#   'film/series/100-years-of-indian-cinema',
#   'food/indian',
#   'global-development/series/2004-indian-ocean-tsunami-10-years-on',
#   'media/series/social-india',
#   'sport/england-in-india-2011',
#   'sport/england-in-india-2012-13',
#   'sport/england-in-india-2016-17',
#   'sport/england-in-india-2020-21',
#   'sport/england-in-india-2024',
#   'sport/england-v-india-2018',
#   'sport/england-v-india-2021',
#   'sport/england-v-india-2022',
#   'sport/englandinindia200102',
#   'sport/englandinindia200506',
#   'sport/englandinindia200809',
#   'sport/englandvindia2007',
#   'sport/force-india',
#   'sport/india-australia-2008',
#   'sport/india-in-england-2011',
#   'sport/india-in-england-2014',
#   'sport/india-women-s-cricket-team',
#   'sport/indiacricketteam',
#   'sport/indiainengland2002',
#   'sport/indiana-pacers',
#   'sport/indianapolis-colts',
#   'travel/india',
#   'travel/offers/india',
#   'tv-and-radio/indian-summers',
#   'tv-and-radio/series/indian-summers-episode-by-episode',
#   'us-news/indiana',
#   'us-news/indianapolis',
#   'weather/hyderabadindia',
#   'weather/india',
#   'weather/indianapolis',
#   'world/india',
#   'world/india-elections-2019',
#   'world/india-elections-2024',
#   'world/indian-elections-2009',
#   'world/indian-elections-2014',
#   'world/series/thenewindia',
#   'world/tsunami2004'],
#  'Indonesia': ['australia-news/series/indonesian-boys--australian-jails',
#   'food/indonesian-food-and-drink',
#   'travel/indonesia',
#   'weather/indonesia',
#   'world/indonesia',
#   'world/indonesia-tsunami',
#   'world/indonesia-tsunami-december-2018'],
#  'Iran': ['campaign/callout/callout-iran-poisonings',
#   'commentisfree/series/iran-one-year-on',
#   'commentisfree/series/remembering-iran-s-revolution',
#   'football/iran',
#   'travel/iran',
#   'us-news/mek',
#   'weather/iran',
#   'world/iran',
#   'world/iran-blog',
#   'world/iran-nuclear-deal',
#   'world/iranian-presidential-election-2009',
#   'world/iranian-presidential-election-2013',
#   'world/iranian-revolution',
#   'world/irans-nuclear-programme'],
#  'Iraq': ['books/series/writersoniraq',
#   'commentisfree/series/defeatiniraq',
#   'commentisfree/series/iraqfouryearson',
#   'commentisfree/series/the-iraq-invasion--20-years-on',
#   'football/iraq',
#   'theobserver/fiveyearson',
#   'travel/iraq',
#   'uk/iraq-war-inquiry',
#   'uk/series/iraq-war-inquiry-key-testimony',
#   'weather/iraq',
#   'world/british-hostages-in-iraq',
#   'world/iraq',
#   'world/iraq-war-logs',
#   'world/muntazer-al-zaidi-iraqi-shoe-thrower',
#   'world/series/iraq-10-years-100-viewpoints-arte-films',
#   'world/series/iraq-daily-briefing',
#   'world/series/iraq-legacy',
#   'world/series/iraq-war-10-years-on',
#   'world/series/iraq-war-20-years-on',
#   'world/series/seansmithiraq',
#   'world/series/voices-on-iraq'],
#  'Ireland': ['business/bank-of-ireland',
#   'business/ireland-bailout',
#   'business/ireland-business-blog-with-lisa-ocarroll',
#   'campaign/callout/callout-irelands-new-taoiseach',
#   'campaign/callout/callout-northern-ireland-trade-deal',
#   'culture/scotlandandirelandlistings',
#   'discover-ireland/discover-ireland',
#   'extra/scotland-northern-ireland-extra',
#   'football/footballinireland',
#   'football/northern-ireland-womens-football-team',
#   'football/northernireland',
#   'football/republic-of-ireland-women-s-football-team',
#   'football/republicofireland',
#   'healthcare-network/northern-ireland',
#   'my-ireland/my-ireland',
#   'origin-green-ireland-partner-zone/origin-green-ireland-partner-zone',
#   'politics/northern-ireland-elections-2011',
#   'social-care-network/northern-ireland',
#   'society/series/abortion-in-northern-ireland',
#   'sport/ireland-cricket-team',
#   'sport/ireland-rugby-league-team',
#   'sport/ireland-rugby-union-team',
#   'sport/ireland-women-s-cricket-team',
#   'sport/ireland-womens-rugby-union-team',
#   'stage/david-ireland',
#   'technology/series/guardian-technology-in-ireland',
#   'tourism-ireland/tourism-ireland',
#   'travel/ireland',
#   'travel/northern-ireland',
#   'travel/offers/ireland',
#   'travel/series/visit-britain-and-northern-ireland',
#   'uk/northernireland',
#   'unwindireland/acrossireland',
#   'unwindireland/unwindireland',
#   'weather/ireland',
#   'world/ireland',
#   'world/series/ireland-beyond-brexit'],
#  'Isle of Man': ['sport/isle-of-man-tt', 'uk/isle-of-man'],
#  'Israel': ['campaign/callout/callout-callout-israel',
#   'campaign/callout/callout-israel',
#   'campaign/callout/callout-israel-2023',
#   'campaign/callout/callout-israel-and-gaza',
#   'campaign/callout/callout-israel-and-gaza-embed',
#   'campaign/callout/callout-israel-oct-2023',
#   'campaign/callout/callout-israel2023',
#   'campaign/callout/callout-israelis',
#   'football/israel',
#   'sport/israel-folau',
#   'travel/israel',
#   'travel/offers/israel',
#   'weather/israel',
#   'world/israel',
#   'world/israel-hamas-war',
#   'world/israeli-elections-2009',
#   'world/series/israeli-election-from-gaza-to-jerusalem'],
#  'Italy': ['a-taste-of-piedmont-and-alpine-italy/a-taste-of-piedmont-and-alpine-italy',
#   'film/the-trip-to-italy',
#   'football/italy',
#   'football/italy-womens-football-team',
#   'music/series/sounds-of-europe-italy',
#   'peroni-made-in-italy/peroni-made-in-italy',
#   'sport/italy-olympic-team',
#   'sport/italy-rugby-league-team',
#   'sport/italy-rugby-union-team',
#   'sport/italy-womens-rugby-union-team',
#   'travel/italy',
#   'travel/offers/italy',
#   'travel/series/inside-italy',
#   'weather/italy',
#   'world/brothers-of-italy',
#   'world/central-italy-earthquake',
#   'world/italy',
#   'world/series/italy-votes'],
#  'Jamaica': ['books/jamaica-kincaid',
#   'football/jamaica',
#   'football/jamaica-womens-football-team',
#   'sport/jamaica-olympic-team',
#   'travel/jamaica',
#   'weather/jamaica',
#   'world/jamaica'],
#  'Japan': ['business/bank-of-japan',
#   'discover-japan/discover-japan',
#   'food/japanese',
#   'football/japan',
#   'football/japan-womens-football-team',
#   'football/series/japanese-language-football',
#   'music/japanese-breakfast',
#   'music/series/turningjapanese',
#   'sport/japan-olympic-team',
#   'sport/japanrugby',
#   'travel/japan',
#   'travel/offers/japan',
#   'travel/series/learn-japanese',
#   'weather/japan',
#   'world/japan',
#   'world/japan-earthquake-and-tsunami',
#   'world/series/japan-disaster-one-year-on',
#   'world/series/the-guardian-in-japanese'],
#  'Jersey': ['film/jersey-boys',
#   'film/jersey-girl',
#   'sport/new-jersey-devils',
#   'uk-news/new-jersey',
#   'uk/jersey',
#   'us-news/new-york-and-new-jersey-bombings',
#   'weather/jersey'],
#  'Jordan': ['books/jordan-peterson',
#   'campaign/callout/callout-jim-jordan-speakership',
#   'discover-jordan/discover-jordan',
#   'film/jordan-peele',
#   'film/michael-b-jordan',
#   'film/neil-jordan',
#   'football/jordan',
#   'football/jordan-pickford',
#   'sport/jordan-spieth',
#   'sport/michael-jordan',
#   'stage/jordan-brookes',
#   'travel/jordan',
#   'travel/offers/jordan',
#   'travel/petra',
#   'us-news/jim-jordan',
#   'us-news/jordan-neely',
#   'weather/jordan',
#   'world/jordan'],
#  'Kazakhstan': ['football/kazakhstan',
#   'travel/kazakhstan',
#   'weather/kazakhstan',
#   'world/kazakhstan'],
#  'Kenya': ['football/kenya',
#   'lifeandstyle/series/running-with-the-kenyans',
#   'sport/kenya-cricket-team',
#   'travel/kenya',
#   'travel/offers/kenya',
#   'weather/kenya',
#   'world/kenya'],
#  'Kiribati': ['global-development/series/voices-from-kiribati',
#   'travel/kiribati',
#   'weather/kiribati',
#   'world/kiribati'],
#  'Kosovo': ['football/kosovo', 'travel/kosovo', 'world/kosovo'],
#  'Kuwait': ['travel/kuwait',
#   'weather/kuwait',
#   'weather/kuwaitcity',
#   'world/kuwait'],
#  'Kyrgyzstan': ['travel/kyrgyzstan', 'weather/kyrgyzstan', 'world/kyrgyzstan'],
#  'Laos': ['travel/laos', 'weather/laos', 'world/laos'],
#  'Latvia': ['football/latvia',
#   'travel/latvia',
#   'travel/offers/latvia',
#   'weather/latvia',
#   'world/latvia'],
#  'Lebanon': ['film/lebanon',
#   'travel/lebanon',
#   'weather/lebanon',
#   'world/lebanon'],
#  'Lesotho': ['sport/lesotho-olympic-team',
#   'travel/lesotho',
#   'weather/lesotho',
#   'world/lesotho'],
#  'Liberia': ['weather/liberia', 'world/liberia'],
#  'Libya': ['campaign/callout/callout-libya-flooding',
#   'football/libya',
#   'travel/libya',
#   'travel/offers/libya',
#   'weather/libya',
#   'world/libya',
#   'world/libya-flood-2023'],
#  'Liechtenstein': ['football/liechtenstein',
#   'travel/liechtenstein',
#   'weather/liechtenstein',
#   'world/liechtenstein'],
#  'Lithuania': ['football/lithuania',
#   'travel/lithuania',
#   'travel/offers/lithuania',
#   'weather/lithuania',
#   'world/lithuania'],
#  'Luxembourg': ['football/luxembourg',
#   'travel/luxembourg',
#   'weather/luxembourg',
#   'weather/luxembourgluxembourg',
#   'world/luxembourg'],
#  'Macao': [],
#  'Madagascar': ['film/penguins-of-madagascar',
#   'football/madagascar-football-team',
#   'travel/madagascar',
#   'weather/madagascar',
#   'world/madagascar'],
#  'Malawi': ['football/malawi',
#   'travel/malawi',
#   'weather/malawi',
#   'world/malawi'],
#  'Malaysia': ['food/malaysian-food-and-drink',
#   'news/malaysia-airlines-flight-mh17',
#   'travel/malaysia',
#   'travel/petronastowers',
#   'weather/malaysia',
#   'world/malaysia',
#   'world/malaysia-airlines-flight-mh370'],
#  'Maldives': ['travel/maldives', 'world/maldives'],
#  'Mali': ['australia-news/peter-malinauskas',
#   'film/terrence-malick',
#   'football/mali',
#   'music/zayn-malik',
#   'politics/shahid-malik',
#   'stage/russellmaliphant',
#   'travel/mali',
#   'weather/mali',
#   'world/mali',
#   'world/nouri-al-maliki'],
#  'Malta': ['football/malta',
#   'travel/malta',
#   'travel/offers/malta',
#   'weather/malta',
#   'world/malta'],
#  'Marshall Islands': ['travel/marshallislands',
#   'weather/marshallislands',
#   'world/marshall-islands'],
#  'Martinique': ['travel/martinique'],
#  'Mauritania': ['football/mauritania-football-team',
#   'travel/mauritania',
#   'weather/mauritania',
#   'world/mauritania'],
#  'Mauritius': ['ba-guide-to-mauritius/ba-guide-to-mauritius',
#   'the-report/mauritius',
#   'travel/mauritius',
#   'weather/mauritius',
#   'world/mauritius'],
#  'Mayotte': ['travel/mayotte'],
#  'Mexico': ['cities/series/mexico-city-live',
#   'football/mexico',
#   'football/series/mexico-north-americas-team',
#   'the-report/mexico',
#   'travel/mexico',
#   'travel/mexicocity',
#   'travel/new-mexico',
#   'travel/series/road-trips-usa-texas-and-new-mexico',
#   'us-news/newmexico',
#   'us-news/us-mexico-border',
#   'weather/mexico',
#   'weather/mexicocity',
#   'world/mexico',
#   'world/series/hugs-and-bullets--the-battle-to-pacify-mexico',
#   'world/series/mexico-drug-war',
#   'world/series/mexico-s-war-on-drugs-5-years-on'],
#  'Micronesia (country)': [],
#  'Moldova': ['football/moldova',
#   'travel/moldova',
#   'weather/moldova',
#   'world/moldova'],
#  'Monaco': ['film/grace-of-monaco',
#   'football/monaco',
#   'travel/monaco',
#   'weather/monaco',
#   'weather/principalityofmonaco',
#   'world/monaco'],
#  'Mongolia': ['travel/mongolia',
#   'travel/series/londonmongoliarally',
#   'weather/mongolia',
#   'world/mongolia'],
#  'Montenegro': ['football/montenegro',
#   'travel/montenegro',
#   'travel/serbiaandmontenegro',
#   'weather/montenegro',
#   'weather/serbiaandmontenegro',
#   'world/montenegro'],
#  'Montserrat': ['travel/montserrat', 'world/montserrat'],
#  'Morocco': ['campaign/callout/callout-morocco-earthquake',
#   'football/morocco',
#   'football/morocco-women-s-football-team',
#   'travel/morocco',
#   'travel/offers/morocco',
#   'travel/series/moroccodesertadventure',
#   'weather/morocco',
#   'world/morocco',
#   'world/morocco-earthquake-2023'],
#  'Mozambique': ['football/mozambique',
#   'travel/mozambique',
#   'weather/mozambique',
#   'world/mozambique'],
#  'Myanmar': ['global-development/series/myanmar-three-years-on-from-the-coup',
#   'global-development/series/reporting-myanmar',
#   'travel/myanmar',
#   'weather/myanmar',
#   'world/myanmar',
#   'world/myanmar-coup'],
#  'Namibia': ['football/namibia-football-team',
#   'sport/namibia-rugby-union-team',
#   'travel/namibia',
#   'weather/namibia',
#   'world/namibia'],
#  'Nauru': ['australia-news/nauru-files',
#   'news/series/nauru-files',
#   'travel/nauru',
#   'weather/nauru',
#   'world/nauru'],
#  'Nepal': ['global-development/nepal-earthquake-one-year-on',
#   'travel/nepal',
#   'weather/nepal',
#   'world/nepal',
#   'world/nepal-earthquake-2015'],
#  'Netherlands': ['campaign/callout/callout-netherlands',
#   'campaign/callout/series-dining-across-the-divide-the-netherlands',
#   'football/holland',
#   'football/netherlands-womens-football-team',
#   'music/series/sounds-of-europe-netherlands',
#   'sport/netherlands-cricket-team',
#   'travel/netherlands',
#   'travel/offers/netherlands',
#   'weather/netherlands',
#   'world/netherlands'],
#  'New Caledonia': ['travel/newcaledonia',
#   'weather/newcaledonia',
#   'world/new-caledonia'],
#  'New Zealand': ['campaign/callout/callout-new-zealand-birds-and-cats',
#   'football/new-zealand-womens-football-team',
#   'football/newzealand',
#   'sport/england-in-new-zealand-2012-13',
#   'sport/england-in-new-zealand-2014',
#   'sport/england-in-new-zealand-2018',
#   'sport/england-in-new-zealand-2019-20',
#   'sport/england-in-new-zealand-2023',
#   'sport/england-v-new-zealand-2013',
#   'sport/england-v-new-zealand-2015',
#   'sport/england-v-new-zealand-2021',
#   'sport/england-v-new-zealand-2022',
#   'sport/englandinnewzealand200102',
#   'sport/englandinnewzealand200708',
#   'sport/englandvnewzealand2008',
#   'sport/new-zealand-cricket-team',
#   'sport/new-zealand-netball-team',
#   'sport/new-zealand-rugby-league',
#   'sport/new-zealand-rugby-union-team',
#   'sport/new-zealand-warriors',
#   'sport/new-zealand-women-s-cricket-team',
#   'sport/new-zealand-women-s-rugby-union-team',
#   'sport/newzealandinengland2004',
#   'tracking/commissioningdesk/new-zealand',
# ...
#  'North Korea': ['football/north-korea',
#   'travel/northkorea',
#   'weather/northkorea',
#   'world/north-korea',
#   'world/series/north-korea-at-70',
#   'world/series/north-korea-network'],
#  'North Macedonia': ['football/macedonia',
#   'travel/macedonia',
#   'weather/macedonia',
#   'world/north-macedonia'],
#  'Northern Mariana Islands': [],
#  'Norway': ['football/norway',
#   'football/norway-womens-football-team',
#   'hurtigruten-discover-norway/hurtigruten-discover-norway',
#   'travel/norway',
#   'travel/offers/norway',
#   'weather/norway',
#   'world/norway'],
#  'Oman': ['travel/oman', 'weather/oman', 'world/oman'],
#  'Pakistan': ['commentisfree/series/voicesfrompakistan',
#   'sport/england-v-pakistan-2010',
#   'sport/england-v-pakistan-2016',
#   'sport/england-v-pakistan-2018',
#   'sport/england-v-pakistan-2020',
#   'sport/englandinpakistan200506',
#   'sport/pakistan-cricket-betting-scandal',
#   'sport/pakistan-england-2011-12',
#   'sport/pakistan-v-england-2015',
#   'sport/pakistan-v-england-2022',
#   'sport/pakistan-women-s-cricket-team',
#   'sport/pakistan2006',
#   'sport/pakistancricketteam',
#   'sport/pakistaninengland2001',
#   'travel/pakistan',
#   'weather/hyderabadpakistan',
#   'weather/pakistan',
#   'world/pakistan',
#   'world/pakistan-flood',
#   'world/pakistans-blasphemy-laws',
#   'world/series/indus-river-journey-pakistan-after-the-floods'],
#  'Palau': ['travel/palau', 'weather/palau', 'world/palau'],
#  'Palestine': ['campaign/callout/callout-armistice-day-pro-palestine-march',
#   'campaign/callout/callout-callout-armistice-day-pro-palestine-march',
#   'football/palestine-football-team',
#   'travel/palestine',
#   'world/palestine-papers',
#   'world/series/palestine-papers-documents'],
#  'Panama': ['football/panama',
#   'football/panama-women-s-football-team',
#   'news/series/panama-papers',
#   'travel/panama',
#   'travel/panamacanal',
#   'weather/panama',
#   'weather/panamapanama',
#   'world/panama',
#   'world/panama-papers'],
#  'Papua New Guinea': ['sport/papua-new-guinea-rugby-league-team',
#   'travel/papuanewguinea',
#   'weather/papuanewguinea',
#   'world/papua-new-guinea'],
#  'Paraguay': ['football/paraguay',
#   'travel/paraguay',
#   'weather/paraguay',
#   'world/paraguay'],
#  'Peru': ['environment/series/climate-journey-ecuador-peru',
#   'football/peru',
#   'football/perugia',
#   'travel/machupicchu',
#   'travel/offers/peru',
#   'travel/peru',
#   'weather/peru',
#   'weather/perugia',
#   'world/peru'],
#  'Philippines': ['campaign/callout/callout-marcos-and-the-philippines',
#   'football/philippines-womens-football-team',
#   'travel/philippines',
#   'weather/philippines',
#   'world/philippines'],
#  'Pitcairn': ['travel/pitcairn'],
#  'Poland': ['campaign/callout/callout-poland-election',
#   'football/poland',
#   'music/series/sounds-of-europe-poland',
#   'travel/offers/poland',
#   'travel/poland',
#   'weather/poland',
#   'world/poland',
#   'world/series/new-europe-poland'],
#  'Portugal': ['campaign/callout/callout-50th-anniversary-carnation-revolution-portugal',
#   'football/portugal',
#   'football/portugal-women-s-football-team',
#   'sport/portugal-rugby-union-team',
#   'travel/offers/portugal',
#   'travel/portugal',
#   'weather/portugal',
#   'world/portugal'],
#  'Puerto Rico': ['travel/puertorico',
#   'us-news/series/the-forgotten-americans-puerto-rico-after-maria',
#   'weather/puertorico',
#   'world/puerto-rico'],
#  'Qatar': ['football/qatar',
#   'news/series/qatar-beyond-the-football',
#   'qatar-uk-2013/qatar-uk-2013',
#   'travel/qatar',
#   'weather/qatar',
#   'world/qatar'],
#  'Reunion': ['travel/reunion', 'world/reunion'],
#  'Romania': ['football/romania',
#   'sport/romaniarugbyunionteam',
#   'travel/offers/romania',
#   'travel/romania',
#   'weather/romania',
#   'world/romania'],
#  'Russia': ['campaign/callout/callout-mood-in-russia',
#   'cities/series/the-other-russia',
#   'commentisfree/series/in-the-shadow-of-putin-s-russia',
#   'film/from-russia-with-love',
#   'football/russia',
#   'football/russia-womens-football-team',
#   'russian-standard-vodka/russian-standard-vodka',
#   'sport/russia-doping-scandal',
#   'sport/russia-olympic-team',
#   'sport/russia-rugby-union-team',
#   'travel/offers/russia',
#   'travel/russia',
#   'travel/series/learn-russian',
#   'us-news/trump-russia-inquiry',
#   'weather/russia',
#   'world/russia',
#   'world/russian-presidential-election-2012',
#   'world/russian-presidential-election-2018',
#   'world/russian-presidential-election-2024',
#   'world/russian-revolution',
#   'world/russian-spy-ring',
#   'world/series/russia-in-africa',
#   'world/series/russia-ukraine-war-at-a-glance',
#   'world/series/russian-asset-tracker',
#   'world/series/the-guardian-in-russian'],
#  'Rwanda': ['actionaid-feeling/rwanda-blog',
#   'film/hotel-rwanda',
#   'global-development/series/rwanda-20-years-after-the-genocide',
#   'travel/rwanda',
#   'weather/rwanda',
#   'world/rwanda'],
#  'Saint Barthelemy': [],
#  'Saint Helena': [],
#  'Saint Kitts and Nevis': ['travel/saintkittsandnevis'],
#  'Saint Lucia': [],
#  'Saint Martin (French part)': [],
#  'Saint Pierre and Miquelon': [],
#  'Saint Vincent and the Grenadines': ['travel/saintvincentandthegrenadines',
#   'weather/saintvincentandthegrenadines'],
#  'Samoa': ['sport/samoa-rugby-union-team',
#   'sport/samoarugbyleagueteam',
#   'travel/americansamoa',
#   'travel/samoa',
#   'weather/samoa',
#   'world/samoa'],
#  'San Marino': ['football/sanmarino',
#   'travel/sanmarino',
#   'weather/sanmarino',
#   'weather/sanmarinorep',
#   'world/san-marino'],
#  'Sao Tome and Principe': ['travel/sao-tome-and-principe',
#   'weather/saotomeandprincipe',
#   'world/sao-tome-and-principe'],
#  'Saudi Arabia': ['football/saudiarabia',
#   'sport/saudi-arabia-and-sport',
#   'travel/saudiarabia',
#   'weather/saudiarabia',
#   'world/saudi-arabia-drone-attacks',
#   'world/saudiarabia',
#   'world/series/inside-saudi-arabia'],
#  'Senegal': ['football/senegal',
#   'travel/senegal',
#   'weather/senegal',
#   'world/senegal'],
#  'Serbia': ['football/serbia',
#   'travel/serbia',
#   'travel/serbiaandmontenegro',
#   'weather/serbiaandmontenegro',
#   'world/serbia'],
#  'Seychelles': ['the-report/seychelles',
#   'travel/seychelles',
#   'weather/seychelles',
#   'world/seychelles'],
#  'Sierra Leone': ['football/sierra-leone',
#   'law/special-court-for-sierra-leone',
#   'travel/sierraleone',
#   'weather/sierraleone',
#   'world/sierraleone'],
#  'Singapore': ['first-stop-singapore/first-stop-singapore',
#   'media-network/activate-singapore',
#   'singapore-invites/singapore-invites',
#   'travel/series/singapore-city-guide',
#   'travel/singapore',
#   'visit-singapore/visit-singapore',
#   'weather/republicofsingapore',
#   'weather/singapore',
#   'world/singapore',
#   'world/singapore-changi-airport',
#   'your-singapore/your-singapore'],
#  'Sint Maarten (Dutch part)': [],
#  'Slovakia': ['football/slovakia',
#   'travel/offers/slovakia',
#   'travel/slovakia',
#   'weather/slovakia',
#   'world/slovakia'],
#  'Slovenia': ['football/slovenia',
#   'travel/slovenia',
#   'weather/slovenia',
#   'world/slovenia'],
#  'Solomon Islands': ['travel/solomonislands',
#   'weather/solomonislands',
#   'world/solomonislands'],
#  'Somalia': ['global-development/series/crisis-somalia',
#   'global-development/series/the-politics-of-aid-in-somalia',
#   'travel/somalia',
#   'weather/somalia',
#   'world/london-conference-on-the-future-of-somalia',
#   'world/somalia'],
#  'South Africa': ['cities/series/south-african-cities-week',
#   'culture/series/south-africa-today',
#   'discover-south-africa-2015/discover-south-africa-2015',
#   'discover-south-africa-2016/discover-south-africa-2016',
#   'discover-south-africa-competition/discover-south-africa-competition',
#   'food/south-african-food-and-drink',
#   'football/south-africa-womens-football-team',
#   'football/southafrica',
#   'my-mission-south-africa/my-mission-south-africa',
#   'my-mission-south-africa/series/celebrity-blogs',
#   'sport/australia-in-south-africa-2014',
#   'sport/england-in-south-africa-2009-2010',
#   'sport/england-in-south-africa-2015-2016',
#   'sport/england-in-south-africa-2019-20',
#   'sport/england-in-south-africa-2020-21',
#   'sport/england-v-south-africa-2012',
#   'sport/england-v-south-africa-2017',
#   'sport/england-v-south-africa-2022',
#   'sport/englandinsouthafrica200405',
#   'sport/englandvsouthafrica2008',
#   'sport/south-africa-cricket-team',
#   'sport/south-africa-in-england-2012',
#   'sport/south-africa-rugby-team',
#   'sport/south-africa-women-s-cricket-team',
#   'sport/southafricainengland2003',
#   'travel/series/alternative-south-africa',
#   'travel/southafrica',
#   'weather/southafrica',
#   'world/southafrica'],
#  'South Georgia and the South Sandwich Islands': [],
#  'South Korea': ['campaign/callout/aus-callout-teachers-in-south-korea',
#   'campaign/callout/callout-teachers-in-south-korea',
#   'football/south-korea-womens-football-team',
#   'football/southkorea',
#   'sport/south-korea-olympic-team',
#   'travel/southkorea',
#   'weather/southkorea',
#   'world/south-korea',
#   'world/south-korea-ferry-disaster'],
#  'South Sudan': ['global-development/series/south-sudan-one-year-on',
#   'world/south-sudan'],
#  'Spain': ['campaign/callout/callout-dining-across-the-divide-spain',
#   'campaign/callout/series-dining-across-the-divide-spain',
#   'football/spain',
#   'football/spain-womens-football-team',
#   'music/series/sounds-of-europe-spain',
#   'travel/offers/spain',
#   'travel/spain',
#   'weather/cordobaspain',
#   'weather/portofspain',
#   'weather/spain',
#   'world/barcelona-van-attack',
#   'world/series/barca-loners-will-breakaway-catalonia-fracture-spain',
#   'world/series/new-europe-spain',
#   'world/spain'],
#  'Sri Lanka': ['food/sri-lankan-food-and-drink',
#   'sport/england-in-sri-lanka-2012',
#   'sport/england-in-sri-lanka-2014-15',
#   'sport/england-in-sri-lanka-2018',
#   'sport/england-in-sri-lanka-2020-21',
#   'sport/england-v-sri-lanka-2016',
#   'sport/englandcrickettourofsrilanka2001',
#   'sport/englandinsrilanka200304',
#   'sport/englandinsrilanka200708',
#   'sport/sri-lanka-cricket-team',
#   'sport/sri-lanka-in-england-2011',
#   'sport/sri-lanka-in-england-2014',
#   'sport/sri-lanka-women-s-cricket-team',
#   'sport/srilankainengland2002',
#   'the-report/sri-lanka',
#   'travel/offers/srilanka',
#   'travel/srilanka',
#   'weather/srilanka',
#   'world/sri-lanka-attacks',
#   'world/sri-lanka-cricket-team-attack',
#   'world/srilanka'],
#  'Sudan': ['campaign/callout/callout-brits-in-sudan',
#   'campaign/callout/callout-sudan-clashes',
#   'football/sudan',
#   'global-development/series/south-sudan-one-year-on',
#   'travel/sudan',
#   'weather/portsudan',
#   'weather/sudan',
#   'world/series/the-sudans-after-the-divide',
#   'world/series/the-sudans-takeover',
#   'world/south-sudan',
#   'world/sudan'],
#  'Suriname': ['travel/surinam', 'world/suriname'],
#  'Sweden': ['football/sweden',
#   'football/sweden-womens-football-team',
#   'travel/offers/sweden',
#   'travel/series/visit-sweden',
#   'travel/sweden',
#   'try-swedish/try-swedish',
#   'weather/sweden',
#   'world/sweden'],
#  'Switzerland': ['football/switzerland',
#   'football/switzerland-womens-football-team',
#   'panoramic-switzerland/panoramic-switzerland',
#   'switzerland-winter-holidays/switzerland-winter-holidays',
#   'travel/offers/switzerland',
#   'travel/switzerland',
#   'visit-switzerland/visit-switzerland',
#   'weather/switzerland',
#   'world/switzerland'],
#  'Syria': ['campaign/callout/callout-turkey-and-syria-six-months-on',
#   'campaign/callout/turkey-and-syria-earthquake',
#   'commentisfree/series/syria-the-options',
#   'football/syria-football-team',
#   'travel/syria',
#   'weather/syria',
#   'world/series/syria-refugee-crisis',
#   'world/series/syria-the-endgame',
#   'world/syria',
#   'world/turkey-syria-earthquake-2023'],
#  'Taiwan': ['travel/taiwan', 'weather/taiwan', 'world/taiwan'],
#  'Tajikistan': ['travel/tajikistan', 'weather/tajikistan', 'world/tajikistan'],
#  'Tanzania': ['football/tanzania-football-team',
#   'the-report/the-report-tanzania',
#   'travel/tanzania',
#   'weather/tanzania',
#   'world/tanzania'],
#  'Thailand': ['football/thailand-womens-football-team',
#   'news/thailand-cave-rescue',
#   'travel/thailand',
#   'weather/thailand',
#   'world/thailand'],
#  'Togo': ['football/togo', 'travel/togo', 'weather/togo', 'world/togo'],
#  'Tokelau': ['travel/tokelau'],
#  'Tonga': ['sport/tonga-rugby-union-team',
#   'sport/tongarugbyleagueteam',
#   'travel/tonga',
#   'weather/tonga',
#   'world/tonga',
#   'world/tonga-volcano'],
#  'Trinidad and Tobago': ['sport/trinidad-and-tobago',
#   'the-report/trinidad-and-tobago',
#   'travel/trinidadandtobago',
#   'weather/trinidadandtobago',
#   'world/trinidad-and-tobago'],
#  'Tunisia': ['books/series/after-tunisia-arabic-writers-reflect',
#   'football/tunisia',
#   'travel/tunisia',
#   'weather/tunisia',
#   'world/tunisia',
#   'world/tunisia-attack-2015',
#   'world/tunisian-elections-2011'],
#  'Turkey': ['campaign/callout/callout-turkey-and-syria-six-months-on',
#   'campaign/callout/callout-turkey-election',
#   'campaign/callout/turkey-and-syria-earthquake',
#   'food/turkey',
#   'football/turkey',
#   'travel/offers/turkey',
#   'travel/turkey',
#   'weather/turkey',
#   'world/series/turkey-jailed-journalists',
#   'world/turkey',
#   'world/turkey-coup-attempt',
#   'world/turkey-syria-earthquake-2023',
#   'world/turkeyquakes'],
#  'Turkmenistan': ['travel/turkmenistan',
#   'weather/turkmenistan',
#   'world/turkmenistan'],
#  'Turks and Caicos Islands': ['world/turks-and-caicos-islands'],
#  'Tuvalu': ['travel/tuvalu', 'weather/tuvalu', 'world/tuvalu'],
#  'Uganda': ['football/uganda-football-team',
#   'travel/uganda',
#   'weather/uganda',
#   'world/uganda'],
#  'Ukraine': ['campaign/callout/callout-homes-for-ukraine',
#   'campaign/callout/callout-ukraine-2023',
#   'campaign/callout/callout-ukraine-general',
#   'campaign/callout/callout-ukraine-general-june-23',
#   'campaign/callout/uk-callout-ukraine-euro-2024',
#   'commentisfree/series/war-in-ukraine-two-years-in',
#   'football/ukraine',
#   'travel/ukraine',
#   'weather/ukraine',
#   'world/series/a-year-of-war-in-ukraine',
#   'world/series/russia-ukraine-war-at-a-glance',
#   'world/series/ukraine-live',
#   'world/ukraine',
#   'world/ukraine-international-airlines-flight-752'],
#  'United Arab Emirates': ['football/unitedarabemirates',
#   'sport/united-arab-emirates-cricket-team',
#   'travel/unitedarabemirates',
#   'weather/unitedarabemirates',
#   'world/united-arab-emirates'],
#  'United Kingdom': ['film/a-united-kingdom',
#   'travel/offers/unitedkingdom',
#   'travel/uk',
#   'weather/uk'],
#  'United States': ['sport/usada',
#   'travel/offers/unitedstates',
#   'travel/usa',
#   'us-news/series/united-states-of-inequality',
#   'us-news/series/united-states-of-plastic',
#   'visit-the-usa-the-united-states-of-adventure/visit-the-usa-the-united-states-of-adventure',
#   'weather/usa'],
#  'United States Virgin Islands': [],
#  'Uruguay': ['football/uruguay',
#   'sport/uruguay-rugby-union-team',
#   'travel/offers/uruguay',
#   'travel/uruguay',
#   'weather/uruguay',
#   'world/uruguay'],
#  'Uzbekistan': ['football/uzbekistan',
#   'travel/offers/uzbekistan',
#   'travel/uzbekistan',
#   'weather/uzbekistan',
#   'world/uzbekistan'],
#  'Vanuatu': ['travel/vanuatu',
#   'weather/vanuatu',
#   'world/series/vanuatu-citizenship-for-sale',
#   'world/vanuatu'],
#  'Vatican': ['travel/vaticancitystate', 'world/vatican'],
#  'Venezuela': ['football/venezuela',
#   'travel/venezuela',
#   'weather/barcelonavenezuela',
#   'weather/valenciavenezuela',
#   'weather/venezuela',
#   'world/series/venezuela-children-of-the-crisis',
#   'world/venezuela'],
#  'Vietnam': ['food/vietnamese-food-and-drink',
#   'football/vietnam-women-s-football-team',
#   'travel/offers/vietnam',
#   'travel/vietnam',
#   'weather/vietnam',
#   'world/vietnam',
#   'world/vietnam-war'],
#  'Wallis and Futuna': [],
#  'Western Sahara': ['travel/westernsahara', 'world/western-sahara'],
#  'Yemen': ['campaign/callout/callout-yemen-aid-workers',
#   'travel/yemen',
#   'weather/yemen',
#   'world/series/yemen-at-war',
#   'world/yemen'],
#  'Zambia': ['football/zambia',
#   'football/zambia-womens-football-team',
#   'travel/offers/zambia',
#   'travel/zambia',
#   'weather/zambia',
#   'world/zambia'],
#  'Zimbabwe': ['football/zimbabwe',
#   'sport/zimbabwe-cricket-team',
#   'sport/zimbabweinengland2003',
#   'travel/zimbabwe',
#   'weather/zimbabwe',
#   'world/zimbabwe']}
