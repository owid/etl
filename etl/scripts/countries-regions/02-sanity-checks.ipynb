# %% [markdown]
# ## Did we store any non-standard ISO level 2/3 area codes?

# %%
from init import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_feather("intermediate/01-countries-from-mysql.feather")

# %%
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>owid_name</th>
#       <th>iso_alpha2</th>
#       <th>iso_alpha3</th>
#       <th>imf_code</th>
#       <th>cow_letter</th>
#       <th>cow_code</th>
#       <th>unctad_code</th>
#       <th>marc_code</th>
#       <th>ncd_code</th>
#       <th>kansas_code</th>
#       <th>penn_code</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>562</td>
#       <td>Afghanistan</td>
#       <td>AF</td>
#       <td>AFG</td>
#       <td>512.0</td>
#       <td>AFG</td>
#       <td>700.0</td>
#       <td>AFG</td>
#       <td>AF</td>
# ...

# %% [markdown]
# ### What entities do not have iso alpha 2 codes?

# %%
df[df["iso_alpha2"].isnull()]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>owid_name</th>
#       <th>iso_alpha2</th>
#       <th>iso_alpha3</th>
#       <th>imf_code</th>
#       <th>cow_letter</th>
#       <th>cow_code</th>
#       <th>unctad_code</th>
#       <th>marc_code</th>
#       <th>ncd_code</th>
#       <th>kansas_code</th>
#       <th>penn_code</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15</th>
#       <td>822</td>
#       <td>Austria-Hungary</td>
#       <td>None</td>
#       <td>None</td>
#       <td>NaN</td>
#       <td>AUH</td>
#       <td>300.0</td>
#       <td>None</td>
#       <td>None</td>
# ...

# %% [markdown]
# 💡 This looks like most of these are historical entities. World is the main entitiy that we might want to have that does not have a ISO Alpha 2 code
