# %% [markdown]
# ## Update metadata
#
# Update `wdi.meta.yml` from WDI metadata file. This notebook is intended to be run manually and all changes to the YAML file need to be verified.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from owid.catalog import Dataset
from etl.paths import DATA_DIR
import os

version = os.getcwd().rsplit('/', 1)[1]
ds_meadow = Dataset(DATA_DIR / 'meadow/worldbank_wdi' / version / 'wdi')
tb = ds_meadow['wdi']
indicator_codes = [tb[col].m.title for col in tb.columns]

# %%
# %load_ext autoreload
# %autoreload 2

from wdi import load_variable_metadata

df_vars = load_variable_metadata(indicator_codes)
df_vars.head()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2025-01-28 19:33:48 [info     ] wdi.missing_metadata           n_indicators=1
# 2025-01-28 19:33:48 [info     ] wdi.fetch_metadata             indicator_code=VA.STD.ERR
#                                                   topic  \
# indicator_code
# ag_con_fert_pt_zs  Environment: Agricultural production
# ag_con_fert_zs     Environment: Agricultural production
# ag_lnd_agri_k2                    Environment: Land use
# ag_lnd_agri_zs                    Environment: Land use
# ag_lnd_arbl_ha                    Environment: Land use
#
#                                                       indicator_name  \
# indicator_code
# ag_con_fert_pt_zs  Fertilizer consumption (% of fertilizer produc...
# ag_con_fert_zs     Fertilizer consumption (kilograms per hectare ...
# ag_lnd_agri_k2                            Agricultural land (sq. km)
# ag_lnd_agri_zs                    Agricultural land (% of land area)
# ag_lnd_arbl_ha                                Arable land (hectares)
#
#                   short_definition  \
# indicator_code
# ag_con_fert_pt_zs              NaN
# ag_con_fert_zs                 NaN
# ag_lnd_agri_k2                 NaN
# ag_lnd_agri_zs                 NaN
# ag_lnd_arbl_ha                 NaN
#
#                                                      long_definition  \
# indicator_code
# ag_con_fert_pt_zs  Fertilizer consumption measures the quantity o...
# ag_con_fert_zs     Fertilizer consumption measures the quantity o...
# ag_lnd_agri_k2     Agricultural land refers to the share of land ...
# ag_lnd_agri_zs     Agricultural land refers to the share of land ...
# ag_lnd_arbl_ha     Arable land (in hectares) includes land define...
#
#                   unit_of_measure periodicity base_period  \
# indicator_code
# ag_con_fert_pt_zs             NaN      Annual         NaN
# ag_con_fert_zs                NaN      Annual         NaN
# ag_lnd_agri_k2                NaN      Annual         NaN
# ag_lnd_agri_zs                NaN      Annual         NaN
# ag_lnd_arbl_ha                NaN      Annual         NaN
#
#                                                          other_notes  \
# indicator_code
# ag_con_fert_pt_zs  The world and regional aggregate series do not...
# ag_con_fert_zs     The world and regional aggregate series do not...
# ag_lnd_agri_k2     Areas of former states are included in the suc...
# ag_lnd_agri_zs     Areas of former states are included in the suc...
# ag_lnd_arbl_ha                                                   NaN
#
#                   aggregation_method  \
# indicator_code
# ag_con_fert_pt_zs   Weighted average
# ag_con_fert_zs      Weighted average
# ag_lnd_agri_k2                   Sum
# ag_lnd_agri_zs      Weighted average
# ag_lnd_arbl_ha                   NaN
#
#                                           limitations_and_exceptions  \
# indicator_code
# ag_con_fert_pt_zs  The FAO has revised the time series for fertil...
# ag_con_fert_zs     The FAO has revised the time series for fertil...
# ag_lnd_agri_k2     The data are collected by the Food and Agricul...
# ag_lnd_agri_zs     The data are collected by the Food and Agricul...
# ag_lnd_arbl_ha     The Food and Agriculture Organization (FAO) tr...
#
#                   notes_from_original_source general_comments  \
# indicator_code
# ag_con_fert_pt_zs                        NaN              NaN
# ag_con_fert_zs                           NaN              NaN
# ag_lnd_agri_k2                           NaN              NaN
# ag_lnd_agri_zs                           NaN              NaN
# ag_lnd_arbl_ha                           NaN              NaN
#
#                                                               source  \
# indicator_code
# ag_con_fert_pt_zs  Food and Agriculture Organization, electronic ...
# ag_con_fert_zs     Food and Agriculture Organization, electronic ...
# ag_lnd_agri_k2     Food and Agriculture Organization, electronic ...
# ag_lnd_agri_zs     Food and Agriculture Organization, electronic ...
# ag_lnd_arbl_ha     Food and Agriculture Organization, electronic ...
#
#                                  statistical_concept_and_methodology  \
# indicator_code
# ag_con_fert_pt_zs  Fertilizer consumption measures the quantity o...
# ag_con_fert_zs     Fertilizer consumption measures the quantity o...
# ag_lnd_agri_k2     Agricultural land constitutes only a part of a...
# ag_lnd_agri_zs     Agriculture is still a major sector in many ec...
# ag_lnd_arbl_ha     Temporary fallow land refers to land left fall...
#
#                                                development_relevance  \
# indicator_code
# ag_con_fert_pt_zs  Factors such as the green revolution, has led ...
# ag_con_fert_zs     Factors such as the green revolution, has led ...
# ag_lnd_agri_k2     Agricultural land covers more than one-third o...
# ag_lnd_agri_zs     Agricultural land covers more than one-third o...
# ag_lnd_arbl_ha     Agricultural land covers more than one-third o...
#
#                   related_source_links other_web_links related_indicators  \
# indicator_code
# ag_con_fert_pt_zs                  NaN             NaN                NaN
# ag_con_fert_zs                     NaN             NaN                NaN
# ag_lnd_agri_k2                     NaN             NaN                NaN
# ag_lnd_agri_zs                     NaN             NaN                NaN
# ag_lnd_arbl_ha                     NaN             NaN                NaN
#
#                   license_type unit
# indicator_code
# ag_con_fert_pt_zs    CC BY-4.0  NaN
# ag_con_fert_zs       CC BY-4.0  NaN
# ag_lnd_agri_k2       CC BY-4.0  NaN
# ag_lnd_agri_zs       CC BY-4.0  NaN
# ag_lnd_arbl_ha       CC BY-4.0  NaN

# %% [markdown]
# ## Replace years in YAML metadata

# %%
from etl.files import ruamel_dump, ruamel_load

yaml_path = "wdi.meta.yml"

with open(yaml_path, "r") as f:
    yml = ruamel_load(f)

# %%
KEEP = {'armed_forces_share_population'}

# Delete variables that are not in the dataset
missing_variables = set(yml['tables']['wdi']['variables'].keys()) - set(tb.columns)
missing_variables = {v for v in missing_variables if not v.startswith('omm_') and v not in KEEP}

print(f"Deleting {len(missing_variables)} variables")
for var in missing_variables:
    del yml['tables']['wdi']['variables'][var]
# Out:
# Deleting 1 variables

# %%
import re
from typing import Union


def replace_years(s: str, year: Union[int, str]) -> str:
    """replaces all years in string with {year}.

    Example:

        >>> replace_years("GDP (constant 2010 US$)", 2015)
        "GDP (constant 2015 US$)"
    """
    year_regex = re.compile(r"\b([1-2]\d{3})\b")
    s_new = year_regex.sub(str(year), s)
    return s_new


variables = yml["tables"]["wdi"]["variables"]

for indicator_code in df_vars.index:
    if indicator_code in variables:
        var = variables[indicator_code]
    else:
        var = {}
        variables[indicator_code] = var

    # update titles from metadata file
    try:
        var["title"] = df_vars.loc[indicator_code].indicator_name
    except KeyError:
        continue

    # if title contains year, try to update units too
    year_regex = re.compile(r"\b([1-2]\d{3})\b")
    regex_res = year_regex.search(df_vars.loc[indicator_code].indicator_name)
    if regex_res:
        assert len(regex_res.groups()) == 1
        year = regex_res.groups()[0]

        if "unit" in var:
            var["unit"] = replace_years(var["unit"], year)

        if "short_unit" in var:
            var["short_unit"] = replace_years(var["short_unit"], year)

        for k in ["name", "unit", "short_unit"]:
            if var.get("display", {}).get("unit"):
                var["display"]["unit"] = replace_years(var["display"]["unit"], year)

            if var.get("display", {}).get("short_unit"):
                var["display"]["short_unit"] = replace_years(var["display"]["short_unit"], year)

        if "presentation" in var:
            for k in ["title_public", "title_variant"]:
                if k in var["presentation"]:
                    var["presentation"][k] = replace_years(var["presentation"][k], year)

# %%
with open(yaml_path, "w") as f:
    f.write(ruamel_dump(yml))

# %% [markdown]
# ## Replace years in chart configs

# %%
from etl.db import get_engine, read_sql

# get GDP variable
q = """
select id from variables
where name = 'GDP per capita, PPP (constant 2021 international $)'
    and catalogPath = 'grapher/worldbank_wdi/2025-01-24/wdi/wdi#ny_gdp_pcap_pp_kd'
"""
engine = get_engine()
var_id = read_sql(q, engine).id.iloc[0]
print(var_id)

# get all charts using that variable
q = f"""
select chartId from chart_dimensions where variableId = {var_id};
"""
chart_ids = list(read_sql(q, engine)['chartId'])
len(chart_ids)
# Out:
# 1008343
# 157

# %%
from apps.chart_sync.admin_api import AdminAPI
from etl.config import OWID_ENV, ENV_GRAPHER_USER_ID

admin_api = AdminAPI(OWID_ENV, grapher_user_id=ENV_GRAPHER_USER_ID)

old_year = "2017"
new_year = "2021"

for chart_id in chart_ids:
    chart_config = admin_api.get_chart_config(chart_id)

    fields = ['subtitle', 'note']

    update = False
    for field in fields:
        if field in chart_config:
            if old_year in (chart_config.get(field, '') or ''):
                chart_config[field] = chart_config[field].replace(old_year, new_year)
                update = True

    if update:
        print(f"Updating chart {chart_id}")
        admin_api.update_chart(chart_id, chart_config)
# Out:
# Updating chart 185
# Updating chart 225
# Updating chart 251
# Updating chart 340
# Updating chart 374
# Updating chart 517
# Updating chart 705
# Updating chart 936
# Updating chart 1005
# Updating chart 1355
# Updating chart 1592
# Updating chart 1699
# Updating chart 1700
# Updating chart 1722
# Updating chart 1746
# Updating chart 1885
# Updating chart 1993
# Updating chart 2038
# Updating chart 2282
# Updating chart 2283
# Updating chart 2414
# Updating chart 2437
# Updating chart 2640
# Updating chart 2891
# Updating chart 2900
# Updating chart 3515
# Updating chart 3516
# Updating chart 3519
# Updating chart 3538
# Updating chart 3540
# Updating chart 3544
# Updating chart 3593
# Updating chart 3740
# Updating chart 3886
# Updating chart 3994
# Updating chart 4373
# Updating chart 4413
# Updating chart 4414
# Updating chart 4417
# Updating chart 4654
# Updating chart 4669
# Updating chart 4890
# Updating chart 4893
# Updating chart 4917
# Updating chart 5168
# Updating chart 5500
# Updating chart 6186
# Updating chart 6303
# Updating chart 6305
# Updating chart 6420
# Updating chart 7135
# Updating chart 7136
# Updating chart 7845
# Updating chart 8121
# Updating chart 8122
# Updating chart 8138
# Updating chart 8231
# Updating chart 8454
# Updating chart 212
# Updating chart 449
# Updating chart 450
# Updating chart 587
# Updating chart 629
# Updating chart 773
# Updating chart 1131
# Updating chart 3132
# Updating chart 3587
# Updating chart 6965

# %% [markdown]
# ## Update Sources

# %%
import json

with open("wdi.sources.json", "r") as f:
    sources = json.load(f)

sources = [s for s in sources if not s["name"].startswith("TODO")]

missing_sources = list(set(df_vars["source"]) - {s["rawName"] for s in sources})
missing_sources
# Out:
# ["World Bank staff estimates using the World Integrated Trade Solution system, based on tariff data from the United Nations Conference on Trade and Development's Trade and Development's Trade Analysis and Information System (TRAINS) database and global imports data from the United Nations Statistics Division's Comtrade database.",
#  "World Bank staff estimates based on age/sex distributions of United Nations Population Division's World Population Prospects: 2024 Revision.",
#  'International Labour Organization. “Education and Mismatch Indicators database (EMI)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.',
#  'International Labour Organization. “Labour Market-related SDG Indicators database (ILOSDG)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.',
#  "World Bank staff estimates using the World Bank's total population and age/sex distributions of the United Nations Population Division's World Population Prospects: 2024 Revision.",
#  '(1) United Nations Population Division. World Population Prospects: 2024 Revision; (2) Statistical databases and publications from national statistical offices; (3) Eurostat: Demographic Statistics; (4) United Nations Statistics Division. Population and Vital Statistics Report (various years).',
#  'International Labour Organization. “Labour Force Statistics database (LFS)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.',
#  'International Labour Organization. “Wages and Working Time Statistics database (COND)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.',
#  'Derived from total population. Population source: (1) United Nations Population Division. World Population Prospects: 2024 Revision; (2) Statistical databases and publications from national statistical offices; (3) Eurostat: Demographic Statistics; (4) United Nations Statistics Division. Population and Vital Statistics Report (various years).',
#  'UNESCO Institute for Statistics (UIS). UIS.Stat Bulk Data Download Service. Accessed September 30, 2024. https://apiportal.uis.unesco.org/bdds.',
#  "World Bank staff estimates based on age distributions of United Nations Population Division's World Population Prospects: 2024 Revision."]

# %%
import os
from openai import OpenAI
import random

SYSTEM_PROMPT = f"""
You are given list of examples in JSON format you should use for learning. Each example has
rawName and fields name and dataPublisherSource are derived from rawName.
I'll give you a list of rawNames and you should give me a JSON with one field "sources" that
contains list of objects with rawName, name and dataPublisherSource fields filled in.

Examples:
{json.dumps(random.sample(sources, 20))}
"""

all_sources = "\n\n".join(missing_sources)

messages = [
    {
        "role": "system",
        "content": SYSTEM_PROMPT,
    },
    {
        "role": "user",
        "content": all_sources,
    },
]

client = OpenAI()

# 10 missing sources / 5 examples -> 2min
response = client.chat.completions.create(
    model="gpt-4o",
    temperature=0,
    messages=messages,
    response_format={"type": "json_object"},
)
print(f"Cost GPT4o: ${response.usage.total_tokens / 1e6 * 7.5:.2f}")
r = json.loads(response.choices[0].message.content)
print(json.dumps(r, ensure_ascii=False, indent=2))
# Out:
# Cost GPT4o: $0.02
# {
#   "sources": [
#     {
#       "rawName": "World Bank staff estimates using the World Integrated Trade Solution system, based on tariff data from the United Nations Conference on Trade and Development's Trade and Development's Trade Analysis and Information System (TRAINS) database and global imports data from the United Nations Statistics Division's Comtrade database.",
#       "name": "World Bank based on data from UNCTAD and UN Statistics Division",
#       "dataPublisherSource": "World Integrated Trade Solution - World Bank, TRAINS Database - UNCTAD, Comtrade Database - UN Statistics Division"
#     },
#     {
#       "rawName": "World Bank staff estimates based on age/sex distributions of United Nations Population Division's World Population Prospects: 2024 Revision.",
#       "name": "World Bank based on data from the UN Population Division",
#       "dataPublisherSource": "World Bank based on World Population Prospects - UN Population Division (2024)"
#     },
#     {
#       "rawName": "International Labour Organization. “Education and Mismatch Indicators database (EMI)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.",
#       "name": "International Labour Organization (via World Bank)",
#       "dataPublisherSource": "Education and Mismatch Indicators Database (EMI) - International Labour Organization"
#     },
#     {
#       "rawName": "International Labour Organization. “Labour Market-related SDG Indicators database (ILOSDG)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.",
#       "name": "International Labour Organization (via World Bank)",
#       "dataPublisherSource": "Labour Market-related SDG Indicators Database (ILOSDG) - International Labour Organization"
#     },
#     {
#       "rawName": "World Bank staff estimates using the World Bank's total population and age/sex distributions of the United Nations Population Division's World Population Prospects: 2024 Revision.",
#       "name": "World Bank based on data from the UN Population Division",
#       "dataPublisherSource": "World Bank based on World Population Prospects - UN Population Division (2024)"
#     },
#     {
#       "rawName": "(1) United Nations Population Division. World Population Prospects: 2024 Revision; (2) Statistical databases and publications from national statistical offices; (3) Eurostat: Demographic Statistics; (4) United Nations Statistics Division. Population and Vital Statistics Report (various years).",
#       "name": "United Nations Population Division, Eurostat, and National Statistical Offices",
#       "dataPublisherSource": "World Population Prospects - UN Population Division (2024), Demographic Statistics - Eurostat, Population and Vital Statistics Report - UN Statistics Division"
#     },
#     {
#       "rawName": "International Labour Organization. “Labour Force Statistics database (LFS)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.",
#       "name": "International Labour Organization (via World Bank)",
#       "dataPublisherSource": "Labour Force Statistics Database (LFS) - International Labour Organization"
#     },
#     {
#       "rawName": "International Labour Organization. “Wages and Working Time Statistics database (COND)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.",
#       "name": "International Labour Organization (via World Bank)",
#       "dataPublisherSource": "Wages and Working Time Statistics Database (COND) - International Labour Organization"
#     },
#     {
#       "rawName": "Derived from total population. Population source: (1) United Nations Population Division. World Population Prospects: 2024 Revision; (2) Statistical databases and publications from national statistical offices; (3) Eurostat: Demographic Statistics; (4) United Nations Statistics Division. Population and Vital Statistics Report (various years).",
#       "name": "United Nations Population Division, Eurostat, and National Statistical Offices",
#       "dataPublisherSource": "World Population Prospects - UN Population Division (2024), Demographic Statistics - Eurostat, Population and Vital Statistics Report - UN Statistics Division"
#     },
#     {
#       "rawName": "UNESCO Institute for Statistics (UIS). UIS.Stat Bulk Data Download Service. Accessed September 30, 2024. https://apiportal.uis.unesco.org/bdds.",
#       "name": "UNESCO Institute for Statistics",
#       "dataPublisherSource": "UIS.Stat Bulk Data Download Service - UNESCO Institute for Statistics"
#     },
#     {
#       "rawName": "World Bank staff estimates based on age distributions of United Nations Population Division's World Population Prospects: 2024 Revision.",
#       "name": "World Bank based on data from the UN Population Division",
#       "dataPublisherSource": "World Bank based on World Population Prospects - UN Population Division (2024)"
#     }
#   ]
# }
