# %% [markdown]
# ## Update metadata
#
# Update `wdi.meta.yml` from WDI metadata file. This notebook is intended to be run manually and all changes to the YAML file need to be verified.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from owid.catalog import Dataset
from etl.paths import DATA_DIR
import os

version = os.getcwd().rsplit('/', 1)[1]
ds_meadow = Dataset(DATA_DIR / 'meadow/worldbank_wdi' / version / 'wdi')
tb = ds_meadow['wdi']
indicator_codes = [tb[col].m.title for col in tb.columns]

tb_metadata = ds_meadow.read("wdi_metadata", safe_types=False)

# %%
from wdi import load_variable_metadata

df_vars = load_variable_metadata(tb_metadata, indicator_codes)
df_vars.head()
# Out:
# 2025-06-19 09:25:08 [info     ] wdi.missing_metadata           n_indicators=1
#                                                   topic  \
# indicator_code
# ag_con_fert_pt_zs  Environment: Agricultural production
# ag_con_fert_zs     Environment: Agricultural production
# ag_lnd_agri_k2                    Environment: Land use
# ag_lnd_agri_zs                    Environment: Land use
# ag_lnd_arbl_ha                    Environment: Land use
#
#                                                       indicator_name  \
# indicator_code
# ag_con_fert_pt_zs  Fertilizer consumption (% of fertilizer produc...
# ag_con_fert_zs     Fertilizer consumption (kilograms per hectare ...
# ag_lnd_agri_k2                            Agricultural land (sq. km)
# ag_lnd_agri_zs                    Agricultural land (% of land area)
# ag_lnd_arbl_ha                                Arable land (hectares)
#
#                   short_definition  \
# indicator_code
# ag_con_fert_pt_zs              NaN
# ag_con_fert_zs                 NaN
# ag_lnd_agri_k2                 NaN
# ag_lnd_agri_zs                 NaN
# ag_lnd_arbl_ha                 NaN
#
#                                                      long_definition  \
# indicator_code
# ag_con_fert_pt_zs  Fertilizer consumption measures the quantity o...
# ag_con_fert_zs     Fertilizer consumption measures the quantity o...
# ag_lnd_agri_k2     Agricultural land refers to the share of land ...
# ag_lnd_agri_zs     Agricultural land refers to the share of land ...
# ag_lnd_arbl_ha     Arable land (in hectares) includes land define...
#
#                   unit_of_measure periodicity base_period  \
# indicator_code
# ag_con_fert_pt_zs             NaN      Annual         NaN
# ag_con_fert_zs                NaN      Annual         NaN
# ag_lnd_agri_k2                NaN      Annual         NaN
# ag_lnd_agri_zs                NaN      Annual         NaN
# ag_lnd_arbl_ha                NaN      Annual         NaN
#
#                                                          other_notes  \
# indicator_code
# ag_con_fert_pt_zs  The world and regional aggregate series do not...
# ag_con_fert_zs     The world and regional aggregate series do not...
# ag_lnd_agri_k2     Areas of former states are included in the suc...
# ag_lnd_agri_zs     Areas of former states are included in the suc...
# ag_lnd_arbl_ha                                                   NaN
#
#                   aggregation_method  \
# indicator_code
# ag_con_fert_pt_zs   Weighted average
# ag_con_fert_zs      Weighted average
# ag_lnd_agri_k2                   Sum
# ag_lnd_agri_zs      Weighted average
# ag_lnd_arbl_ha                   NaN
#
#                                           limitations_and_exceptions  ...  \
# indicator_code                                                        ...
# ag_con_fert_pt_zs  The FAO has revised the time series for fertil...  ...
# ag_con_fert_zs     The FAO has revised the time series for fertil...  ...
# ag_lnd_agri_k2     The data are collected by the Food and Agricul...  ...
# ag_lnd_agri_zs     The data are collected by the Food and Agricul...  ...
# ag_lnd_arbl_ha     The Food and Agriculture Organization (FAO) tr...  ...
#
#                   general_comments  \
# indicator_code
# ag_con_fert_pt_zs              NaN
# ag_con_fert_zs                 NaN
# ag_lnd_agri_k2                 NaN
# ag_lnd_agri_zs                 NaN
# ag_lnd_arbl_ha                 NaN
#
#                                                               source  \
# indicator_code
# ag_con_fert_pt_zs  Food and Agriculture Organization, electronic ...
# ag_con_fert_zs     Food and Agriculture Organization, electronic ...
# ag_lnd_agri_k2     Food and Agriculture Organization, electronic ...
# ag_lnd_agri_zs     Food and Agriculture Organization, electronic ...
# ag_lnd_arbl_ha     Food and Agriculture Organization, electronic ...
#
#                                  statistical_concept_and_methodology  \
# indicator_code
# ag_con_fert_pt_zs  Fertilizer consumption measures the quantity o...
# ag_con_fert_zs     Fertilizer consumption measures the quantity o...
# ag_lnd_agri_k2     Agricultural land constitutes only a part of a...
# ag_lnd_agri_zs     Agriculture is still a major sector in many ec...
# ag_lnd_arbl_ha     Temporary fallow land refers to land left fall...
#
#                                                development_relevance  \
# indicator_code
# ag_con_fert_pt_zs  Factors such as the green revolution, has led ...
# ag_con_fert_zs     Factors such as the green revolution, has led ...
# ag_lnd_agri_k2     Agricultural land covers more than one-third o...
# ag_lnd_agri_zs     Agricultural land covers more than one-third o...
# ag_lnd_arbl_ha     Agricultural land covers more than one-third o...
#
#                   related_source_links other_web_links related_indicators  \
# indicator_code
# ag_con_fert_pt_zs                  NaN             NaN                NaN
# ag_con_fert_zs                     NaN             NaN                NaN
# ag_lnd_agri_k2                     NaN             NaN                NaN
# ag_lnd_agri_zs                     NaN             NaN                NaN
# ag_lnd_arbl_ha                     NaN             NaN                NaN
#
#                   license_type unit indicator_code_original
# indicator_code
# ag_con_fert_pt_zs    CC BY-4.0  NaN       AG.CON.FERT.PT.ZS
# ag_con_fert_zs       CC BY-4.0  NaN          AG.CON.FERT.ZS
# ag_lnd_agri_k2       CC BY-4.0  NaN          AG.LND.AGRI.K2
# ag_lnd_agri_zs       CC BY-4.0  NaN          AG.LND.AGRI.ZS
# ag_lnd_arbl_ha       CC BY-4.0  NaN          AG.LND.ARBL.HA
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Replace years in YAML metadata

# %%
from etl.files import ruamel_dump, ruamel_load

yaml_path = "wdi.meta.yml"

with open(yaml_path, "r") as f:
    yml = ruamel_load(f)

# %%
KEEP = {'armed_forces_share_population'}

# Delete variables that are not in the dataset
missing_variables = set(yml['tables']['wdi']['variables'].keys()) - set(tb.columns)
missing_variables = {v for v in missing_variables if not v.startswith('omm_') and v not in KEEP}

print(f"Deleting {len(missing_variables)} variables")
for var in missing_variables:
    del yml['tables']['wdi']['variables'][var]

# %%
import re
from typing import Union


def replace_years(s: str, year: Union[int, str]) -> str:
    """replaces all years in string with {year}.

    Example:

        >>> replace_years("GDP (constant 2010 US$)", 2015)
        "GDP (constant 2015 US$)"
    """
    year_regex = re.compile(r"\b([1-2]\d{3})\b")
    s_new = year_regex.sub(str(year), s)
    return s_new


variables = yml["tables"]["wdi"]["variables"]

for indicator_code in df_vars.index:
    if indicator_code in variables:
        var = variables[indicator_code]
    else:
        var = {}
        variables[indicator_code] = var

    # update titles from metadata file
    try:
        var["title"] = df_vars.loc[indicator_code].indicator_name
    except KeyError:
        continue

    # if title contains year, try to update units too
    year_regex = re.compile(r"\b([1-2]\d{3})\b")
    regex_res = year_regex.search(df_vars.loc[indicator_code].indicator_name)
    if regex_res:
        assert len(regex_res.groups()) == 1
        year = regex_res.groups()[0]

        if "unit" in var:
            var["unit"] = replace_years(var["unit"], year)

        if "short_unit" in var:
            var["short_unit"] = replace_years(var["short_unit"], year)

        for k in ["name", "unit", "short_unit"]:
            if var.get("display", {}).get("unit"):
                var["display"]["unit"] = replace_years(var["display"]["unit"], year)

            if var.get("display", {}).get("short_unit"):
                var["display"]["short_unit"] = replace_years(var["display"]["short_unit"], year)

        if "presentation" in var:
            for k in ["title_public", "title_variant"]:
                if k in var["presentation"]:
                    var["presentation"][k] = replace_years(var["presentation"][k], year)

# %%
with open(yaml_path, "w") as f:
    f.write(ruamel_dump(yml))

# %% [markdown]
# ## Replace years in chart configs

# %%
from etl.db import get_engine, read_sql

# get GDP variable
q = """
select id from variables
where name = 'GDP per capita, PPP (constant 2021 international $)'
    and catalogPath = 'grapher/worldbank_wdi/2025-01-24/wdi/wdi#ny_gdp_pcap_pp_kd'
"""
engine = get_engine()
var_id = read_sql(q, engine).id.iloc[0]
print(var_id)

# get all charts using that variable
q = f"""
select chartId from chart_dimensions where variableId = {var_id};
"""
chart_ids = list(read_sql(q, engine)['chartId'])
len(chart_ids)

# %%
from apps.chart_sync.admin_api import AdminAPI
from etl.config import OWID_ENV, ENV_GRAPHER_USER_ID

admin_api = AdminAPI(OWID_ENV, grapher_user_id=ENV_GRAPHER_USER_ID)

old_year = "2017"
new_year = "2021"

for chart_id in chart_ids:
    chart_config = admin_api.get_chart_config(chart_id)

    fields = ['subtitle', 'note']

    update = False
    for field in fields:
        if field in chart_config:
            if old_year in (chart_config.get(field, '') or ''):
                chart_config[field] = chart_config[field].replace(old_year, new_year)
                update = True

    if update:
        print(f"Updating chart {chart_id}")
        admin_api.update_chart(chart_id, chart_config)

# %% [markdown]
# ## Update Sources

# %%
import json

with open("wdi.sources.json", "r") as f:
    sources = json.load(f)

sources = [s for s in sources if not s["name"].startswith("TODO")]

missing_sources = list(set(df_vars["source"]) - {s["rawName"] for s in sources})
len(missing_sources)
# Out:
# 208

# %%
GOOD_EXAMPLES = [
    {
    "rawName": "ASPIRE: The Atlas of Social Protection - Indicators of Resilience and Equity, The World Bank. Data are based on national representative household surveys. (datatopics.worldbank.org/aspire/)",
    "dataPublisherSource": "The Atlas of Social Protection Indicators of Resilience and Equity - World Bank",
    "name": "ASPIRE: The Atlas of Social Protection, World Bank"
  },
  {
    "rawName": "Brauer, M. et al. 2017, for the Global Burden of Disease Study 2017.",
    "dataPublisherSource": "Brauer et al. (2017)",
    "name": "Brauer et al. (2017), via World Bank"
  },
  {
    "rawName": "Data collected by the Lancet Commission on Global Surgery (www.lancetglobalsurgery.org); Data collected by WHO Collaborating Centre for Surgery and Public Health at Lund University from various sources including Ministries of Health or equivalent national regulatory bodies, national official entities such as medical councils, Eurostat, OECD, WHO Euro Health For All Database, WHO EURO Technical resources for health Database; BMJ Glob Health.",
    "dataPublisherSource": "Lancet Commission on Global Surgery, World Health Organization Collaborating Centre for Surgery and Public Health at Lund University",
    "name": "Lancet Commission on Global Surgery, WHO, and BMJ Global Health, via World Bank"
  },
  {
    "rawName": "Debt service is the sum of principle repayments and interest actually paid in currency, goods, or services. This series differs from the standard debt to exports series. It covers only long-term public and publicly guaranteed debt and repayments (repurchases and charges) to the IMF. Exports of goods and services include primary income, but do not include workers' remittances.",
    "dataPublisherSource": "International Debt Statistics - World Bank",
    "name": "International Debt Statistics - World Bank"
  },
  {
    "rawName": "Demographic and Health Surveys (DHS)",
    "dataPublisherSource": "Demographic and Health Surveys",
    "name": "Demographic and Health Surveys (DHS), via World Bank",
  },
  {
    "rawName": "Demographic and Health Surveys (DHS), Multiple Indicator Cluster Surveys (MICS), and other surveys",
    "dataPublisherSource": "Demographic and Health Surveys, Multiple Indicator Cluster Surveys, other surveys",
    "name": "Demographic and Health Surveys (DHS), Multiple Indicator Cluster Surveys (MICS), and other surveys, via World Bank"
  },
  {
    "rawName": "Demographic and Health Surveys (DHS).",
    "dataPublisherSource": "Demographic and Health Surveys (DHS)",
    "name": "Demographic and Health Surveys (DHS), via World Bank"
  },
  {
    "rawName": "Demographic and Health Surveys, and UNAIDS.",
    "dataPublisherSource": "Demographic and Health Surveys, UNAIDS",
    "name": "Demographic and Health Surveys (DHS), and UNAIDS, via World Bank"
  },
  {
    "rawName": "Derived using World Bank national accounts data and OECD National Accounts data files, and employment data from International Labour Organization, ILOSTAT database.",
    "dataPublisherSource": "ILOSTAT database - International Labour Organization, National accounts data - World Bank / OECD",
    "name": "World Bank and OECD national accounts, and ILOSTAT"
  },
  {
    "rawName": "World Bank staff estimates based on age distributions of United Nations Population Division's World Population Prospects: 2024 Revision.",
    "dataPublisherSource": "World Bank based on World Population Prospects - UN Population Division (2024)",
    "name": "World Bank based on data from the UN Population Division"
  },
  {
    "rawName": "Food and Agriculture Organization of the United Nations (FAO)",
    "dataPublisherSource": "Food and Agriculture Organization of the United Nations",
    "name": "Food and Agriculture Organization of the United Nations, via World Bank"
  },
  {
    "rawName": "Inter-Parliamentary Union (IPU) (www.ipu.org).  For the year of 1998, the data is as of August 10, 1998.",
    "dataPublisherSource": "Inter-Parliamentary Union",
    "name": "Inter-Parliamentary Union (IPU), via World Bank"
  },
  {
    "rawName": "United Nations Population Division, Trends in Total Migrant Stock: 2008 Revision.",
    "dataPublisherSource": "Trends in Total Migrant Stock - UN Population Division (2008)",
    "name": "United Nations Population Division, via World Bank",
  },
  {
    "rawName": "Development Assistance Committee of the Organisation for Economic Co-operation and Development, Geographical Distribution of Financial Flows to Developing Countries, Development Co-operation Report, and International Development Statistics database. Data are available online at: www.oecd.org/dac/stats/idsonline. World Bank gross capital formation estimates are used for the denominator.",
    "dataPublisherSource": "Geographical Distribution of Financial Flows to Developing Countries - OECD Development Assistance Committee, Development Co-operation Report - OECD Development Assistance Committee, International Development Statistics Database - OECD, Gross capital formation estimates - World Bank",
    "name": "Development Assistance Committee - OECD, via World Bank",
  },
  {
    "rawName": "Development Assistance Committee of the Organisation for Economic Co-operation and Development, Geographical Distribution of Financial Flows to Developing Countries, Development Co-operation Report, and International Development Statistics database. Data are available online at: www.oecd.org/dac/stats/idsonline. World Bank imports of good and services estimates are used for the denominator.",
    "dataPublisherSource": "Geographical Distribution of Financial Flows to Developing Countries - OECD Development Assistance Committee, Development Co-operation Report - OECD Development Assistance Committee, International Development Statistics Database - OECD, Imports estimates - World Bank",
    "name": "Development Assistance Committee - OECD, via World Bank",
  },
  {
    "rawName": "Food and Agriculture Organization and World Bank population estimates.",
    "dataPublisherSource": "Food and Agriculture Organization of the United Nations, Population estimates - World Bank",
    "name": "Food and Agriculture Organization of the United Nations and World Bank",
  },
  {
    "rawName": "Food and Agriculture Organization of the United Nations (FAO)",
    "dataPublisherSource": "Food and Agriculture Organization of the United Nations",
    "name": "Food and Agriculture Organization of the United Nations and World Bank",
  },
  {
    "rawName": "Food and Agriculture Organization, AQUASTAT data, and World Bank and OECD GDP estimates.",
    "dataPublisherSource": "AQUASTAT Database - Food and Agriculture Organization of the United Nations, GDP estimates - World Bank / OECD",
    "name": "Food and Agriculture Organization of the United Nations, OECD, and World Bank"
  },
  {
    "rawName": "Food and Agriculture Organization, AQUASTAT data.",
    "dataPublisherSource": "AQUASTAT Database - Food and Agriculture Organization of the United Nations",
    "name": "Food and Agriculture Organization of the United Nations, OECD, and World Bank"
  },
  {
    "rawName": "Food and Agriculture Organization, electronic files and web site.",
    "dataPublisherSource": "Food and Agriculture Organization of the United Nations",
    "name": "Food and Agriculture Organization of the United Nations, via World Bank"
  },
  {
    "rawName": "Household surveys, including Demographic and Health Surveys and Multiple Indicator Cluster Surveys. Largely compiled by United Nations Population Division.",
    "dataPublisherSource": "Demographic and Health Surveys, Multiple Indicator Cluster Surveys, Household surveys, UN Population Division",
    "name": "Demographic and Health Surveys (DHS), Multiple Indicator Cluster Surveys (MICS), and United Nations Population Division, via World Bank",
  },
  {
    "rawName": "International Comparison Program, World Bank | World Development Indicators database, World Bank | Eurostat-OECD PPP Programme.",
    "dataPublisherSource": "International Comparison Program - World Bank, World Development Indicators - World Bank, Eurostat-OECD PPP Programme",
    "name": "Eurostat, OECD, and World Bank",
  },
  {
    "rawName": "The Program in Global Surgery and Social Change (PGSSC) at Harvard Medical School (https://www.pgssc.org/)",
    "dataPublisherSource": "Harvard Medical School Program in Global Surgery and Social Change",
    "name": "Harvard Medical School Program in Global Surgery and Social Change (PGSSC), via World Bank"
  },
  {
    "rawName": "The country data compiled, adjusted and used in the estimation model by the Maternal Mortality Estimation Inter-Agency Group (MMEIG). The country data were compiled from the following sources:  civil registration and vital statistics; specialized studies on maternal mortality; population based surveys and censuses; other available data sources including data from surveillance sites.",
    "dataPublisherSource": "UN Maternal Mortality Estimation Inter-Agency Group",
    "name": "UN Maternal Mortality Estimation Inter-Agency Group, via World Bank"
  },
  {
    "rawName": "UNICEF, State of the World's Children, Childinfo, and Demographic and Health Surveys.",
    "dataPublisherSource": "State of the World's Children - UNICEF, Demographic and Health Surveys",
    "name": "Demographic and Health Surveys (DHS) and UNICEF, via World Bank"
  },
  {
    "rawName": "UNICEF-WHO Low birthweight estimates [data.unicef.org]",
    "dataPublisherSource": "Low Birthweight Estimates - UNICEF / World Health Organization",
    "name": "UNICEF and World Health Organization, via World Bank"
  },
  {
    "rawName": "Understanding Children's Work project based on data from ILO, UNICEF and the World Bank.",
    "dataPublisherSource": "Understanding Children's Work Project - International Labour Organization / UNICEF / World Bank",
    "name": "International Labour Organization, UNICEF, and World Bank"
  },
  {
    "rawName": "United Nations Children's Fund, Division of Data, Analysis, Planning and Monitoring (2019). UNICEF Global Databases on Iodized salt, New York, June 2019",
    "dataPublisherSource": "Global Database on Household Consumption of Iodized Salt - UNICEF",
    "name": "UNICEF, via World Bank"
  },
  {
    "rawName": "United Nations High Commissioner for Refugees (UNHCR) and UNRWA through UNHCR's Refugee Data Finder at https://www.unhcr.org/refugee-statistics/.",
    "dataPublisherSource": "Refugee Data Finder - UN High Commissioner for Refugees",
    "name": "UNHCR and UNRWA, via World Bank"
  },
  {
    "rawName": "United Nations High Commissioner for Refugees (UNHCR) and UNRWA through UNHCR's Refugee Data Finder at https://www.unhcr.org/refugee-statistics/.",
    "dataPublisherSource": "Refugee Data Finder - UN High Commissioner for Refugees",
    "name": "UNHCR and UNRWA, via World Bank"
  },
  {
    "rawName": "World Bank staff estimates based on IMF balance of payments data, and World Bank and OECD GDP estimates.",
    "dataPublisherSource": "World Bank based on Balance of Payments Statistics - International Monetary Fund, GDP estimates - World Bank / OECD",
    "name": "World Bank based on IMF and OECD"
  },
  {
    "rawName": "International Labour Organization. “ILO Modelled Estimates and Projections database (ILOEST)” ILOSTAT. Accessed June 18, 2024. https://ilostat.ilo.org/data/.",
    "dataPublisherSource": "ILO Modelled Estimates and Projections Database (ILOEST) - International Labour Organization",
    "name": "International Labour Organization, ILOSTAT, via World Bank"
  },
]

# %%
import os
from openai import OpenAI
import json

SYSTEM_PROMPT = """
You are tasked with creating short citation names for data sources based on their raw names and data publisher sources.

Input format: You will receive rawName and dataPublisherSource fields.
Output format: Return a JSON object with a "sources" field containing an array of objects with rawName and name fields.


Rules for creating the "name" field in addition to what you infer from examples
1. World Bank MUST appear in every citation name

Check out these good examples. Make sure these examples are followed closely.
""" + json.dumps(GOOD_EXAMPLES, indent=2)


# Limit batch size to control costs and API limits
MAX_BATCH_SIZE = 30

client = OpenAI()
all_new_sources = []

# Process all missing sources in batches
for i in range(0, len(missing_sources), MAX_BATCH_SIZE):
    batch_missing_sources = missing_sources[i:i+MAX_BATCH_SIZE]
    print(f"Processing batch {i//MAX_BATCH_SIZE + 1}: {len(batch_missing_sources)} sources (total: {len(missing_sources)})")

    # Create input data for this batch
    missing_sources_data = []
    for raw_name in batch_missing_sources:
        # Find corresponding dataPublisherSource from df_vars
        matching_rows = df_vars[df_vars["source"] == raw_name]
        if not matching_rows.empty:
            data_publisher_source = matching_rows.iloc[0].get("dataPublisherSource", "")
            missing_sources_data.append({
                "rawName": raw_name,
                "dataPublisherSource": data_publisher_source
            })

    if not missing_sources_data:
        continue

    input_text = json.dumps(missing_sources_data, ensure_ascii=False, indent=2)

    messages = [
        {
            "role": "system",
            "content": SYSTEM_PROMPT,
        },
        {
            "role": "user",
            "content": input_text,
        },
    ]

    # Use GPT-4o for processing
    response = client.chat.completions.create(
        # model="gpt-4.1-mini",
        model="gpt-4.1",
        temperature=0,
        messages=messages,
        response_format={"type": "json_object"},
    )

    r = json.loads(response.choices[0].message.content)
    all_new_sources.extend(r['sources'])

print(f"Processed {len(all_new_sources)} sources across {(len(missing_sources) + MAX_BATCH_SIZE - 1) // MAX_BATCH_SIZE} batches")

# Combine all results
r = {'sources': all_new_sources}
print(f"\nFirst 5 results:")
for source in r['sources'][:5]:
    print(f"  {source['name']} <- {source['rawName'][:100]}...")
# Out:
# Processing batch 1: 30 sources (total: 208)
# Processing batch 2: 30 sources (total: 208)
# Processing batch 3: 30 sources (total: 208)
# Processing batch 4: 30 sources (total: 208)
# Processing batch 5: 30 sources (total: 208)
# Processing batch 6: 30 sources (total: 208)
# Processing batch 7: 28 sources (total: 208)
# Processed 208 sources across 7 batches
#
# First 5 results:
#   CIESIN/Columbia University and NASA SEDAC, via World Bank <- Center for International Earth Science Information Network (CIESIN)/Columbia University. 2013. Urban...
#   IMF Balance of Payments Statistics, OECD, and World Bank <- International Monetary Fund, Balance of Payments Statistics Yearbook and data files, and World Bank ...
#   World Bank based on data from the UN Population Division <- World Bank staff estimates using the World Bank's total population and age/sex distributions of the ...
#   World Health Organization, via World Bank <- World Health Organization, World malaria report and Global Health Observatory Data Repository/World ...
#   Lancet Commission on Global Surgery and UCSF Center for Health Equity in Surgery and Anesthesia, via World Bank <- Data from various sources compiled by the Lancet Commission on Global Surgery (www.lancetglobalsurge...

# %% [markdown]
# ## Update wdi.sources.json file

# %%
import json

with open("wdi.sources.json", "r") as f:
    sources = json.load(f)

for new_source in r['sources']:
    for s in sources:
        if s['rawName'] == new_source['rawName']:
            print(f"Updating source:\n  {new_source['name']} <- {s['rawName']}")
            s['name'] = new_source['name']
            break
    else:
        raise ValueError(f"Source {new_source['rawName']} not found in existing sources")

# Remove sources that still have TODO in their name
sources = [s for s in sources if not s['name'].startswith('TODO')]

# Save updated sources back to file
with open("wdi.sources.json", "w") as f:
    json.dump(sources, f, ensure_ascii=False, indent=2)
# Out:
# Updating source:
#   CIESIN/Columbia University and NASA SEDAC, via World Bank <- Center for International Earth Science Information Network (CIESIN)/Columbia University. 2013. Urban-Rural Population and Land Area Estimates Version 2. Palisades, NY: NASA Socioeconomic Data and Applications Center (SEDAC). http://sedac.ciesin.columbia.edu/data/set/lecz-urban-rural-population-land-area-estimates-v2.
# Updating source:
#   IMF Balance of Payments Statistics, OECD, and World Bank <- International Monetary Fund, Balance of Payments Statistics Yearbook and data files, and World Bank and OECD GDP estimates.
# Updating source:
#   World Bank based on data from the UN Population Division <- World Bank staff estimates using the World Bank's total population and age/sex distributions of the United Nations Population Division's World Population Prospects: 2024 Revision.
# Updating source:
#   World Health Organization, via World Bank <- World Health Organization, World malaria report and Global Health Observatory Data Repository/World Health Statistics (http://apps.who.int/ghodata/).
# Updating source:
#   Lancet Commission on Global Surgery and UCSF Center for Health Equity in Surgery and Anesthesia, via World Bank <- Data from various sources compiled by the Lancet Commission on Global Surgery (www.lancetglobalsurgery.org) and the Center for Health Equity in Surgery and Anesthesia at UCSF Medical Center.
# Updating source:
#   CIESIN/Columbia University, CUNY CIDR, and NASA SEDAC, via World Bank <- Center for International Earth Science Information Network - CIESIN - Columbia University, and CUNY Institute for Demographic Research - CIDR - City University of New York. 2021. Low Elevation Coastal Zone (LECZ) Urban-Rural Population and Land Area Estimates, Version 3. Palisades, NY: NASA Socioeconomic Data and Applications Center (SEDAC). https://doi.org/10.7927/d1x1-d702.
# Updating source:
#   UNCTAD, via World Bank <- United Nations Conference on Trade and Development, Review of Maritime Transport 2010.
# Updating source:
#   World Health Organization, via World Bank <- World Health Organization, Global Tuberculosis Report.
# Updating source:
#   Food and Agriculture Organization of the United Nations and World Bank <- Food and Agriculture Organization and World Bank population estimates.
# Updating source:
#   EDGAR Community GHG Database (European Commission JRC, IEA), via World Bank <- EDGAR (Emissions Database for Global Atmospheric Research) Community GHG Database, a collaboration between the European Commission, Joint Research Centre (JRC), the International Energy Agency (IEA), and comprising IEA-EDGAR CO2, EDGAR CH4, EDGAR N2O, EDGAR F-GASES version 8.0, (2023) European Commission, JRC (Datasets). https://edgar.jrc.ec.europa.eu/dataset_ghg80
# Updating source:
#   Demographic and Health Surveys (DHS) and UNFPA, via World Bank <- Demographic and Health Surveys compiled by United Nations Population Fund. Retrieved on February 14, 2023, from the SDG Global database API (https://unstats.un.org/sdgs/UNSDGAPIV5/swagger/index.html).
# Updating source:
#   World Bank, OECD, and IMF WEO <- World Bank staff estimates based on World Bank national accounts data archives, OECD National Accounts, and the IMF WEO database.
# Updating source:
#   UNESCO Institute for Statistics (UIS), via World Bank <- UNESCO Institute for Statistics (UIS). UIS.Stat Bulk Data Download Service. Accessed October 24, 2022. https://apiportal.uis.unesco.org/bdds.
# Updating source:
#   UNICEF, via World Bank <- United Nations Children's Fund, Division of Data, Analysis, Planning and Monitoring (2019). UNICEF Global Databases on Iodized salt, New York, June 2019
# Updating source:
#   EDGAR Community GHG Database (European Commission JRC, IEA), via World Bank <- EDGAR (Emissions Database for Global Atmospheric Research) Community GHG Database, a collaboration between the European Commission, Joint Research Centre (JRC), the International Energy Agency (IEA), and comprising IEA-EDGAR CO2, EDGAR CH4, EDGAR N2O, EDGAR F-GASES version 8.0, (2023) European Commission, JRC (Datasets). https://edgar.jrc.ec.europa.eu/dataset_ghg77
# Updating source:
#   Demographic and Health Surveys (DHS), Multiple Indicator Cluster Surveys (MICS), and UNICEF, via World Bank <- Household surveys such as Demographic and Health Surveys and Multiple Indicator Cluster Surveys.  Largely compiled by UNICEF.
# Updating source:
#   Food and Agriculture Organization of the United Nations, via World Bank <- Food and Agriculture Organization.
# Updating source:
#   Demographic and Health Surveys (DHS) and UNICEF, via World Bank <- UNICEF, State of the World's Children, Childinfo, and Demographic and Health Surveys.
# Updating source:
#   World Bank based on IMF <- World Bank staff estimates based on IMF balance of payments data.
# Updating source:
#   Development Assistance Committee - OECD, via World Bank <- Development Assistance Committee of the Organisation for Economic Co-operation and Development, Geographical Distribution of Financial Flows to Developing Countries, Development Co-operation Report, and International Development Statistics database. Data are available online at: www.oecd.org/dac/stats/idsonline. IMF central government expense estimates are used for the denominator.
# Updating source:
#   IMF Government Finance Statistics, OECD, and World Bank <- International Monetary Fund, Government Finance Statistics Yearbook and data files, and World Bank and OECD GDP estimates.
# Updating source:
#   United Nations Population Division, via World Bank <- United Nations Population Division. World Population Prospects: 2024 Revision.
# Updating source:
#   Grassi et al. (2022), via World Bank <- Grassi, G., Conchedda, G., Federici, S., Abad Viñas, R., Korosuo, A., Melo, J., Rossi, S., Sandker, M., Somogyi, Z., and Tubiello, F. N.: Carbon fluxes from land 2000–2020: bringing clarity on countries’ reporting, Earth Syst. Sci. Data, 14, 4643–4666, 2022, doi:10.5194/essd-14-4643-2022. Data available from https://doi.org/10.5281/zenodo.7190601
# Updating source:
#   International Labour Organization, ILOSTAT, via World Bank <- International Labour Organization. “Education and Mismatch Indicators database (EMI)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.
# Updating source:
#   UNCTAD, via World Bank <- UNCTAD (http://unctad.org/en/Pages/statistics.aspx)
# Updating source:
#   UNESCO Institute for Statistics (UIS), via World Bank <- UNESCO Institute for Statistics (UIS). UIS.Stat Bulk Data Download Service. Accessed September 30, 2024. https://apiportal.uis.unesco.org/bdds.
# Updating source:
#   National Science Foundation, via World Bank <- National Science Foundation, Science and Engineering Indicators.
# Updating source:
#   International Telecommunication Union (ITU), via World Bank <- International Telecommunication Union (ITU) World Telecommunication/ICT Indicators Database
# Updating source:
#   UNCTAD, via World Bank <- United Nations Conference on Trade and Development
# Updating source:
#   International Union of Railways (UIC) and OECD, via World Bank <- Internation Union of Railways (UIC), OECD Statistics
# Updating source:
#   World Health Organization, via World Bank <- Data are from the World Health Organization, supplemented by country data.
# Updating source:
#   United Nations Population Division, via World Bank <- United Nations Population Division, Trends in Total Migrant Stock: 2012 Revision.
# Updating source:
#   Worldwide Governance Indicators (WGI), World Bank <- Detailed documentation of the WGI, interactive tools for exploring the data, and full access to the underlying source data available at www.govindicators.org. The WGI are produced by Daniel Kaufmann (Natural Resource Governance Institute and Brookings Institution) and Aart Kraay (World Bank Development Research Group).  Please cite Kaufmann, Daniel, Aart Kraay and Massimo Mastruzzi (2010).  "The Worldwide Governance Indicators:  Methodology and Analytical Issues".  World Bank Policy Research Working Paper No. 5430 (http://papers.ssrn.com/sol3/papers.cfm?abstract_id=1682130).  The WGI do not reflect the official views of the Natural Resource Governance Institute, the Brookings Institution, the World Bank, its Executive Directors, or the countries they represent.
# Updating source:
#   World Development Indicators, World Bank, with data from ILO and United Nations Population Division <- World Bank, World Development Indicators database. Estimates are based on data obtained from International Labour Organization and United Nations Population Division.
# Updating source:
#   Demographic and Health Surveys (DHS), via World Bank <- Demographic and Health Surveys (DHS).
# Updating source:
#   Oxford Poverty and Human Development Initiative (OPHI), via World Bank <- Alkire, S., Kanagaratnam, U., and Suppa, N. (2023). ‘The global Multidimensional Poverty Index (MPI) 2023 country results and methodological note’, OPHI MPI Methodological Note 55, Oxford Poverty and Human Development Initiative (OPHI), University of Oxford. (https://ophi.org.uk/mpi-methodological-note-55-2/)
# Updating source:
#   UNEP-WCMC and IUCN Red List, via World Bank <- United Nations Environmental Program and the World Conservation Monitoring Centre, and International Union for Conservation of Nature, Red List of Threatened Species.
# Updating source:
#   National statistical offices and United Nations Statistics Division, via World Bank <- National statistical offices or national database and publications compiled by United Nations Statistics Division. The data were downloaded on April 4, 2024, from the Global SDG  API: https://unstats.un.org/sdgs/UNSDGAPIV5/swagger/index.html
# Updating source:
#   Netcraft and World Bank <- Netcraft (http://www.netcraft.com/) and World Bank population estimates.
# Updating source:
#   Global Health Observatory, World Health Organization, via World Bank <- Global Health Observatory. Geneva: World Health Organization; 2023. (https://www.who.int/data/gho/data/themes/topics/service-coverage)
# Updating source:
#   UNICEF, via World Bank <- UNICEF global databases, based on administrative reports from countries (link: https://data.unicef.org/topic/nutrition/vitamin-a-deficiency/)
# Updating source:
#   Global Findex Database, World Bank <- Global Findex Database, World Bank (https://www.worldbank.org/en/publication/globalfindex).
# Updating source:
#   World Bank based on data from the UN Population Division <- World Bank staff estimates based on age distributions of United Nations Population Division's World Population Prospects: 2024 Revision.
# Updating source:
#   United Nations Population Division, Eurostat, national statistical offices, and United Nations Statistics Division, via World Bank <- Derived from total population. Population source: (1) United Nations Population Division. World Population Prospects: 2024 Revision; (2) Statistical databases and publications from national statistical offices; (3) Eurostat: Demographic Statistics; (4) United Nations Statistics Division. Population and Vital Statistics Report (various years).
# Updating source:
#   UN Comtrade via WITS, World Bank <- United Nations, Comtrade database through the WITS platform.
# Updating source:
#   UN Comtrade via WITS, World Bank <- World Bank staff estimates through the WITS platform from the Comtrade database maintained by the United Nations Statistics Division.
# Updating source:
#   Standard & Poor's, via World Bank <- Standard & Poor's, Global Stock Markets Factbook and supplemental S&P data.
# Updating source:
#   World Federation of Exchanges, via World Bank <- World Federation of Exchanges database.
# Updating source:
#   Grassi et al. (2022), via World Bank <- Grassi, G., Conchedda, G., Federici, S., Abad Viñas, R., Korosuo, A., Melo, J., Rossi, S., Sandker, M., Somogyi, Z., and Tubiello, F. N.: Carbon fluxes from land 2000–2020: bringing clarity on countries’ reporting, Earth Syst. Sci. Data, 14, 4643–4666, 2022, doi:10.5194/essd-14-4643-2022. Data available from https://doi.org/10.5281/zenodo.7190605
# Updating source:
#   Food and Agriculture Organization of the United Nations, via World Bank <- Food and Agriculture Organization, electronic files and web site.
# Updating source:
#   Entrepreneurship Database, World Bank <- World Bank's Entrepreneurship Database (https://www.worldbank.org/en/programs/entrepreneurship).
# Updating source:
#   International Financial Statistics, IMF, via World Bank <- International Monetary Fund, International Financial Statistics database.
# Updating source:
#   UNESCO Institute for Statistics, via World Bank <- UNESCO Institute for Statistics (http://uis.unesco.org/). Data as of February 2020.
# Updating source:
#   UN Maternal Mortality Estimation Inter-Agency Group, via World Bank <- The country data compiled, adjusted and used in the estimation model by the Maternal Mortality Estimation Inter-Agency Group (MMEIG). The country data were compiled from the following sources:  civil registration and vital statistics; specialized studies on maternal mortality; population based surveys and censuses; other available data sources including data from surveillance sites.
# Updating source:
#   International Labour Organization, ILOSTAT, via World Bank <- International Labour Organization. “Labour Market-related SDG Indicators database (ILOSDG)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.
# Updating source:
#   International Labour Organization, ILOSTAT, via World Bank <- International Labour Organization. “ILO Modelled Estimates and Projections database ( ILOEST )” ILOSTAT. Accessed September 06, 2024. https://ilostat.ilo.org/data/.
# Updating source:
#   United Nations Population Division, via World Bank <- United Nations Population Division, Trends in Total Migrant Stock: 2008 Revision.
# Updating source:
#   IMF Balance of Payments, UNCTAD, and national sources, via World Bank <- International Monetary Fund, Balance of Payments database, supplemented by data from the United Nations Conference on Trade and Development and official national sources.
# Updating source:
#   The Changing Wealth of Nations, World Bank <- World Bank staff estimates based on sources and methods described in the World Bank's The Changing Wealth of Nations.
# Updating source:
#   Global Database of Shared Prosperity (GDSP), World Bank <- World Bank, Global Database of Shared Prosperity (GDSP) (http://www.worldbank.org/en/topic/poverty/brief/global-database-of-shared-prosperity).
# Updating source:
#   Demographic and Health Surveys (DHS), Multiple Indicator Cluster Surveys (MICS), and other surveys, via World Bank <- Demographic and Health Surveys (DHS), Multiple Indicator Cluster Surveys (MICS), and other surveys
# Updating source:
#   World Bank based on United Nations Statistics Division and UNESCO Institute for Statistics <- World Bank staff estimates using data from the United Nations Statistics Division's Statistical Yearbook, and the UNESCO Institute for Statistics online database.
# Updating source:
#   World Tourism Organization, IMF, and World Bank <- World Tourism Organization, Yearbook of Tourism Statistics, Compendium of Tourism Statistics and data files, and IMF and World Bank exports estimates.
# Updating source:
#   IEA, IRENA, UNSD, WHO, and World Bank <- IEA, IRENA, UNSD, World Bank, WHO. 2023. Tracking SDG 7: The Energy Progress Report. World Bank, Washington DC. © World Bank. License: Creative Commons Attribution—NonCommercial 3.0 IGO (CC BY-NC 3.0 IGO).
# Updating source:
#   UN-Habitat, via World Bank <- United Nations Human Settlements Programme (UN-HABITAT)
# Updating source:
#   World Health Organization, via World Bank <- World Health Organization, Global Health Observatory Data Repository/World Health Statistics (http://apps.who.int/gho/data/node.main.1?lang=en).
# Updating source:
#   International Monetary Fund and World Bank <- International Monetary Fund, Balance of Payments database, and World Bank, International Debt Statistics.
# Updating source:
#   UNHCR and UNRWA, via World Bank <- United Nations High Commissioner for Refugees (UNHCR) and UNRWA through UNHCR's Refugee Data Finder at https://www.unhcr.org/refugee-statistics/.
# Updating source:
#   UN Office on Drugs and Crime, via World Bank <- UN Office on Drugs and Crime's International Homicide Statistics database.
# Updating source:
#   EDGAR (European Commission JRC), IEA, and World Bank <- EDGAR (Emissions Database for Global Atmospheric Research) Community GHG Database, a collaboration between the European Commission, Joint Research Centre (JRC), the International Energy Agency (IEA), and comprising IEA-EDGAR CO2, EDGAR CH4, EDGAR N2O, EDGAR F-GASES version 8.0, (2023) European Commission, JRC (Datasets). https://edgar.jrc.ec.europa.eu/dataset_ghg74
# Updating source:
#   WHO and UNICEF, via World Bank <- WHO and UNICEF (http://www.who.int/immunization/monitoring_surveillance/en/).
# Updating source:
#   International Union of Railways and OECD, via World Bank <- Internation Union of Railways (UIC Railisa Database), OECD Statistics
# Updating source:
#   EDGAR (European Commission JRC), IEA, and World Bank <- EDGAR (Emissions Database for Global Atmospheric Research) Community GHG Database, a collaboration between the European Commission, Joint Research Centre (JRC), the International Energy Agency (IEA), and comprising IEA-EDGAR CO2, EDGAR CH4, EDGAR N2O, EDGAR F-GASES version 8.0, (2023) European Commission, JRC (Datasets). https://edgar.jrc.ec.europa.eu/dataset_ghg78
# Updating source:
#   United Nations Statistics Division, via World Bank <- United Nations Statistics Division (UNSD)
# Updating source:
#   World Bank based on IMF Direction of Trade Statistics <- World Bank staff estimates based data from International Monetary Fund's Direction of Trade database.
# Updating source:
#   United Nations Population Division, Eurostat, national statistical offices, and United Nations Statistics Division, via World Bank <- (1) United Nations Population Division. World Population Prospects: 2022 Revision; (2) Statistical databases and publications from national statistical offices; (3) Eurostat: Demographic Statistics; (4) United Nations Statistics Division. Population and Vital Statistics Reprot (various years).
# Updating source:
#   International Labour Organization, ILOSTAT, via World Bank <- International Labour Organization. “ILO modelled estimates database” ILOSTAT. Accessed February 07, 2024. https://ilostat.ilo.org/data/.
# Updating source:
#   Eurostat, OECD, and World Bank <- International Comparison Program, World Bank | World Development Indicators database, World Bank | Eurostat-OECD PPP Programme.
# Updating source:
#   International Labour Organization, UNICEF, and World Bank <- Understanding Children's Work project based on data from ILO, UNICEF and the World Bank.
# Updating source:
#   Lancet Commission on Global Surgery, WHO, and BMJ Global Health, via World Bank <- Data collected by the Lancet Commission on Global Surgery (www.lancetglobalsurgery.org); Data collected by WHO Collaborating Centre for Surgery and Public Health at Lund University from various sources including Ministries of Health or equivalent national regulatory bodies, national official entities such as medical councils, Eurostat, OECD, WHO Euro Health For All Database, WHO EURO Technical resources for health Database; BMJ Glob Health.
# Updating source:
#   World Health Organization and OECD, via World Bank <- World Health Organization's Global Health Workforce Statistics, OECD, supplemented by country data.
# Updating source:
#   International Monetary Fund, OECD, and World Bank <- International Monetary Fund, Government Finance Statistics Yearbook and data files, and World Bank and OECD value added estimates.
# Updating source:
#   World Bank based on United Nations Statistics Division <- World Bank staff estimates using data from the United Nations Statistics Division's National Accounts Statistics.
# Updating source:
#   UN Inter-agency Group for Child Mortality Estimation (UNICEF, WHO, World Bank, UN DESA Population Division) <- Estimates developed by the UN Inter-agency Group for Child Mortality Estimation (UNICEF, WHO, World Bank, UN DESA Population Division) at www.childmortality.org.
# Updating source:
#   Remittance Prices Worldwide - World Bank <- World Bank, Remittance Prices Worldwide, available at http://remittanceprices.worldbank.org
# Updating source:
#   United Nations Population Division, Eurostat, national statistical offices, and United Nations Statistics Division, via World Bank <- (1) United Nations Population Division. World Population Prospects: 2024 Revision; (2) Statistical databases and publications from national statistical offices; (3) Eurostat: Demographic Statistics; (4) United Nations Statistics Division. Population and Vital Statistics Report (various years).
# Updating source:
#   International Institute for Strategic Studies, via World Bank <- International Institute for Strategic Studies, The Military Balance.
# Updating source:
#   World Bank and UNESCO Institute for Statistics <- World Bank and UIS
# Updating source:
#   World Bank based on UNCTAD TRAINS and United Nations Statistics Division Comtrade <- World Bank staff estimates using the World Integrated Trade Solution system, based on tariff data from the United Nations Conference on Trade and Development's Trade and Development's Trade Analysis and Information System (TRAINS) database and global imports data from the United Nations Statistics Division's Comtrade database.
# Updating source:
#   Private Participation in Infrastructure Project Database - World Bank <- World Bank, Private Participation in Infrastructure Project Database (http://ppi.worldbank.org).
# Updating source:
#   United Nations Population Division, via World Bank <- United Nations Population Division. World Urbanization Prospects: 2018 Revision.
# Updating source:
#   Inter-Parliamentary Union (IPU), via World Bank <- Inter-Parliamentary Union (IPU) (www.ipu.org).  For the year of 1998, the data is as of August 10, 1998.
# Updating source:
#   International Debt Statistics - World Bank and OECD <- World Bank, International Debt Statistics, and OECD.
# Updating source:
#   International Labour Organization, ILOSTAT, via World Bank <- International Labour Organization. “ILO modelled estimates database” ILOSTAT. Accessed February 06, 2024. https://ilostat.ilo.org/data/.
# Updating source:
#   UNIDO Competitive Industrial Performance (CIP) database, via World Bank <- United Nations Industrial Development Organization (UNIDO), Competitive Industrial Performance (CIP) database
# Updating source:
#   International Labour Organization, ILOSTAT, via World Bank <- International Labour Organization. “Wages and Working Time Statistics database (COND)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.
# Updating source:
#   IEA and OECD, via World Bank <- IEA Statistics © OECD/IEA 2018 (https://www.iea.org/data-and-statistics), subject to https://www.iea.org/terms/
# Updating source:
#   Grassi et al. (2022), via World Bank <- Grassi, G., Conchedda, G., Federici, S., Abad Viñas, R., Korosuo, A., Melo, J., Rossi, S., Sandker, M., Somogyi, Z., and Tubiello, F. N.: Carbon fluxes from land 2000–2020: bringing clarity on countries’ reporting, Earth Syst. Sci. Data, 14, 4643–4666, 2022, doi:10.5194/essd-14-4643-2022. Data available from https://doi.org/10.5281/zenodo.7190602
# Updating source:
#   International Civil Aviation Organization (ICAO), via World Bank <- International Civil Aviation Organization, Civil Aviation Statistics of the World and ICAO staff estimates.
# Updating source:
#   World Bank <- World Bank.
# Updating source:
#   EDGAR Community GHG Database (European Commission, JRC, IEA), via World Bank <- EDGAR (Emissions Database for Global Atmospheric Research) Community GHG Database, a collaboration between the European Commission, Joint Research Centre (JRC), the International Energy Agency (IEA), and comprising IEA-EDGAR CO2, EDGAR CH4, EDGAR N2O, EDGAR F-GASES version 8.0, (2023) European Commission, JRC (Datasets). https://edgar.jrc.ec.europa.eu/dataset_ghg75
# Updating source:
#   International Financial Statistics - IMF, via World Bank <- International Monetary Fund, International Financial Statistics.
# Updating source:
#   World Intellectual Property Organization (WIPO), via World Bank <- World Intellectual Property Organization (WIPO), Statistics Database at www.wipo.int/ipstats/. The International Bureau of WIPO assumes no responsibility with respect to the transformation of these data.
# Updating source:
#   Netcraft, via World Bank <- Netcraft (http://www.netcraft.com/)
# Updating source:
#   United Nations Statistics Division, via World Bank <- National statistical offices or national database and publications compiled by United Nations Statistics Division.  The data were downloaded on April 4, 2024, from the Global SDG  API: https://unstats.un.org/sdgs/UNSDGAPIV5/swagger/index.html
# Updating source:
#   ASPIRE: The Atlas of Social Protection, World Bank <- ASPIRE: The Atlas of Social Protection - Indicators of Resilience and Equity, The World Bank. Data are based on national representative household surveys. (datatopics.worldbank.org/aspire/)
# Updating source:
#   Logistics Performance Index (LPI), World Bank <- Data are available online at: https://lpi.worldbank.org/. Summary results are published in World Bank (2023): Connecting to Compete: Trade Logistics in the Global Economy, The Logistics Performance Index and Its Indicators.
# Updating source:
#   Development Assistance Committee - OECD, via World Bank <- Development Assistance Committee of the Organisation for Economic Co-operation and Development, Geographical Distribution of Financial Flows to Developing Countries, Development Co-operation Report, and International Development Statistics database. Data are available online at: www.oecd.org/dac/stats/idsonline. World Bank gross capital formation estimates are used for the denominator.
# Updating source:
#   Logistics Performance Index (LPI), World Bank and Turku School of Economics <- World Bank and Turku School of Economics, Logistic Performance Index Surveys. Data are available online at : http://www.worldbank.org/lpi. Summary results are published in Arvis and others' Connecting to Compete: Trade Logistics in the Global Economy, The Logistics Performance Index and Its Indicators report.
# Updating source:
#   World Bank national accounts data <- World Bank national accounts data files.
# Updating source:
#   Harvard Medical School Program in Global Surgery and Social Change (PGSSC), via World Bank <- The Program in Global Surgery and Social Change (PGSSC) at Harvard Medical School (https://www.pgssc.org/)
# Updating source:
#   World Bank and OECD national accounts <- World Bank national accounts data, and OECD National Accounts data files.
# Updating source:
#   World Bank based on IMF and OECD <- World Bank staff estimates based on IMF balance of payments data, and World Bank and OECD GDP estimates.
# Updating source:
#   FishBase (Froese and Pauly, 2008), via World Bank <- Froese, R. and Pauly, D. (eds). 2008. FishBase database, www.fishbase.org.
# Updating source:
#   Women, Business and the Law, World Bank <- World Bank: Women, Business and the Law. https://wbl.worldbank.org/
# Updating source:
#   World Health Organization, via World Bank <- World Health Organization, Global Health Observatory Data Repository/World Health Statistics.
# Updating source:
#   IEA and OECD, via World Bank <- IEA Statistics © OECD/IEA 2014 (https://www.iea.org/data-and-statistics), subject to https://www.iea.org/terms/
# Updating source:
#   International Financial Statistics - IMF, via World Bank <- International Monetary Fund, International Financial Statistics, supplemented by World Bank staff estimates.
# Updating source:
#   Demographic and Health Surveys (DHS), and UNAIDS, via World Bank <- Demographic and Health Surveys, and UNAIDS.
# Updating source:
#   UNICEF, World Health Organization, and World Bank <- UNICEF, WHO, World Bank: Joint child Malnutrition Estimates (JME). Aggregation is based on UNICEF, WHO, and the World Bank harmonized dataset (adjusted, comparable data) and methodology.
# Updating source:
#   Grassi et al. (2022), via World Bank <- Grassi, G., Conchedda, G., Federici, S., Abad Viñas, R., Korosuo, A., Melo, J., Rossi, S., Sandker, M., Somogyi, Z., and Tubiello, F. N.: Carbon fluxes from land 2000–2020: bringing clarity on countries’ reporting, Earth Syst. Sci. Data, 14, 4643–4666, 2022, doi:10.5194/essd-14-4643-2022. Data available from https://doi.org/10.5281/zenodo.7190604
# Updating source:
#   Demographic and Health Surveys (DHS), Multiple Indicator Cluster Surveys (MICS), and UNICEF, via World Bank <- UNICEF DATA (http://www.data.unicef.org/);  Demographic and Health Surveys (DHS); Multiple Indicator Cluster Surveys (MICS), and other surveys.
# Updating source:
#   Enterprise Surveys - World Bank <- World Bank, Enterprise Surveys (http://www.enterprisesurveys.org/)
# Updating source:
#   World Bank based on data from the UN Population Division <- World Bank staff estimates based on the United Nations Population Division's World Urbanization Prospects: 2018 Revision.
# Updating source:
#   Grassi et al. (2022), via World Bank <- Grassi, G., Conchedda, G., Federici, S., Abad Viñas, R., Korosuo, A., Melo, J., Rossi, S., Sandker, M., Somogyi, Z., and Tubiello, F. N.: Carbon fluxes from land 2000–2020: bringing clarity on countries’ reporting, Earth Syst. Sci. Data, 14, 4643–4666, 2022, doi:10.5194/essd-14-4643-2022. Data available from https://doi.org/10.5281/zenodo.7190603
# Updating source:
#   Development Assistance Committee - OECD, via World Bank <- Development Assistance Committee of the Organisation for Economic Co-operation and Development, Geographical Distribution of Financial Flows to Developing Countries, Development Co-operation Report, and International Development Statistics database. Data are available online at: www.oecd.org/dac/stats/idsonline. World Bank population estimates are used for the denominator.
# Updating source:
#   World Bank and OECD national accounts, and ILOSTAT <- Derived using World Bank national accounts data and OECD National Accounts data files, and employment data from International Labour Organization, ILOSTAT database.
# Updating source:
#   Poverty and Inequality Platform - World Bank <- World Bank, Poverty and Inequality Platform. Data are compiled from official government sources or are computed by World Bank staff using national (i.e. country–specific) poverty lines.
# Updating source:
#   Poverty and Inequality Platform - World Bank <- World Bank’s Poverty and Inequality Platform: http://pip.worldbank.org.
# Updating source:
#   United Nations Industrial Development Organization, via World Bank <- United Nations Industrial Development Organization, International Yearbook of Industrial Statistics.
# Updating source:
#   EDGAR Community GHG Database (European Commission JRC, IEA), via World Bank <- EDGAR (Emissions Database for Global Atmospheric Research) Community GHG Database, a collaboration between the European Commission, Joint Research Centre (JRC), the International Energy Agency (IEA), and comprising IEA-EDGAR CO2, EDGAR CH4, EDGAR N2O, EDGAR F-GASES version 8.0, (2023) European Commission, JRC (Datasets). https://edgar.jrc.ec.europa.eu/dataset_ghg72
# Updating source:
#   Development Assistance Committee - OECD, via World Bank <- Development Assistance Committee of the Organisation for Economic Co-operation and Development, Geographical Distribution of Financial Flows to Developing Countries, Development Co-operation Report, and International Development Statistics database. Data are available online at: www.oecd.org/dac/stats/idsonline. World Bank GNI estimates are used for the denominator.
# Updating source:
#   Stockholm International Peace Research Institute (SIPRI), via World Bank <- Stockholm International Peace Research Institute (SIPRI), Arms Transfers Programme (http://portal.sipri.org/publications/pages/transfer/splash).
# Updating source:
#   International Monetary Fund, OECD, and World Bank <- International Monetary Fund, International Financial Statistics and data files, and World Bank and OECD GDP estimates.
# Updating source:
#   Stockholm International Peace Research Institute (SIPRI), via World Bank <- Stockholm International Peace Research Institute (SIPRI), Yearbook: Armaments, Disarmament and International Security.
# Updating source:
#   International Debt Statistics - World Bank <- Debt service is the sum of principle repayments and interest actually paid in currency, goods, or services. This series differs from the standard debt to exports series. It covers only long-term public and publicly guaranteed debt and repayments (repurchases and charges) to the IMF. Exports of goods and services include primary income, but do not include workers' remittances.
# Updating source:
#   Public Expenditure and Financial Accountability (PEFA), via World Bank <- Public Expenditure and Financial Accountability (PEFA). Ministry of Finance (MoF).
# Updating source:
#   Food and Agriculture Organization of the United Nations and World Bank <- Food and Agriculture Organization of the United Nations (FAO)
# Updating source:
#   World Tourism Organization, IMF, and World Bank <- World Tourism Organization, Yearbook of Tourism Statistics, Compendium of Tourism Statistics and data files, and IMF and World Bank imports estimates.
# Updating source:
#   World Health Organization, UNICEF, UNFPA, UNDESA, and World Bank <- WHO, UNICEF, UNFPA, World Bank Group, and UNDESA/Population Division. Trends in Maternal Mortality 2000 to 2020. Geneva, World Health Organization, 2023
# Updating source:
#   World Tourism Organization, via World Bank <- World Tourism Organization, Yearbook of Tourism Statistics, Compendium of Tourism Statistics and data files.
# Updating source:
#   EM-DAT: The OFDA/CRED International Disaster Database, via World Bank <- EM-DAT: The OFDA/CRED International Disaster Database: www.emdat.be, Université Catholique de Louvain, Brussels (Belgium), World Bank.
# Updating source:
#   UNCTADstat - United Nations Conference on Trade and Development, via World Bank <- United Nations Conference on Trade and Development's UNCTADstat database at http://unctadstat.unctad.org/ReportFolders/reportFolders.aspx.
# Updating source:
#   Global Health Estimates - World Health Organization, via World Bank <- Derived based on the data from Global Health Estimates 2020: Deaths by Cause, Age, Sex, by Country and by Region, 2000-2019. Geneva, World Health Organization; 2020. Link: https://www.who.int/data/gho/data/themes/mortality-and-global-health-estimates/ghe-leading-causes-of-death
# Updating source:
#   Uppsala Conflict Data Program, via World Bank <- Uppsala Conflict Data Program, http://www.pcr.uu.se/research/ucdp/.
# Updating source:
#   World Database on Protected Areas (WDPA), via World Bank <- World Database on Protected Areas (WDPA) where the compilation and management is carried out by United Nations Environment World Conservation Monitoring Centre (UNEP-WCMC) in collaboration with governments, non-governmental organizations, academia and industry. The data is available online through the Protected Planet website (https://www.protectedplanet.net/).
# Updating source:
#   United Nations Population Division, Eurostat, and national statistical offices, via World Bank <- (1) United Nations Population Division. World Population Prospects: 2022 Revision; (2) Statistical databases and publications from national statistical offices; (3) Eurostat: Demographic Statistics.
# Updating source:
#   World Trade Organization, via World Bank <- World Trade Organization.
# Updating source:
#   International Monetary Fund, via World Bank <- International Monetary Fund, Government Finance Statistics Yearbook and data files.
# Updating source:
#   Food and Agriculture Organization of the United Nations, OECD, and World Bank <- Food and Agriculture Organization, AQUASTAT data.
# Updating source:
#   United Nations Population Division and Human Mortality Database, via World Bank <- (1) United Nations Population Division. World Population Prospects: 2022 Revision. (2) HMD. Human Mortality Database. Max Planck Institute for Demographic Research (Germany), University of California, Berkeley (USA), and French Institute for Demographic Studies (France). Available at www.mortality.org.
# Updating source:
#   International Labour Organization, ILOSTAT, via World Bank <- International Labour Organization. “Labour Force Statistics database (LFS)” ILOSTAT. Accessed October 16, 2024. https://ilostat.ilo.org/data/.
# Updating source:
#   Worldwide Governance Indicators (WGI), World Bank <- Detailed documentation of the WGI, interactive tools for exploring the data, and full access to the underlying source data available at www.govindicators.org.The WGI are produced by Daniel Kaufmann (Natural Resource Governance Institute and Brookings Institution) and Aart Kraay (World Bank Development Research Group).  Please cite Kaufmann, Daniel, Aart Kraay and Massimo Mastruzzi (2010).  "The Worldwide Governance Indicators:  Methodology and Analytical Issues".  World Bank Policy Research Working Paper No. 5430 (http://papers.ssrn.com/sol3/papers.cfm?abstract_id=1682130).  The WGI do not reflect the official views of the Natural Resource Governance Institute, the Brookings Institution, the World Bank, its Executive Directors, or the countries they represent.
# Updating source:
#   Statistical Performance Indicators, World Bank <- Statistical Performance Indicators, The World Bank (https://datacatalog.worldbank.org/dataset/statistical-performance-indicators)
# Updating source:
#   UNHCR, via World Bank <- United Nations High Commissioner for Refugees (UNHCR), Refugee Data Finder at https://www.unhcr.org/refugee-statistics/.
# Updating source:
#   United Nations Population Division, via World Bank <- United Nations Population Division, World Population Prospects.
# Updating source:
#   Internal Displacement Monitoring Centre, via World Bank <- The Internal Displacement Monitoring Centre (http://www.internal-displacement.org/)
# Updating source:
#   EDGAR (European Commission JRC, IEA), via World Bank <- EDGAR (Emissions Database for Global Atmospheric Research) Community GHG Database, a collaboration between the European Commission, Joint Research Centre (JRC), the International Energy Agency (IEA), and comprising IEA-EDGAR CO2, EDGAR CH4, EDGAR N2O, EDGAR F-GASES version 8.0, (2023) European Commission, JRC (Datasets). https://edgar.jrc.ec.europa.eu/dataset_ghg73
# Updating source:
#   Demographic and Health Surveys (DHS), via World Bank <- Demographic and Health Surveys.
# Updating source:
#   World Bank and International Labour Organization, ILOSTAT <- World Bank, World Development Indicators database. Estimates are based on data obtained from International Labour Organization, ILOSTAT at https://ilostat.ilo.org/data/.
# Updating source:
#   World Bank, International Labour Organization, United Nations Population Division, Eurostat, and OECD <- World Bank, World Development Indicators database. Estimates are based on employment, population, GDP, and PPP data obtained from International Labour Organization, United Nations Population Division, Eurostat, OECD, and World Bank.
# Updating source:
#   International Labour Organization, ILOSTAT, via World Bank <- International Labour Organization. “ILO Modelled Estimates and Projections database (ILOEST)” ILOSTAT. Accessed June 18, 2024. https://ilostat.ilo.org/data/.
# Updating source:
#   International Monetary Fund, via World Bank <- International Monetary Fund, International Financial Statistics and data files.
# Updating source:
#   EDGAR (European Commission JRC, IEA), via World Bank <- EDGAR (Emissions Database for Global Atmospheric Research) Community GHG Database, a collaboration between the European Commission, Joint Research Centre (JRC), the International Energy Agency (IEA), and comprising IEA-EDGAR CO2, EDGAR CH4, EDGAR N2O, EDGAR F-GASES version 8.0, (2023) European Commission, JRC (Datasets). https://edgar.jrc.ec.europa.eu/dataset_ghg79
# Updating source:
#   EDGAR (European Commission JRC, IEA) and Grassi et al. (2022), via World Bank <- EDGAR (Emissions Database for Global Atmospheric Research) Community GHG Database, a collaboration between the European Commission, Joint Research Centre (JRC), the International Energy Agency (IEA), and comprising IEA-EDGAR CO2, EDGAR CH4, EDGAR N2O, EDGAR F-GASES version 8.0, (2023) European Commission, JRC (Datasets). https://edgar.jrc.ec.europa.eu/dataset_ghg72; Grassi, G., Conchedda, G., Federici, S., Abad Viñas, R., Korosuo, A., Melo, J., Rossi, S., Sandker, M., Somogyi, Z., and Tubiello, F. N.: Carbon fluxes from land 2000–2020: bringing clarity on countries’ reporting, Earth Syst. Sci. Data, 14, 4643–4666, 2022, doi:10.5194/essd-14-4643-2022. Data available from https://doi.org/10.5281/zenodo.7190601
# Updating source:
#   UNICEF, World Health Organization, and World Bank <- UNICEF, WHO, World Bank: Joint child Malnutrition Estimates (JME).
# Updating source:
#   World Health Organization, via World Bank <- World Health Organization, Global Health Observatory Data Repository (http://apps.who.int/ghodata/).
# Updating source:
#   EDGAR (European Commission JRC, IEA), via World Bank <- EDGAR (Emissions Database for Global Atmospheric Research) Community GHG Database, a collaboration between the European Commission, Joint Research Centre (JRC), the International Energy Agency (IEA), and comprising IEA-EDGAR CO2, EDGAR CH4, EDGAR N2O, EDGAR F-GASES version 8.0, (2023) European Commission, JRC (Datasets). https://edgar.jrc.ec.europa.eu/dataset_ghg76
# Updating source:
#   Development Assistance Committee - OECD, via World Bank <- Development Assistance Committee of the Organisation for Economic Co-operation and Development, Geographical Distribution of Financial Flows to Developing Countries, Development Co-operation Report, and International Development Statistics database. Data are available online at: https://data-explorer.oecd.org/.
# Updating source:
#   World Health Organization, via World Bank <- Global Health Observatory. Geneva: World Health Organization; 2023. (https://www.who.int/data/gho/data/themes/topics/financial-protection)
# Updating source:
#   CPIA database, World Bank <- World Bank Group, CPIA database (http://www.worldbank.org/ida).
# Updating source:
#   Demographic and Health Surveys (DHS), Multiple Indicator Cluster Surveys (MICS), and United Nations Population Division, via World Bank <- Household surveys, including Demographic and Health Surveys and Multiple Indicator Cluster Surveys. Largely compiled by United Nations Population Division.
# Updating source:
#   International Monetary Fund, via World Bank <- International Monetary Fund, Financial Access Survey.
# Updating source:
#   International Monetary Fund, via World Bank <- International Monetary Fund, Financial Soundness Indicators.
# Updating source:
#   Doing Business project, World Bank <- World Bank, Doing Business project (http://www.doingbusiness.org/). NOTE: Doing Business has been discontinued as of 9/16/2021. For more information: https://bit.ly/3CLCbme
# Updating source:
#   World Bank, The Changing Wealth of Nations (2011) <- World Bank staff estimates based on sources and methods in World Bank's "The Changing Wealth of Nations: Measuring Sustainable Development in the New Millennium" (2011).
# Updating source:
#   International Diabetes Federation, via World Bank <- International Diabetes Federation, Diabetes Atlas.
# Updating source:
#   United Nations Population Division, national statistical offices, and Eurostat, via World Bank <- (1) United Nations Population Division. World Population Prospects: 2022 Revision; or derived from male and female life expectancy at birth from sources such as: (2) Statistical databases and publications from national statistical offices; (3) Eurostat: Demographic Statistics.
# Updating source:
#   UNICEF and World Health Organization, via World Bank <- UNICEF-WHO Low birthweight estimates [data.unicef.org]
# Updating source:
#   UNAIDS, via World Bank <- UNAIDS estimates.
# Updating source:
#   Global Burden of Disease Study 2013, Institute for Health Metrics and Evaluation (IHME), via World Bank <- Data on health impacts from exposure to ambient PM2.5 pollution and household air pollution are from the Global Burden of Disease 2013 study. Data are provided by the Institute for Health Metrics and Evaluation at the University of Washington.
# Updating source:
#   International Union of Railways (UIC), via World Bank <- Internation Union of Railways (UIC)
# Updating source:
#   Global Burden of Disease Study 2019, Institute for Health Metrics and Evaluation (IHME), via World Bank <- Global Burden of Disease Collaborative Network. 2021. Global Burden of Disease Study 2019 (GBD 2019) Air Pollution Exposure Estimates 1990-2019. Seattle, United States of America: Institute for Health Metrics and Evaluation (IHME). https://doi.org/10.6069/70JS-NC54
# Updating source:
#   Development Assistance Committee - OECD, via World Bank <- Development Assistance Committee of the Organisation for Economic Co-operation and Development, Geographical Distribution of Financial Flows to Developing Countries, Development Co-operation Report, and International Development Statistics database. Data are available online at: www.oecd.org/dac/stats/idsonline. World Bank imports of good and services estimates are used for the denominator.
# Updating source:
#   Brauer et al. (2017), via World Bank <- Brauer, M. et al. 2017, for the Global Burden of Disease Study 2017.
# Updating source:
#   WHO/UNICEF Joint Monitoring Programme (JMP), via World Bank <- WHO/UNICEF Joint Monitoring Programme (JMP) for Water Supply, Sanitation and Hygiene (washdata.org).
# Updating source:
#   World Integrated Trade Solution (WITS), World Trade Organization, via World Bank <- World Bank staff estimates using the World Integrated Trade Solution system, based on data from World Trade Organization.
# Updating source:
#   Poverty and Inequality Platform, World Bank <- World Bank, Poverty and Inequality Platform. Data are based on primary household survey data obtained from government statistical agencies and World Bank country departments. Data for high-income economies are mostly from the Luxembourg Income Study database. For more information and methodology, please see http://pip.worldbank.org.
# Updating source:
#   World Trade Organization and World Bank <- World Trade Organization, and World Bank GDP estimates.
# Updating source:
#   International Monetary Fund, OECD, and World Bank <- International Monetary Fund, International Financial Statistics and Balance of Payments databases, World Bank, International Debt Statistics, and World Bank and OECD GDP estimates.
# Updating source:
#   United Nations, World Urbanization Prospects, via World Bank <- United Nations, World Urbanization Prospects.
# Updating source:
#   Demographic and Health Surveys (DHS), via World Bank <- Demographic and Health Surveys (DHS)
# Updating source:
#   International Labour Organization, ILOSTAT, via World Bank <- International Labour Organization. “ILO Modelled Estimates and Projections database (ILOEST)” ILOSTAT. Accessed February 06, 2024. https://ilostat.ilo.org/data/.
# Updating source:
#   World Bank (2018) <- World Bank staff calculations based on the methodology described in World Bank (2018). https://openknowledge.worldbank.org/handle/10986/30498
# Updating source:
#   UN Conference on Trade and Development (UNCTAD), via World Bank <- United Nations Conference on Trade and Development, Handbook of Statistics and data files. (http://unctadstat.unctad.org)
# Updating source:
#   World Integrated Trade Solution (WITS), UNCTAD TRAINS, via World Bank <- World Bank staff estimates using the World Integrated Trade Solution system, based on data from United Nations Conference on Trade and Development's Trade Analysis and Information System (TRAINS) database.
# Updating source:
#   Food and Agriculture Organization of the United Nations, via World Bank <- Food and Agriculture Organization (http://www.fao.org/faostat/en/#home).
# Updating source:
#   Demographic and Health Surveys (DHS), Multiple Indicator Cluster Surveys (MICS), UNICEF, and other surveys, via World Bank <- UNICEF Data; Demographic and Health Surveys (DHS), Multiple Indicator Cluster Surveys (MICS), AIDS Indicator Surveys(AIS), Reproductive Health Survey(RHS), and other household surveys.
# Updating source:
#   Food and Agriculture Organization of the United Nations, OECD, and World Bank <- Food and Agriculture Organization, AQUASTAT data, and World Bank and OECD GDP estimates.
# Updating source:
#   World Health Organization Global Health Expenditure Database, via World Bank <- World Health Organization Global Health Expenditure database (http://apps.who.int/nha/database). The data was retrieved on April 15, 2024.
# Updating source:
#   International Monetary Fund and World Bank <- International Monetary Fund, International Financial Statistics and data files using World Bank data on the GDP deflator.
# Updating source:
#   Enterprise Surveys, World Bank <- World Bank, Enterprise Surveys (http://www.enterprisesurveys.org/).
# Updating source:
#   International Debt Statistics - World Bank <- World Bank, International Debt Statistics.
# Updating source:
#   International Monetary Fund, via World Bank <- International Monetary Fund, Balance of Payments Statistics Yearbook and data files.
# Updating source:
#   World Bank based on data from the UN Population Division <- World Bank staff estimates based on age/sex distributions of United Nations Population Division's World Population Prospects: 2024 Revision.
# Updating source:
#   World Intellectual Property Organization (WIPO), via World Bank <- World Intellectual Property Organization (WIPO), WIPO Patent Report: Statistics on Worldwide Patent Activity. The International Bureau of WIPO assumes no responsibility with respect to the transformation of these data.
# Updating source:
#   UNISDR, via World Bank <- (UNISDR, 2009-2011 Progress Reports, http://www.preventionweb.net/english/hyogo).
# Updating source:
#   UNESCO Institute for Statistics, via World Bank <- UNESCO Institute for Statistics (http://uis.unesco.org/). Data as of March 2021.
